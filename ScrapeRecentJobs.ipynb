# %%
# Import Packages 
import csv
from datetime import *
import numpy
import math
import requests
from bs4 import BeautifulSoup
import pandas as pd
import time
import re
from nltk import *
from nltk.collocations import BigramCollocationFinder, TrigramCollocationFinder
from nltk.metrics import BigramAssocMeasures, TrigramAssocMeasures
from nltk.corpus import stopwords

# %%
def get_job_results(url: str, info_id: str) -> list:
    """"Return page results from job site"""
    page = requests.get(url)
    soup = BeautifulSoup(page.content, 'html.parser')
    results = soup.find(id=info_id) 
    return results

def collect_individual_search_info(site: str, individual_searches: list, total_results_frame, unique_results_frame, search_times: list, total_search_time: float, notes:str = None):
    """Return individual search info as one DataFrame"""
    # Create framework for the individual search data. 
    individual_searches_frame = pd.DataFrame(individual_searches, columns=['search_location', 'search_title'])
    individual_searches_frame['SearchTimes'] = search_times
    individual_searches_frame['Site'] = site
    individual_searches_frame['Date'] = datetime.now().strftime("%Y-%m-%d %H:%M:%S")

    # Collect the counts for the results before removing duplicates.
    total_results = total_results_frame[['search_title', 'search_location', 'description']].groupby(['search_title', 'search_location'], as_index=False).count()

    # Collect the counts for the results after removing duplicates.
    unique_results = unique_results_frame[['search_title', 'search_location', 'description']].groupby(['search_title', 'search_location'], as_index=False).count()

    # Add the Total Results count to the individual searches frame.
    individual_searches_frame = pd.merge(
        individual_searches_frame, 
        pd.DataFrame({
            'search_title': total_results['search_title'], 
            'search_location': total_results['search_location'], 
            'TotalResults': total_results['description']
            }),
        on=['search_title', 'search_location'], 
        how='left'
        )

    # Add the Unique Results count to the individual searches frame.
    individual_searches_frame = pd.merge(
        individual_searches_frame, 
        pd.DataFrame({
            'search_title': unique_results['search_title'], 
            'search_location': unique_results['search_location'], 
            'UniqueResults': unique_results['description']
            }),
            on=['search_title', 'search_location'], 
            how='left'
            )
    
    # Where we didn't have a results count we must not have found anything, so replace the NaN with a 0.
    for col in ['TotalResults', 'UniqueResults']:
        individual_searches_frame[col][individual_searches_frame[col].isnull()] = 0

    # Add the total search time to the data frame.
    individual_searches_frame['TotalSearchTime'] = total_search_time
    # Add any notes we have to the frame.
    individual_searches_frame['Notes'] = notes
    individual_searches_frame.to_csv('Diagnostics/ScraperPerformancebySearch.csv', mode='a', header=False)
  

def preprocess_jobs_recent(initial_data):
    """Clean up the jobs frame"""
    for col in [col for col in indeed_0.columns if col is not 'posted']:
        initial_data[col] = initial_data[col].str.replace('\n', ' ')
    processed_data = initial_data.drop_duplicates(subset=['title', 'company', 'description'], keep='first')
    processed_data['description'] = processed_data['description'].str.replace(r"([a-z])([A-Z])", r"\1 \.\2")
    processed_data['description'] = processed_data['description'].str.replace(r' \\.', '')
    processed_data['posted'] = pd.to_numeric(processed_data['posted'])
    return processed_data


def categorize_jobs(posting_number: int):
    """Place jobs into one of four categories (y, n, u, o)"""
    job_status = input('Is this a job you would want to apply to? (y/n/u/o)')
    if job_status.lower() in ['yes', 'yeah', 'y']:
        yes.append(posting_number)
    elif job_status.lower() in ['no', 'nah', 'n']:
        no.append(posting_number)
    elif job_status.lower() in ['u', 'underqualified']:
        underqualified.append(posting_number)
    elif job_status.lower() in ['o', 'other', 'm', 'maybe']:
        other.append(posting_number)

def JobPostBisandTris(posting_number: int, n_results_per: int = 10, sorting: bool = True):
    '''
        Print Important Bigrams and Trigrams 
        0. Assemble stopword set
        1. Tokenize Sentences
        2. Remove sentences with particular words 
        3. Tokenize words from remaining sentences
        4. Remove stopwords
        5. Print collection of important bigrams and trigrams
        6. Print the entire job description
        7. If we are sorting, prompt user for whether it's a job to apply to
    ''' 
    stopset = set(stopwords.words('english') + word_tokenize(df['company'][posting_number].lower()))
    sentences = sent_tokenize(df.description[posting_number])
    sentences = [sentence for sentence in sentences if not [p for p in ['equal opportunity', 'not discriminate', 'diversity', 'affirmative action', 'gender', 'eoe'] if p  in sentence.lower()]]
    words = [word for words in sentences for word in word_tokenize(words.lower()) if word not in stopset]
    words = [word for word in words if (word.isalpha() or word.isnumeric()) and (len(word) < 2 or len(word) > 3)]
    bcf = BigramCollocationFinder.from_words(words)
    tcf = TrigramCollocationFinder.from_words(words)
    # Print company and job title
    print(df.company[posting_number])
    print(df.title[posting_number])
    print()
    # print bigrams
    print('Bigrams')
    print(set(bcf.nbest(BigramAssocMeasures.likelihood_ratio, n_results_per) + bcf.nbest(BigramAssocMeasures.raw_freq, n_results_per) + bcf.nbest(BigramAssocMeasures.chi_sq, n_results_per)))
    print()
    # Print Trigrams
    print('Trigrams')
    print(set(tcf.nbest(TrigramAssocMeasures.likelihood_ratio, n_results_per) + tcf.nbest(TrigramAssocMeasures.raw_freq, n_results_per) + tcf.nbest(TrigramAssocMeasures.chi_sq, n_results_per)))
    print()
    print(df.description[posting_number])
    print('Link:\n', df.link[posting_number])
    # If we are sorting them to train an algo
    if sorting:
        # If we are sorting through them
        categorize_jobs(posting_number)

    
def save_search_stats(site: str, total_returned_jobs: int, unique_jobs: int, search_time: float, total_searches: int, notes: str):
    """Write search statistics as new row in ScraperPerformance.csv"""
    with open('Diagnostics/ScraperPerformance.csv', 'a+', newline='') as file:
        write = csv.writer(file, delimiter=',')
        notes = notes.replace(',', ';')
        write.writerow([site, total_returned_jobs, unique_jobs, search_time, total_searches, date.today(), notes])

# %%
###############################
# Initialize Empty Containers #
###############################

# Index lists for sorting jobs (to train the algo)
yes = []
no = []
underqualified = []
other = []

# Empty container for posting info
jobs_indeed = []
jobs_monster = []

# %%
####################
# Data Frame Columns
columns = ['search_title', 'search_location', 'location', 'title', 'company', 'posted', 'salary', 'summary', 'link', 'description']

###############
# Job titles
prefixes = ['entry level ', 'junior ', 'associate ', '']
titles = ['business analyst', 'data analyst', 'data scientist', 'financial analyst', 'macro analyst']

################
# Job Locations
search_locations = [
    'New York, NY',
    'Newark, NJ', 'Princeton, NJ', 'Jersey City, NJ', 'Trenton, NJ', 'Bridgewater, NJ', 'Somerville, NJ', 'Summit, NJ', 'Morristown, NJ', 'Edison, NJ', 'Metuchen, NJ', 'Hackensack, NJ',
    'Philadelphia, PA', 
    'Stamford, CT', 'Greenwich, CT',
    'New York', 'New Jersey', 'New Hampshire', 'Pennsylvania', 'Connecticut',
    'NY', 'NJ', 'NH', 'PA', 'CT',
    'remote'
    ]


n_searches = (len(titles) * len(prefixes)) * len(search_locations)

# %% [markdown]
# # Indeed

# %%
################################
################################
#### Scrape Indeed for Jobs ####
################################
################################

# Four Fors: Because who needs a head hunter anyways?
# 1. Search each location
#   2. Search each job title
#       3. Search each page of results 
#           4. Get each job's description
# nlocations * ntitles * npages * njobdescriptions = niterations
# 
# NOTE We sleep before hitting the page because if we over do it they won't give us the data
# 

#######################
# Change these fields #
#######################

#######################
# URL Fields
# How many pages per locale
location_results = 100
# How far out should we look?
radius = 50


########################
# Performance Monitors #
########################
search_times_indeed = []
individual_searches = []

# Initialize these for performance monitoring
ttm = True
start_time = time.time()
counter = 1

# Main two iterators for the search, 
for search_location in search_locations: 
    for search_title in [(s + t) for s in prefixes for t in titles]:

       ####################################
        # Monitoring Chunk
        individual_searches.append([search_location, search_title])
        if counter > 1: 
            search_time = time.time() - search_start
            search_times_indeed.append(search_time)
            if ttm:
                print(f'The search took {search_time} seconds.\n')
        if ttm:
            print(f'Searching {search_location} for {search_title} positions \tSearch number {counter} of {n_searches}') 
        counter += 1
        search_start = time.time()
        #####################################

        for nresults in range(0, location_results, 10):            
            # Go to the url below and get the results from each page
            s = search_location.replace(' ', '%20').replace(',', '%2C')
            st = search_title.replace(' ', '%20')
            url = f'https://www.indeed.com/jobs?q={st}+%2420%2C000&l={s}+&radius={radius}&start={str(nresults)}'
            try:
                results = get_job_results(url, 'resultsCol')
            except:
                continue
            # If we have run out of postings move on
            if results is None:
                continue
            job_elems = results.find_all('div', class_='jobsearch-SerpJobCard')
            
            ##############################
            # FIND THE MOST RECENT JOB POSTS!!! 
            for job in job_elems:
                # Make sure it's a valid post
                title_elem = job.find('h2', class_='title')
                if title_elem is None:  
                    continue
                
                # If it was posted 'days ago' we don't want it
                when_elem = job.find('span', class_='date')
                if 'days' in when_elem.text.strip():
                    continue

                title = title_elem.text.strip()              
                     
                # Company:
                company_elem = job.find('span', class_='company')
                if company_elem is None:
                    continue
                else:
                    company_elem = company_elem.text.strip()


                #########################
                #   Location: Where is the job
                #   Salary: How much are they paying
                #   Summary: What's the provided job summary
                location_elem = job.find('span', class_='location')
                salary_elem = job.find('span', class_='salary')
                summary_elem = job.find('div', class_='summary')
                 
                
                # If there isn't a location provided, denote that
                if location_elem is None:
                    location_elem = 'No Location Provided'
                else:
                    location_elem = location_elem.text.strip()

                if 'day' in when_elem.text.strip():
                    when_elem = 1
                else:
                    when_elem = 0

                # If there isn't a salary provided, denote that
                if salary_elem is None:
                    salary_elem = 'No Salary Provided'
                else:
                    salary_elem = salary_elem.text.strip()
                
                 # If there isn't a job summary provided, denote that
                if summary_elem is None:
                    summary_elem = 'No Summary Provided'
                else:
                    summary_elem = summary_elem.text.strip()


                ##################################
                # Go to the Job Description Page #
                ##################################
                # Wait {sleep_time} seconds before hitting the page so they don't kick us out
                # 
                time.sleep(0.5)
                link = job.find('a')['href']
                description_url = f'https://www.indeed.com{link}'
                try:
                    description_results = get_job_results(description_url, 'jobDescriptionText')
                except:
                    continue
                # If we screwed up locating the description, denote that
                if description_results is None:
                    description_text = 'No Description Found'
                else:
                    description_text = description_results.text.strip()

                # Create an array of info for this job posting
                info = [
                    search_title,
                    search_location,
                    location_elem, 
                    title,
                    company_elem,
                    when_elem,
                    salary_elem,
                    summary_elem,
                    description_url,
                    description_text
                ]

                # Append the job info array to the array of job posting arrays
                jobs_indeed.append(info)

# This adds the time for the final search.
search_time = time.time() - search_start
search_times_indeed.append(search_time)

# Calculate the total search time.
total_search_time = time.time() - start_time

if ttm:
     print(f'Indeed search completed in {total_search_time} seconds. {len(jobs_indeed)} results found (including duplicates).') 

# Convert the array of job arrays into a data frame.
indeed_0 = pd.DataFrame(jobs_indeed, columns=columns)


# Filter and modify the original and put it in a new variable.
indeed_1 = preprocess_jobs_recent(indeed_0)

# Save the monitoring data into their respective csv's for later analysis.
# collect_individual_search_info saves into a new csv which monitors performance of each individual search
collect_individual_search_info('Indeed', individual_searches, indeed_0, indeed_1, search_times_indeed, total_search_time, 'Recent Jobs Only')
save_search_stats('Indeed', len(jobs_indeed), len(indeed_1), total_search_time, n_searches, 'Recent Jobs Only')

# Tell us when we're done!
print(f'Returned {len(indeed_1)} unique entries from Indeed.')
# Out:
# ching New Hampshire for financial analyst positions 	Search number 359 of 520
# The search took 2.6653237342834473 seconds.
#
# Searching New Hampshire for macro analyst positions 	Search number 360 of 520
# The search took 2.6184465885162354 seconds.
#
# Searching Pennsylvania for entry level business analyst positions 	Search number 361 of 520
# The search took 2.5526678562164307 seconds.
#
# Searching Pennsylvania for entry level data analyst positions 	Search number 362 of 520
# The search took 2.7577733993530273 seconds.
#
# Searching Pennsylvania for entry level data scientist positions 	Search number 363 of 520
# The search took 2.6325910091400146 seconds.
#
# Searching Pennsylvania for entry level financial analyst positions 	Search number 364 of 520
# The search took 2.541064739227295 seconds.
#
# Searching Pennsylvania for entry level macro analyst positions 	Search number 365 of 520
# The search took 2.474977970123291 seconds.
#
# Searching Pennsylvania for junior business analyst positions 	Search number 366 of 520
# The search took 2.7312119007110596 seconds.
#
# Searching Pennsylvania for junior data analyst positions 	Search number 367 of 520
# The search took 2.583894729614258 seconds.
#
# Searching Pennsylvania for junior data scientist positions 	Search number 368 of 520
# The search took 2.6301157474517822 seconds.
#
# Searching Pennsylvania for junior financial analyst positions 	Search number 369 of 520
# The search took 2.6721527576446533 seconds.
#
# Searching Pennsylvania for junior macro analyst positions 	Search number 370 of 520
# The search took 2.769012212753296 seconds.
#
# Searching Pennsylvania for associate business analyst positions 	Search number 371 of 520
# The search took 2.6176836490631104 seconds.
#
# Searching Pennsylvania for associate data analyst positions 	Search number 372 of 520
# The search took 2.780325174331665 seconds.
#
# Searching Pennsylvania for associate data scientist positions 	Search number 373 of 520
# The search took 2.542214870452881 seconds.
#
# Searching Pennsylvania for associate financial analyst positions 	Search number 374 of 520
# The search took 2.7292449474334717 seconds.
#
# Searching Pennsylvania for associate macro analyst positions 	Search number 375 of 520
# The search took 2.6973557472229004 seconds.
#
# Searching Pennsylvania for business analyst positions 	Search number 376 of 520
# The search took 2.6985669136047363 seconds.
#
# Searching Pennsylvania for data analyst positions 	Search number 377 of 520
# The search took 2.625943660736084 seconds.
#
# Searching Pennsylvania for data scientist positions 	Search number 378 of 520
# The search took 2.6220862865448 seconds.
#
# Searching Pennsylvania for financial analyst positions 	Search number 379 of 520
# The search took 2.6543893814086914 seconds.
#
# Searching Pennsylvania for macro analyst positions 	Search number 380 of 520
# The search took 2.1002426147460938 seconds.
#
# Searching Connecticut for entry level business analyst positions 	Search number 381 of 520
# The search took 2.2822811603546143 seconds.
#
# Searching Connecticut for entry level data analyst positions 	Search number 382 of 520
# The search took 2.060556173324585 seconds.
#
# Searching Connecticut for entry level data scientist positions 	Search number 383 of 520
# The search took 2.7989749908447266 seconds.
#
# Searching Connecticut for entry level financial analyst positions 	Search number 384 of 520
# The search took 2.525390386581421 seconds.
#
# Searching Connecticut for entry level macro analyst positions 	Search number 385 of 520
# The search took 2.3510429859161377 seconds.
#
# Searching Connecticut for junior business analyst positions 	Search number 386 of 520
# The search took 2.5644750595092773 seconds.
#
# Searching Connecticut for junior data analyst positions 	Search number 387 of 520
# The search took 2.3408966064453125 seconds.
#
# Searching Connecticut for junior data scientist positions 	Search number 388 of 520
# The search took 2.550731658935547 seconds.
#
# Searching Connecticut for junior financial analyst positions 	Search number 389 of 520
# The search took 2.6728768348693848 seconds.
#
# Searching Connecticut for junior macro analyst positions 	Search number 390 of 520
# The search took 2.556990385055542 seconds.
#
# Searching Connecticut for associate business analyst positions 	Search number 391 of 520
# The search took 2.596482038497925 seconds.
#
# Searching Connecticut for associate data analyst positions 	Search number 392 of 520
# The search took 2.579195976257324 seconds.
#
# Searching Connecticut for associate data scientist positions 	Search number 393 of 520
# The search took 2.803816318511963 seconds.
#
# Searching Connecticut for associate financial analyst positions 	Search number 394 of 520
# The search took 2.8488004207611084 seconds.
#
# Searching Connecticut for associate macro analyst positions 	Search number 395 of 520
# The search took 2.713303565979004 seconds.
#
# Searching Connecticut for business analyst positions 	Search number 396 of 520
# The search took 2.7770707607269287 seconds.
#
# Searching Connecticut for data analyst positions 	Search number 397 of 520
# The search took 2.727358102798462 seconds.
#
# Searching Connecticut for data scientist positions 	Search number 398 of 520
# The search took 2.6801745891571045 seconds.
#
# Searching Connecticut for financial analyst positions 	Search number 399 of 520
# The search took 2.7635817527770996 seconds.
#
# Searching Connecticut for macro analyst positions 	Search number 400 of 520
# The search took 2.7376911640167236 seconds.
#
# Searching NY for entry level business analyst positions 	Search number 401 of 520
# The search took 2.876084327697754 seconds.
#
# Searching NY for entry level data analyst positions 	Search number 402 of 520
# The search took 2.631366729736328 seconds.
#
# Searching NY for entry level data scientist positions 	Search number 403 of 520
# The search took 2.7164101600646973 seconds.
#
# Searching NY for entry level financial analyst positions 	Search number 404 of 520
# The search took 2.7347285747528076 seconds.
#
# Searching NY for entry level macro analyst positions 	Search number 405 of 520
# The search took 2.733289957046509 seconds.
#
# Searching NY for junior business analyst positions 	Search number 406 of 520
# The search took 2.5020411014556885 seconds.
#
# Searching NY for junior data analyst positions 	Search number 407 of 520
# The search took 2.8802082538604736 seconds.
#
# Searching NY for junior data scientist positions 	Search number 408 of 520
# The search took 2.704467296600342 seconds.
#
# Searching NY for junior financial analyst positions 	Search number 409 of 520
# The search took 2.5445120334625244 seconds.
#
# Searching NY for junior macro analyst positions 	Search number 410 of 520
# The search took 2.597473382949829 seconds.
#
# Searching NY for associate business analyst positions 	Search number 411 of 520
# The search took 3.190002679824829 seconds.
#
# Searching NY for associate data analyst positions 	Search number 412 of 520
# The search took 2.62475323677063 seconds.
#
# Searching NY for associate data scientist positions 	Search number 413 of 520
# The search took 2.52791690826416 seconds.
#
# Searching NY for associate financial analyst positions 	Search number 414 of 520
# The search took 2.5975897312164307 seconds.
#
# Searching NY for associate macro analyst positions 	Search number 415 of 520
# The search took 2.583573579788208 seconds.
#
# Searching NY for business analyst positions 	Search number 416 of 520
# The search took 2.6815502643585205 seconds.
#
# Searching NY for data analyst positions 	Search number 417 of 520
# The search took 2.70310640335083 seconds.
#
# Searching NY for data scientist positions 	Search number 418 of 520
# The search took 2.467296838760376 seconds.
#
# Searching NY for financial analyst positions 	Search number 419 of 520
# The search took 2.4564156532287598 seconds.
#
# Searching NY for macro analyst positions 	Search number 420 of 520
# The search took 2.957458972930908 seconds.
#
# Searching NJ for entry level business analyst positions 	Search number 421 of 520
# The search took 2.494386672973633 seconds.
#
# Searching NJ for entry level data analyst positions 	Search number 422 of 520
# The search took 2.51509165763855 seconds.
#
# Searching NJ for entry level data scientist positions 	Search number 423 of 520
# The search took 2.498289108276367 seconds.
#
# Searching NJ for entry level financial analyst positions 	Search number 424 of 520
# The search took 2.857553005218506 seconds.
#
# Searching NJ for entry level macro analyst positions 	Search number 425 of 520
# The search took 2.3762080669403076 seconds.
#
# Searching NJ for junior business analyst positions 	Search number 426 of 520
# The search took 2.2002062797546387 seconds.
#
# Searching NJ for junior data analyst positions 	Search number 427 of 520
# The search took 2.0884850025177 seconds.
#
# Searching NJ for junior data scientist positions 	Search number 428 of 520
# The search took 2.096799612045288 seconds.
#
# Searching NJ for junior financial analyst positions 	Search number 429 of 520
# The search took 2.090993642807007 seconds.
#
# Searching NJ for junior macro analyst positions 	Search number 430 of 520
# The search took 1.890681266784668 seconds.
#
# Searching NJ for associate business analyst positions 	Search number 431 of 520
# The search took 2.103510618209839 seconds.
#
# Searching NJ for associate data analyst positions 	Search number 432 of 520
# The search took 2.2582309246063232 seconds.
#
# Searching NJ for associate data scientist positions 	Search number 433 of 520
# The search took 2.0040271282196045 seconds.
#
# Searching NJ for associate financial analyst positions 	Search number 434 of 520
# The search took 2.211846113204956 seconds.
#
# Searching NJ for associate macro analyst positions 	Search number 435 of 520
# The search took 2.2926394939422607 seconds.
#
# Searching NJ for business analyst positions 	Search number 436 of 520
# The search took 2.264636754989624 seconds.
#
# Searching NJ for data analyst positions 	Search number 437 of 520
# The search took 2.4239211082458496 seconds.
#
# Searching NJ for data scientist positions 	Search number 438 of 520
# The search took 2.2080421447753906 seconds.
#
# Searching NJ for financial analyst positions 	Search number 439 of 520
# The search took 3.6266140937805176 seconds.
#
# Searching NJ for macro analyst positions 	Search number 440 of 520
# The search took 2.9081320762634277 seconds.
#
# Searching NH for entry level business analyst positions 	Search number 441 of 520
# The search took 3.2131083011627197 seconds.
#
# Searching NH for entry level data analyst positions 	Search number 442 of 520
# The search took 2.0260775089263916 seconds.
#
# Searching NH for entry level data scientist positions 	Search number 443 of 520
# The search took 2.8862836360931396 seconds.
#
# Searching NH for entry level financial analyst positions 	Search number 444 of 520
# The search took 2.1455576419830322 seconds.
#
# Searching NH for entry level macro analyst positions 	Search number 445 of 520
# The search took 2.534965753555298 seconds.
#
# Searching NH for junior business analyst positions 	Search number 446 of 520
# The search took 2.0650475025177 seconds.
#
# Searching NH for junior data analyst positions 	Search number 447 of 520
# The search took 2.270749568939209 seconds.
#
# Searching NH for junior data scientist positions 	Search number 448 of 520
# The search took 2.199542284011841 seconds.
#
# Searching NH for junior financial analyst positions 	Search number 449 of 520
# The search took 2.007373094558716 seconds.
#
# Searching NH for junior macro analyst positions 	Search number 450 of 520
# The search took 2.3100268840789795 seconds.
#
# Searching NH for associate business analyst positions 	Search number 451 of 520
# The search took 2.241192579269409 seconds.
#
# Searching NH for associate data analyst positions 	Search number 452 of 520
# The search took 2.22200608253479 seconds.
#
# Searching NH for associate data scientist positions 	Search number 453 of 520
# The search took 2.182492971420288 seconds.
#
# Searching NH for associate financial analyst positions 	Search number 454 of 520
# The search took 2.1731808185577393 seconds.
#
# Searching NH for associate macro analyst positions 	Search number 455 of 520
# The search took 2.2513744831085205 seconds.
#
# Searching NH for business analyst positions 	Search number 456 of 520
# The search took 2.096217632293701 seconds.
#
# Searching NH for data analyst positions 	Search number 457 of 520
# The search took 2.009239673614502 seconds.
#
# Searching NH for data scientist positions 	Search number 458 of 520
# The search took 2.1840972900390625 seconds.
#
# Searching NH for financial analyst positions 	Search number 459 of 520
# The search took 2.1430840492248535 seconds.
#
# Searching NH for macro analyst positions 	Search number 460 of 520
# The search took 2.1120409965515137 seconds.
#
# Searching PA for entry level business analyst positions 	Search number 461 of 520
# The search took 2.280210018157959 seconds.
#
# Searching PA for entry level data analyst positions 	Search number 462 of 520
# The search took 2.153137445449829 seconds.
#
# Searching PA for entry level data scientist positions 	Search number 463 of 520
# The search took 2.296977996826172 seconds.
#
# Searching PA for entry level financial analyst positions 	Search number 464 of 520
# The search took 2.8783507347106934 seconds.
#
# Searching PA for entry level macro analyst positions 	Search number 465 of 520
# The search took 2.509036064147949 seconds.
#
# Searching PA for junior business analyst positions 	Search number 466 of 520
# The search took 2.2509713172912598 seconds.
#
# Searching PA for junior data analyst positions 	Search number 467 of 520
# The search took 2.2683639526367188 seconds.
#
# Searching PA for junior data scientist positions 	Search number 468 of 520
# The search took 2.1884994506835938 seconds.
#
# Searching PA for junior financial analyst positions 	Search number 469 of 520
# The search took 2.0238394737243652 seconds.
#
# Searching PA for junior macro analyst positions 	Search number 470 of 520
# The search took 2.369374990463257 seconds.
#
# Searching PA for associate business analyst positions 	Search number 471 of 520
# The search took 2.282047986984253 seconds.
#
# Searching PA for associate data analyst positions 	Search number 472 of 520
# The search took 2.240730047225952 seconds.
#
# Searching PA for associate data scientist positions 	Search number 473 of 520
# The search took 2.4637677669525146 seconds.
#
# Searching PA for associate financial analyst positions 	Search number 474 of 520
# The search took 2.164346218109131 seconds.
#
# Searching PA for associate macro analyst positions 	Search number 475 of 520
# The search took 2.165412187576294 seconds.
#
# Searching PA for business analyst positions 	Search number 476 of 520
# The search took 2.2636024951934814 seconds.
#
# Searching PA for data analyst positions 	Search number 477 of 520
# The search took 2.611825466156006 seconds.
#
# Searching PA for data scientist positions 	Search number 478 of 520
# The search took 2.468437671661377 seconds.
#
# Searching PA for financial analyst positions 	Search number 479 of 520
# The search took 2.059509754180908 seconds.
#
# Searching PA for macro analyst positions 	Search number 480 of 520
# The search took 2.122028112411499 seconds.
#
# Searching CT for entry level business analyst positions 	Search number 481 of 520
# The search took 2.068232297897339 seconds.
#
# Searching CT for entry level data analyst positions 	Search number 482 of 520
# The search took 1.983257532119751 seconds.
#
# Searching CT for entry level data scientist positions 	Search number 483 of 520
# The search took 2.3649814128875732 seconds.
#
# Searching CT for entry level financial analyst positions 	Search number 484 of 520
# The search took 2.722568988800049 seconds.
#
# Searching CT for entry level macro analyst positions 	Search number 485 of 520
# The search took 2.740043878555298 seconds.
#
# Searching CT for junior business analyst positions 	Search number 486 of 520
# The search took 2.6984381675720215 seconds.
#
# Searching CT for junior data analyst positions 	Search number 487 of 520
# The search took 2.632545232772827 seconds.
#
# Searching CT for junior data scientist positions 	Search number 488 of 520
# The search took 2.5926530361175537 seconds.
#
# Searching CT for junior financial analyst positions 	Search number 489 of 520
# The search took 2.6820573806762695 seconds.
#
# Searching CT for junior macro analyst positions 	Search number 490 of 520
# The search took 2.5264499187469482 seconds.
#
# Searching CT for associate business analyst positions 	Search number 491 of 520
# The search took 2.534166097640991 seconds.
#
# Searching CT for associate data analyst positions 	Search number 492 of 520
# The search took 2.61464786529541 seconds.
#
# Searching CT for associate data scientist positions 	Search number 493 of 520
# The search took 2.4808504581451416 seconds.
#
# Searching CT for associate financial analyst positions 	Search number 494 of 520
# The search took 2.2142679691314697 seconds.
#
# Searching CT for associate macro analyst positions 	Search number 495 of 520
# The search took 1.9780311584472656 seconds.
#
# Searching CT for business analyst positions 	Search number 496 of 520
# The search took 2.145918130874634 seconds.
#
# Searching CT for data analyst positions 	Search number 497 of 520
# The search took 2.1780900955200195 seconds.
#
# Searching CT for data scientist positions 	Search number 498 of 520
# The search took 2.2336478233337402 seconds.
#
# Searching CT for financial analyst positions 	Search number 499 of 520
# The search took 2.389716863632202 seconds.
#
# Searching CT for macro analyst positions 	Search number 500 of 520
# The search took 2.181392192840576 seconds.
#
# Searching remote for entry level business analyst positions 	Search number 501 of 520
# The search took 2.102839708328247 seconds.
#
# Searching remote for entry level data analyst positions 	Search number 502 of 520
# The search took 2.286054849624634 seconds.
#
# Searching remote for entry level data scientist positions 	Search number 503 of 520
# The search took 1.998422622680664 seconds.
#
# Searching remote for entry level financial analyst positions 	Search number 504 of 520
# The search took 2.161043405532837 seconds.
#
# Searching remote for entry level macro analyst positions 	Search number 505 of 520
# The search took 2.0378212928771973 seconds.
#
# Searching remote for junior business analyst positions 	Search number 506 of 520
# The search took 1.994184970855713 seconds.
#
# Searching remote for junior data analyst positions 	Search number 507 of 520
# The search took 2.46889328956604 seconds.
#
# Searching remote for junior data scientist positions 	Search number 508 of 520
# The search took 2.51838755607605 seconds.
#
# Searching remote for junior financial analyst positions 	Search number 509 of 520
# The search took 3.114245653152466 seconds.
#
# Searching remote for junior macro analyst positions 	Search number 510 of 520
# The search took 2.609741687774658 seconds.
#
# Searching remote for associate business analyst positions 	Search number 511 of 520
# The search took 2.659416913986206 seconds.
#
# Searching remote for associate data analyst positions 	Search number 512 of 520
# The search took 2.6656546592712402 seconds.
#
# Searching remote for associate data scientist positions 	Search number 513 of 520
# The search took 2.798779249191284 seconds.
#
# Searching remote for associate financial analyst positions 	Search number 514 of 520
# The search took 2.7745652198791504 seconds.
#
# Searching remote for associate macro analyst positions 	Search number 515 of 520
# The search took 2.6269302368164062 seconds.
#
# Searching remote for business analyst positions 	Search number 516 of 520
# The search took 2.585427761077881 seconds.
#
# Searching remote for data analyst positions 	Search number 517 of 520
# The search took 2.525053024291992 seconds.
#
# Searching remote for data scientist positions 	Search number 518 of 520
# The search took 2.4527814388275146 seconds.
#
# Searching remote for financial analyst positions 	Search number 519 of 520
# The search took 2.58577299118042 seconds.
#
# Searching remote for macro analyst positions 	Search number 520 of 520
# Indeed search completed in 1501.7561049461365 seconds. 122 results found (including duplicates).
# Returned 66 unique entries from Indeed.

# %% [markdown]
# # Monster

# %%
########################
# Performance Monitors #
########################
search_times_monster = []
individual_searches = []

# Initialize these for performance monitoring
ttm = True
start_time = time.time()
counter = 1

for search_location in search_locations:
    for search_title in [(s + t) for s in prefixes for t in titles]:

        ####################################
        # Monitoring Chunk
        individual_searches.append([search_location, search_title])
        if counter > 1: 
            search_time = time.time() - search_start
            search_times_monster.append(search_time)
            if ttm:
                print(f'The search took {search_time} seconds.\n')
        if ttm:
            print(f'Searching {search_location} for {search_title} positions \tSearch number {counter} of {n_searches}') 
        counter += 1
        search_start = time.time()
        #####################################

        sl = search_location.replace(' ', '-').replace(',', '__2C')
        st = search_title.replace(' ', '-')
        URL = f'https://www.monster.com/jobs/search/?q={st}&where={sl}&stpage=1&page=10'
        try:
            results = get_job_results(URL, 'ResultsContainer')
        except:
            continue
        job_elems = results.find_all('section', class_='card-content')
        if results is None:
            continue

        for job in job_elems:
            # If the title or company isn't present, continue to the next one
            title_elem = job.find('h2', class_='title')
            if title_elem is None:
                continue
            else:
                title = title_elem.text.strip()
            
            if 'days' in job.find('time').text.strip():
                continue
            elif 'day' in job.find('time').text.strip():
                posted = 1
            else:
                posted = 0

           
            # If the company element isn't present continue to the next
            company_elem = job.find('div', class_='company')
            if company_elem is None:
                continue
            else:
                company = company_elem.text.strip()
            
            # If there isn't a job location provided, indicate that
            location_elem = job.find('div', class_='location')
            if location_elem is None:
                location = 'No Location Found'
            else:
                location = location_elem.text.strip()
            #####################
            # Get the link for the page with the full job description
            link = job.find('a')['href']

            description_results = get_job_results(link, 'main-content')
            details_elem = description_results.findAll('div', class_='detail-row')
            salary = None
            job_type = None
            for detail in details_elem:
                dt = detail.text.strip()
                if 'Salary' in dt:
                    salary = dt
                if 'Job Type' in dt:
                    job_type = dt                    
                if posted is None and 'Posted' in dt:
                    posted = dt

            if salary is None:
                salary = 'No Salary Provided'
            if job_type is None:
                job_type = 'No Job Type Provided'
            

            description_elem = description_results.find('div', class_='job-description')
            if description_elem is None:
                description = 'No Description Found'
            else:
                description = description_elem.text.strip()
            
            item = [
                search_title,
                search_location,
                location,
                title,
                company,
                posted,
                salary,
                job_type,
                link,
                description
            ]
            jobs_monster.append(item)

# This adds the time for the final search.
search_time = time.time() - search_start
search_times_monster.append(search_time)

total_search_time_monster = time.time() - start_time

if ttm:
     print(f'Monster search took {total_search_time_monster} seconds to retreive {len(jobs_monster)} total results (including some duplicates).')

# Convert array of arrays into data frame
monster_0 = pd.DataFrame(jobs_monster, columns=columns)

# filter and modify df going forward
monster_1 = preprocess_jobs_recent(monster_0)

# Save the monitoring data into their respective csv's for later analysis.
# collect_individual_search_info saves into a new csv which monitors performance of each individual search
collect_individual_search_info('Monster', individual_searches, monster_0, monster_1, search_times_monster, total_search_time, 'Recent Jobs Only')
save_search_stats('Monster', len(monster_0), len(monster_1), total_search_time_monster, n_searches, 'Recent Jobs Only')

print(f'Returned {len(monster_1)} unique entries from Monster.com')
# Out:
#  seconds.
#
# Searching New Hampshire for macro analyst positions 	Search number 360 of 520
# The search took 6.927181959152222 seconds.
#
# Searching Pennsylvania for entry level business analyst positions 	Search number 361 of 520
# The search took 0.1592864990234375 seconds.
#
# Searching Pennsylvania for entry level data analyst positions 	Search number 362 of 520
# The search took 0.18192481994628906 seconds.
#
# Searching Pennsylvania for entry level data scientist positions 	Search number 363 of 520
# The search took 6.576783895492554 seconds.
#
# Searching Pennsylvania for entry level financial analyst positions 	Search number 364 of 520
# The search took 6.425246238708496 seconds.
#
# Searching Pennsylvania for entry level macro analyst positions 	Search number 365 of 520
# The search took 6.454071283340454 seconds.
#
# Searching Pennsylvania for junior business analyst positions 	Search number 366 of 520
# The search took 0.20774245262145996 seconds.
#
# Searching Pennsylvania for junior data analyst positions 	Search number 367 of 520
# The search took 0.20058417320251465 seconds.
#
# Searching Pennsylvania for junior data scientist positions 	Search number 368 of 520
# The search took 0.1471235752105713 seconds.
#
# Searching Pennsylvania for junior financial analyst positions 	Search number 369 of 520
# The search took 8.445784330368042 seconds.
#
# Searching Pennsylvania for junior macro analyst positions 	Search number 370 of 520
# The search took 6.249140501022339 seconds.
#
# Searching Pennsylvania for associate business analyst positions 	Search number 371 of 520
# The search took 0.32179999351501465 seconds.
#
# Searching Pennsylvania for associate data analyst positions 	Search number 372 of 520
# The search took 0.16687822341918945 seconds.
#
# Searching Pennsylvania for associate data scientist positions 	Search number 373 of 520
# The search took 0.16495156288146973 seconds.
#
# Searching Pennsylvania for associate financial analyst positions 	Search number 374 of 520
# The search took 0.1998457908630371 seconds.
#
# Searching Pennsylvania for associate macro analyst positions 	Search number 375 of 520
# The search took 6.261954307556152 seconds.
#
# Searching Pennsylvania for business analyst positions 	Search number 376 of 520
# The search took 2.200078010559082 seconds.
#
# Searching Pennsylvania for data analyst positions 	Search number 377 of 520
# The search took 2.2113521099090576 seconds.
#
# Searching Pennsylvania for data scientist positions 	Search number 378 of 520
# The search took 1.7637088298797607 seconds.
#
# Searching Pennsylvania for financial analyst positions 	Search number 379 of 520
# The search took 2.419407606124878 seconds.
#
# Searching Pennsylvania for macro analyst positions 	Search number 380 of 520
# The search took 0.19077825546264648 seconds.
#
# Searching Connecticut for entry level business analyst positions 	Search number 381 of 520
# The search took 6.997369050979614 seconds.
#
# Searching Connecticut for entry level data analyst positions 	Search number 382 of 520
# The search took 0.17589545249938965 seconds.
#
# Searching Connecticut for entry level data scientist positions 	Search number 383 of 520
# The search took 0.18335223197937012 seconds.
#
# Searching Connecticut for entry level financial analyst positions 	Search number 384 of 520
# The search took 0.19648265838623047 seconds.
#
# Searching Connecticut for entry level macro analyst positions 	Search number 385 of 520
# The search took 6.6896398067474365 seconds.
#
# Searching Connecticut for junior business analyst positions 	Search number 386 of 520
# The search took 6.252725601196289 seconds.
#
# Searching Connecticut for junior data analyst positions 	Search number 387 of 520
# The search took 0.1774895191192627 seconds.
#
# Searching Connecticut for junior data scientist positions 	Search number 388 of 520
# The search took 0.16399288177490234 seconds.
#
# Searching Connecticut for junior financial analyst positions 	Search number 389 of 520
# The search took 0.16103172302246094 seconds.
#
# Searching Connecticut for junior macro analyst positions 	Search number 390 of 520
# The search took 6.448688268661499 seconds.
#
# Searching Connecticut for associate business analyst positions 	Search number 391 of 520
# The search took 6.12411642074585 seconds.
#
# Searching Connecticut for associate data analyst positions 	Search number 392 of 520
# The search took 0.21327996253967285 seconds.
#
# Searching Connecticut for associate data scientist positions 	Search number 393 of 520
# The search took 0.4312272071838379 seconds.
#
# Searching Connecticut for associate financial analyst positions 	Search number 394 of 520
# The search took 0.17395615577697754 seconds.
#
# Searching Connecticut for associate macro analyst positions 	Search number 395 of 520
# The search took 0.16184592247009277 seconds.
#
# Searching Connecticut for business analyst positions 	Search number 396 of 520
# The search took 1.6670968532562256 seconds.
#
# Searching Connecticut for data analyst positions 	Search number 397 of 520
# The search took 2.7747459411621094 seconds.
#
# Searching Connecticut for data scientist positions 	Search number 398 of 520
# The search took 0.5616838932037354 seconds.
#
# Searching Connecticut for financial analyst positions 	Search number 399 of 520
# The search took 1.4769794940948486 seconds.
#
# Searching Connecticut for macro analyst positions 	Search number 400 of 520
# The search took 0.41544079780578613 seconds.
#
# Searching NY for entry level business analyst positions 	Search number 401 of 520
# The search took 0.17496776580810547 seconds.
#
# Searching NY for entry level data analyst positions 	Search number 402 of 520
# The search took 0.14107561111450195 seconds.
#
# Searching NY for entry level data scientist positions 	Search number 403 of 520
# The search took 0.1688215732574463 seconds.
#
# Searching NY for entry level financial analyst positions 	Search number 404 of 520
# The search took 0.22531652450561523 seconds.
#
# Searching NY for entry level macro analyst positions 	Search number 405 of 520
# The search took 7.052441120147705 seconds.
#
# Searching NY for junior business analyst positions 	Search number 406 of 520
# The search took 0.2143864631652832 seconds.
#
# Searching NY for junior data analyst positions 	Search number 407 of 520
# The search took 0.1590268611907959 seconds.
#
# Searching NY for junior data scientist positions 	Search number 408 of 520
# The search took 0.1558234691619873 seconds.
#
# Searching NY for junior financial analyst positions 	Search number 409 of 520
# The search took 0.14410734176635742 seconds.
#
# Searching NY for junior macro analyst positions 	Search number 410 of 520
# The search took 6.632943630218506 seconds.
#
# Searching NY for associate business analyst positions 	Search number 411 of 520
# The search took 0.16542434692382812 seconds.
#
# Searching NY for associate data analyst positions 	Search number 412 of 520
# The search took 0.4552128314971924 seconds.
#
# Searching NY for associate data scientist positions 	Search number 413 of 520
# The search took 2.0523264408111572 seconds.
#
# Searching NY for associate financial analyst positions 	Search number 414 of 520
# The search took 0.4490330219268799 seconds.
#
# Searching NY for associate macro analyst positions 	Search number 415 of 520
# The search took 6.2954065799713135 seconds.
#
# Searching NY for business analyst positions 	Search number 416 of 520
# The search took 2.6110262870788574 seconds.
#
# Searching NY for data analyst positions 	Search number 417 of 520
# The search took 3.199390172958374 seconds.
#
# Searching NY for data scientist positions 	Search number 418 of 520
# The search took 3.2646422386169434 seconds.
#
# Searching NY for financial analyst positions 	Search number 419 of 520
# The search took 3.4596776962280273 seconds.
#
# Searching NY for macro analyst positions 	Search number 420 of 520
# The search took 0.2119739055633545 seconds.
#
# Searching NJ for entry level business analyst positions 	Search number 421 of 520
# The search took 0.16817569732666016 seconds.
#
# Searching NJ for entry level data analyst positions 	Search number 422 of 520
# The search took 0.1852269172668457 seconds.
#
# Searching NJ for entry level data scientist positions 	Search number 423 of 520
# The search took 0.14455294609069824 seconds.
#
# Searching NJ for entry level financial analyst positions 	Search number 424 of 520
# The search took 0.16557717323303223 seconds.
#
# Searching NJ for entry level macro analyst positions 	Search number 425 of 520
# The search took 6.270460367202759 seconds.
#
# Searching NJ for junior business analyst positions 	Search number 426 of 520
# The search took 0.19970107078552246 seconds.
#
# Searching NJ for junior data analyst positions 	Search number 427 of 520
# The search took 0.2037515640258789 seconds.
#
# Searching NJ for junior data scientist positions 	Search number 428 of 520
# The search took 0.181504487991333 seconds.
#
# Searching NJ for junior financial analyst positions 	Search number 429 of 520
# The search took 0.19538331031799316 seconds.
#
# Searching NJ for junior macro analyst positions 	Search number 430 of 520
# The search took 6.301720857620239 seconds.
#
# Searching NJ for associate business analyst positions 	Search number 431 of 520
# The search took 0.1475205421447754 seconds.
#
# Searching NJ for associate data analyst positions 	Search number 432 of 520
# The search took 0.16729259490966797 seconds.
#
# Searching NJ for associate data scientist positions 	Search number 433 of 520
# The search took 0.4456937313079834 seconds.
#
# Searching NJ for associate financial analyst positions 	Search number 434 of 520
# The search took 0.1725919246673584 seconds.
#
# Searching NJ for associate macro analyst positions 	Search number 435 of 520
# The search took 6.510057210922241 seconds.
#
# Searching NJ for business analyst positions 	Search number 436 of 520
# The search took 2.604685068130493 seconds.
#
# Searching NJ for data analyst positions 	Search number 437 of 520
# The search took 2.746927499771118 seconds.
#
# Searching NJ for data scientist positions 	Search number 438 of 520
# The search took 2.376253604888916 seconds.
#
# Searching NJ for financial analyst positions 	Search number 439 of 520
# The search took 1.1444106101989746 seconds.
#
# Searching NJ for macro analyst positions 	Search number 440 of 520
# The search took 0.1943202018737793 seconds.
#
# Searching NH for entry level business analyst positions 	Search number 441 of 520
# The search took 6.291200399398804 seconds.
#
# Searching NH for entry level data analyst positions 	Search number 442 of 520
# The search took 0.1789863109588623 seconds.
#
# Searching NH for entry level data scientist positions 	Search number 443 of 520
# The search took 6.126746416091919 seconds.
#
# Searching NH for entry level financial analyst positions 	Search number 444 of 520
# The search took 6.011380672454834 seconds.
#
# Searching NH for entry level macro analyst positions 	Search number 445 of 520
# The search took 6.610105514526367 seconds.
#
# Searching NH for junior business analyst positions 	Search number 446 of 520
# The search took 6.107430696487427 seconds.
#
# Searching NH for junior data analyst positions 	Search number 447 of 520
# The search took 0.17580819129943848 seconds.
#
# Searching NH for junior data scientist positions 	Search number 448 of 520
# The search took 0.1761021614074707 seconds.
#
# Searching NH for junior financial analyst positions 	Search number 449 of 520
# The search took 6.022084712982178 seconds.
#
# Searching NH for junior macro analyst positions 	Search number 450 of 520
# The search took 6.3750762939453125 seconds.
#
# Searching NH for associate business analyst positions 	Search number 451 of 520
# The search took 0.20980215072631836 seconds.
#
# Searching NH for associate data analyst positions 	Search number 452 of 520
# The search took 0.15558171272277832 seconds.
#
# Searching NH for associate data scientist positions 	Search number 453 of 520
# The search took 0.6247358322143555 seconds.
#
# Searching NH for associate financial analyst positions 	Search number 454 of 520
# The search took 6.736403942108154 seconds.
#
# Searching NH for associate macro analyst positions 	Search number 455 of 520
# The search took 6.251435041427612 seconds.
#
# Searching NH for business analyst positions 	Search number 456 of 520
# The search took 0.15970325469970703 seconds.
#
# Searching NH for data analyst positions 	Search number 457 of 520
# The search took 0.30019497871398926 seconds.
#
# Searching NH for data scientist positions 	Search number 458 of 520
# The search took 0.16673707962036133 seconds.
#
# Searching NH for financial analyst positions 	Search number 459 of 520
# The search took 0.21578049659729004 seconds.
#
# Searching NH for macro analyst positions 	Search number 460 of 520
# The search took 6.379571199417114 seconds.
#
# Searching PA for entry level business analyst positions 	Search number 461 of 520
# The search took 0.17554378509521484 seconds.
#
# Searching PA for entry level data analyst positions 	Search number 462 of 520
# The search took 0.2051534652709961 seconds.
#
# Searching PA for entry level data scientist positions 	Search number 463 of 520
# The search took 6.293412685394287 seconds.
#
# Searching PA for entry level financial analyst positions 	Search number 464 of 520
# The search took 5.871964693069458 seconds.
#
# Searching PA for entry level macro analyst positions 	Search number 465 of 520
# The search took 6.09401273727417 seconds.
#
# Searching PA for junior business analyst positions 	Search number 466 of 520
# The search took 0.20340561866760254 seconds.
#
# Searching PA for junior data analyst positions 	Search number 467 of 520
# The search took 0.15109729766845703 seconds.
#
# Searching PA for junior data scientist positions 	Search number 468 of 520
# The search took 0.16811919212341309 seconds.
#
# Searching PA for junior financial analyst positions 	Search number 469 of 520
# The search took 6.487248659133911 seconds.
#
# Searching PA for junior macro analyst positions 	Search number 470 of 520
# The search took 7.4650719165802 seconds.
#
# Searching PA for associate business analyst positions 	Search number 471 of 520
# The search took 0.17871427536010742 seconds.
#
# Searching PA for associate data analyst positions 	Search number 472 of 520
# The search took 0.17919087409973145 seconds.
#
# Searching PA for associate data scientist positions 	Search number 473 of 520
# The search took 0.20006871223449707 seconds.
#
# Searching PA for associate financial analyst positions 	Search number 474 of 520
# The search took 0.17493104934692383 seconds.
#
# Searching PA for associate macro analyst positions 	Search number 475 of 520
# The search took 6.032707214355469 seconds.
#
# Searching PA for business analyst positions 	Search number 476 of 520
# The search took 2.123530387878418 seconds.
#
# Searching PA for data analyst positions 	Search number 477 of 520
# The search took 2.4481875896453857 seconds.
#
# Searching PA for data scientist positions 	Search number 478 of 520
# The search took 1.509101152420044 seconds.
#
# Searching PA for financial analyst positions 	Search number 479 of 520
# The search took 2.3206136226654053 seconds.
#
# Searching PA for macro analyst positions 	Search number 480 of 520
# The search took 0.19242000579833984 seconds.
#
# Searching CT for entry level business analyst positions 	Search number 481 of 520
# The search took 6.095870733261108 seconds.
#
# Searching CT for entry level data analyst positions 	Search number 482 of 520
# The search took 0.16954874992370605 seconds.
#
# Searching CT for entry level data scientist positions 	Search number 483 of 520
# The search took 0.14833378791809082 seconds.
#
# Searching CT for entry level financial analyst positions 	Search number 484 of 520
# The search took 0.15546774864196777 seconds.
#
# Searching CT for entry level macro analyst positions 	Search number 485 of 520
# The search took 6.543101787567139 seconds.
#
# Searching CT for junior business analyst positions 	Search number 486 of 520
# The search took 6.835708379745483 seconds.
#
# Searching CT for junior data analyst positions 	Search number 487 of 520
# The search took 0.19757866859436035 seconds.
#
# Searching CT for junior data scientist positions 	Search number 488 of 520
# The search took 0.14829373359680176 seconds.
#
# Searching CT for junior financial analyst positions 	Search number 489 of 520
# The search took 0.1819908618927002 seconds.
#
# Searching CT for junior macro analyst positions 	Search number 490 of 520
# The search took 5.968871355056763 seconds.
#
# Searching CT for associate business analyst positions 	Search number 491 of 520
# The search took 6.4251649379730225 seconds.
#
# Searching CT for associate data analyst positions 	Search number 492 of 520
# The search took 0.14349031448364258 seconds.
#
# Searching CT for associate data scientist positions 	Search number 493 of 520
# The search took 0.379641056060791 seconds.
#
# Searching CT for associate financial analyst positions 	Search number 494 of 520
# The search took 0.15861010551452637 seconds.
#
# Searching CT for associate macro analyst positions 	Search number 495 of 520
# The search took 0.13125205039978027 seconds.
#
# Searching CT for business analyst positions 	Search number 496 of 520
# The search took 1.687638521194458 seconds.
#
# Searching CT for data analyst positions 	Search number 497 of 520
# The search took 2.1332714557647705 seconds.
#
# Searching CT for data scientist positions 	Search number 498 of 520
# The search took 0.6729898452758789 seconds.
#
# Searching CT for financial analyst positions 	Search number 499 of 520
# The search took 1.0449068546295166 seconds.
#
# Searching CT for macro analyst positions 	Search number 500 of 520
# The search took 0.4512495994567871 seconds.
#
# Searching remote for entry level business analyst positions 	Search number 501 of 520
# The search took 0.13741660118103027 seconds.
#
# Searching remote for entry level data analyst positions 	Search number 502 of 520
# The search took 0.16909456253051758 seconds.
#
# Searching remote for entry level data scientist positions 	Search number 503 of 520
# The search took 5.910064220428467 seconds.
#
# Searching remote for entry level financial analyst positions 	Search number 504 of 520
# The search took 6.170367479324341 seconds.
#
# Searching remote for entry level macro analyst positions 	Search number 505 of 520
# The search took 6.673526287078857 seconds.
#
# Searching remote for junior business analyst positions 	Search number 506 of 520
# The search took 0.24423527717590332 seconds.
#
# Searching remote for junior data analyst positions 	Search number 507 of 520
# The search took 0.17595624923706055 seconds.
#
# Searching remote for junior data scientist positions 	Search number 508 of 520
# The search took 6.545456886291504 seconds.
#
# Searching remote for junior financial analyst positions 	Search number 509 of 520
# The search took 5.891579627990723 seconds.
#
# Searching remote for junior macro analyst positions 	Search number 510 of 520
# The search took 5.99273157119751 seconds.
#
# Searching remote for associate business analyst positions 	Search number 511 of 520
# The search took 6.707318067550659 seconds.
#
# Searching remote for associate data analyst positions 	Search number 512 of 520
# The search took 6.624595880508423 seconds.
#
# Searching remote for associate data scientist positions 	Search number 513 of 520
# The search took 0.1660935878753662 seconds.
#
# Searching remote for associate financial analyst positions 	Search number 514 of 520
# The search took 6.1798131465911865 seconds.
#
# Searching remote for associate macro analyst positions 	Search number 515 of 520
# The search took 6.462059497833252 seconds.
#
# Searching remote for business analyst positions 	Search number 516 of 520
# The search took 1.2390854358673096 seconds.
#
# Searching remote for data analyst positions 	Search number 517 of 520
# The search took 0.64388108253479 seconds.
#
# Searching remote for data scientist positions 	Search number 518 of 520
# The search took 1.0209269523620605 seconds.
#
# Searching remote for financial analyst positions 	Search number 519 of 520
# The search took 0.49991917610168457 seconds.
#
# Searching remote for macro analyst positions 	Search number 520 of 520
# Monster search took 1022.9396865367889 seconds to retreive 10751 total results (including some duplicates).
# Returned 138 unique entries from Monster.com

# %%
df_0 = pd.concat([indeed_1, monster_1], ignore_index=True)
df_1 = df_0.drop_duplicates(subset=['description'])
# df = PreprocessJobs(df)
print('Both pre duplicate removal:', len(df_0), '\n', 'Post duplicate removal:', len(df_1))

df = df_1
# Out:
# Both pre duplicate removal: 204
#  Post duplicate removal: 177

# %%
df['description'] = df['description'].str.replace(',', ' ')

# %%
df.to_csv('data/' + datetime.today().strftime("%Y-%m-%d") + '_recentjobs.tsv', sep='\t', index=False)
