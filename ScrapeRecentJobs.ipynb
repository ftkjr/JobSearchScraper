# %%
# Import Packages 
import csv
from datetime import *
import numpy
import math
import requests
from bs4 import BeautifulSoup
import pandas as pd
import time
import re
from nltk import *
from nltk.collocations import BigramCollocationFinder, TrigramCollocationFinder
from nltk.metrics import BigramAssocMeasures, TrigramAssocMeasures
from nltk.corpus import stopwords

# %%
def get_job_results(url: str, info_id: str) -> list:
    """"Return page results from job site"""
    page = requests.get(url)
    soup = BeautifulSoup(page.content, 'html.parser')
    results = soup.find(id=info_id) 
    return results

def collect_individual_search_info(site: str, individual_searches: list, total_results_frame, unique_results_frame, search_times: list, total_search_time: float, notes:str = None):
    """Return individual search info as one DataFrame"""
    # Create framework for the individual search data. 
    individual_searches_frame = pd.DataFrame(individual_searches, columns=['search_location', 'search_title'])
    individual_searches_frame['SearchTimes'] = search_times
    individual_searches_frame['Site'] = site
    individual_searches_frame['Date'] = datetime.now().strftime("%Y-%m-%d %H:%M:%S")

    # Collect the counts for the results before removing duplicates.
    total_results = total_results_frame[['search_title', 'search_location', 'description']].groupby(['search_title', 'search_location'], as_index=False).count()

    # Collect the counts for the results after removing duplicates.
    unique_results = unique_results_frame[['search_title', 'search_location', 'description']].groupby(['search_title', 'search_location'], as_index=False).count()

    # Add the Total Results count to the individual searches frame.
    individual_searches_frame = pd.merge(
        individual_searches_frame, 
        pd.DataFrame({
            'search_title': total_results['search_title'], 
            'search_location': total_results['search_location'], 
            'TotalResults': total_results['description']
            }),
        on=['search_title', 'search_location'], 
        how='left'
        )

    # Add the Unique Results count to the individual searches frame.
    individual_searches_frame = pd.merge(
        individual_searches_frame, 
        pd.DataFrame({
            'search_title': unique_results['search_title'], 
            'search_location': unique_results['search_location'], 
            'UniqueResults': unique_results['description']
            }),
            on=['search_title', 'search_location'], 
            how='left'
            )
    
    # Where we didn't have a results count we must not have found anything, so replace the NaN with a 0.
    for col in ['TotalResults', 'UniqueResults']:
        individual_searches_frame[col][individual_searches_frame[col].isnull()] = 0

    # Add the total search time to the data frame.
    individual_searches_frame['TotalSearchTime'] = total_search_time
    # Add any notes we have to the frame.
    individual_searches_frame['Notes'] = notes
    individual_searches_frame.to_csv('Diagnostics/ScraperPerformancebySearch.csv', mode='a', header=False)
  

def preprocess_jobs_recent(initial_data):
    """Clean up the jobs frame"""
    for col in [col for col in indeed_0.columns if col is not 'posted']:
        initial_data[col] = initial_data[col].str.replace('\n', ' ')
    processed_data = initial_data.drop_duplicates(subset=['link'], keep='first')
    processed_data['description'] = processed_data['description'].str.replace(r"([a-z])([A-Z])", r"\1 \.\2")
    processed_data['description'] = processed_data['description'].str.replace(r' \\.', '')
    return processed_data


    
def save_search_stats(site: str, total_returned_jobs: int, unique_jobs: int, search_time: float, total_searches: int, notes: str):
    """Write search statistics as new row in ScraperPerformance.csv"""
    with open('Diagnostics/ScraperPerformance.csv', 'a+', newline='') as file:
        write = csv.writer(file, delimiter=',')
        notes = notes.replace(',', ';')
        write.writerow([site, total_returned_jobs, unique_jobs, search_time, total_searches, date.today(), notes])

# %%
####################
# Data Frame Columns
columns = [
    'search_title', 'search_location', 'location', 'title', 'company', 'posted', 'salary', 'summary', 'link', 'description'
    ]

###############
# Job titles
prefixes = [
    'entry level ', 
    'junior ', 
    'associate ', 
    ''
    ]
titles = [
    'data', 
    'data analyst', 'data scientist',
    # 'data engineer',
    # 'business analyst', 
    'financial analyst', 
    # 'macro analyst'
    ]

################
# Job Locations
search_locations = [
    'New York, NY',
    'Newark, NJ', 
    'Princeton, NJ', 'Jersey City, NJ', 'Trenton, NJ', 
    'Bridgewater, NJ', 'Somerville, NJ', 'Summit, NJ', 
    'Morristown, NJ', 'Edison, NJ', 'Metuchen, NJ', 
    'Hackensack, NJ',
    # 'Philadelphia, PA', 
    'Stamford, CT', 'Greenwich, CT',
    # 'New York', 'New Jersey', 'New Hampshire', 'Pennsylvania', 'Connecticut',
    # 'NY', 'NJ', 'NH', 'PA', 'CT',
    'remote'
    ]


n_searches = (len(titles) * len(prefixes)) * len(search_locations)

# %%
posted_date_cutoff = 5
# posted_date_cutoff = input('What is our date cutoff for finding jobs? ')

# %% [markdown]
# # Indeed

# %%
################################
################################
#### Scrape Indeed for Jobs ####
################# ###############
################################

# Four Fors: Because who needs a head hunter anyways?
# 1. Search each location
#   2. Search each job title
#       3. Search each page of results 
#           4. Get each job's description
# nlocations * ntitles * npages * njobdescriptions = niterations
# 
# NOTE We sleep before hitting the page because if we over do it they won't give us the data
# 

#######################
# Change these fields #
#######################

#######################
# URL Fields
# How many pages per locale
location_results = 100
# How far out should we look?
radius = 50



########################
# Performance Monitors #
########################
search_times_indeed = []
individual_searches = []

# Initialize these for performance monitoring
ttm = True
start_time = time.time()
counter = 1

# Array of jobs
jobs_indeed = []

# Main two iterators for the search, 
for search_location in search_locations: 
    for search_title in [(s + t) for s in prefixes for t in titles]:

       ####################################
        # Monitoring Chunk
        individual_searches.append([search_location, search_title])
        if counter > 1: 
            search_time = time.time() - search_start
            search_times_indeed.append(search_time)
            if ttm:
                print(f'The search took {search_time} seconds.\n')
        if ttm:
            print(f'Searching {search_location} for {search_title} positions \tSearch number {counter} of {n_searches}') 
        counter += 1
        search_start = time.time()
        #####################################

        for nresults in range(0, location_results, 10):            
            # Go to the url below and get the results from each page
            s = search_location.replace(' ', '%20').replace(',', '%2C')
            st = search_title.replace(' ', '%20')
            url = f'https://www.indeed.com/jobs?q={st}+%2420%2C000&l={s}+&radius={radius}&start={str(nresults)}'
            try:
                results = get_job_results(url, 'resultsCol')
            except:
                continue
            # If we have run out of postings move on
            if results is None:
                continue
            job_elems = results.find_all('div', class_='jobsearch-SerpJobCard')
            
            ##############################
            # FIND THE MOST RECENT JOB POSTS!!! 
            for job in job_elems:
                # Make sure it's a valid post
                title_elem = job.find('h2', class_='title')
                if title_elem is None:  
                    continue
                else:
                    title = title_elem.text.strip()
                
                # If it was posted over our limit we don't want it
                when_elem = job.find('span', class_='date').text.strip()
                if (when_elem[0] == "T") | (when_elem[0] == "J"):
                    when_elem = 0
                elif when_elem[0] == "+":
                    continue
                elif pd.to_numeric(when_elem[:2]) > posted_date_cutoff:
                    continue
                else:
                    when_elem = pd.to_numeric(when_elem[:2])

                # Company:
                company_elem = job.find('span', class_='company')
                if company_elem is None:
                    continue
                else:
                    company_elem = company_elem.text.strip()


                #########################
                #   Location: Where is the job
                #   Salary: How much are they paying
                #   Summary: What's the provided job summary
                location_elem = job.find('span', class_='location')
                salary_elem = job.find('span', class_='salary')
                summary_elem = job.find('div', class_='summary')
                 
                
                # If there isn't a location provided, denote that
                if location_elem is not None:
                    location_elem = location_elem.text.strip()

                # If there isn't a salary provided, denote that
                if salary_elem is not None:
                    salary_elem = salary_elem.text.strip()
                
                 # If there isn't a job summary provided, denote that
                if summary_elem is not None:
                    summary_elem = summary_elem.text.strip()


                ##################################
                # Go to the Job Description Page #
                ##################################
                # Wait {sleep_time} seconds before hitting the page so they don't kick us out
                # 
                time.sleep(2)
                link = job.find('a')['href']
                description_url = f'https://www.indeed.com{link}'
                try:
                    description_results = get_job_results(description_url, 'jobDescriptionText')
                except:
                    continue
                # If we screwed up locating the description, denote that
                if description_results is not None:
                    description_text = description_results.text.strip()

                # Create an array of info for this job posting
                info = [
                    search_title,
                    search_location,
                    location_elem, 
                    title,
                    company_elem,
                    when_elem,
                    salary_elem,
                    summary_elem,
                    description_url,
                    description_text
                ]

                # Append the job info array to the array of job posting arrays
                jobs_indeed.append(info)

# This adds the time for the final search.
search_time = time.time() - search_start
search_times_indeed.append(search_time)

# Calculate the total search time.
total_search_time = time.time() - start_time

if ttm:
     print(f'Indeed search completed in {total_search_time} seconds. {len(jobs_indeed)} results found (including duplicates).') 

# Convert the array of job arrays into a data frame.
indeed_0 = pd.DataFrame(jobs_indeed, columns=columns)

# Save raw data just in case
indeed_0.to_csv('data/0rawdata/' + datetime.today().strftime("%Y-%m-%d") + '_indeed.csv', index=False)

# Filter and modify the original and put it in a new variable.
indeed_1 = preprocess_jobs_recent(indeed_0)

# Save the monitoring data into their respective csv's for later analysis.
# collect_individual_search_info saves into a new csv which monitors performance of each individual search
# collect_individual_search_info('Indeed', individual_searches, indeed_0, indeed_1, search_times_indeed, total_search_time, 'Recent Jobs Only')
# save_search_stats('Indeed', len(jobs_indeed), len(indeed_1), total_search_time, n_searches, 'Recent Jobs Only')

# Tell us when we're done!
print(f'Returned {len(indeed_1)} unique entries from Indeed.')
# Out:
# rch number 84 of 240
# The search took 5.100890398025513 seconds.
#
# Searching Bridgewater, NJ for junior data positions 	Search number 85 of 240
# The search took 2.7008955478668213 seconds.
#
# Searching Bridgewater, NJ for junior data analyst positions 	Search number 86 of 240
# The search took 2.626526117324829 seconds.
#
# Searching Bridgewater, NJ for junior data scientist positions 	Search number 87 of 240
# The search took 2.8299527168273926 seconds.
#
# Searching Bridgewater, NJ for junior financial analyst positions 	Search number 88 of 240
# The search took 2.9917516708374023 seconds.
#
# Searching Bridgewater, NJ for associate data positions 	Search number 89 of 240
# The search took 3.179213285446167 seconds.
#
# Searching Bridgewater, NJ for associate data analyst positions 	Search number 90 of 240
# The search took 2.7341156005859375 seconds.
#
# Searching Bridgewater, NJ for associate data scientist positions 	Search number 91 of 240
# The search took 2.629298210144043 seconds.
#
# Searching Bridgewater, NJ for associate financial analyst positions 	Search number 92 of 240
# The search took 2.9903347492218018 seconds.
#
# Searching Bridgewater, NJ for data positions 	Search number 93 of 240
# The search took 2.9296517372131348 seconds.
#
# Searching Bridgewater, NJ for data analyst positions 	Search number 94 of 240
# The search took 2.7837677001953125 seconds.
#
# Searching Bridgewater, NJ for data scientist positions 	Search number 95 of 240
# The search took 2.5326175689697266 seconds.
#
# Searching Bridgewater, NJ for financial analyst positions 	Search number 96 of 240
# The search took 2.871649742126465 seconds.
#
# Searching Somerville, NJ for entry level data positions 	Search number 97 of 240
# The search took 2.2900748252868652 seconds.
#
# Searching Somerville, NJ for entry level data analyst positions 	Search number 98 of 240
# The search took 29.05959415435791 seconds.
#
# Searching Somerville, NJ for entry level data scientist positions 	Search number 99 of 240
# The search took 2.4796981811523438 seconds.
#
# Searching Somerville, NJ for entry level financial analyst positions 	Search number 100 of 240
# The search took 2.4999008178710938 seconds.
#
# Searching Somerville, NJ for junior data positions 	Search number 101 of 240
# The search took 2.5374915599823 seconds.
#
# Searching Somerville, NJ for junior data analyst positions 	Search number 102 of 240
# The search took 2.2694272994995117 seconds.
#
# Searching Somerville, NJ for junior data scientist positions 	Search number 103 of 240
# The search took 2.360750913619995 seconds.
#
# Searching Somerville, NJ for junior financial analyst positions 	Search number 104 of 240
# The search took 2.422600746154785 seconds.
#
# Searching Somerville, NJ for associate data positions 	Search number 105 of 240
# The search took 2.393096446990967 seconds.
#
# Searching Somerville, NJ for associate data analyst positions 	Search number 106 of 240
# The search took 2.7284493446350098 seconds.
#
# Searching Somerville, NJ for associate data scientist positions 	Search number 107 of 240
# The search took 3.610323429107666 seconds.
#
# Searching Somerville, NJ for associate financial analyst positions 	Search number 108 of 240
# The search took 4.104022026062012 seconds.
#
# Searching Somerville, NJ for data positions 	Search number 109 of 240
# The search took 2.644176483154297 seconds.
#
# Searching Somerville, NJ for data analyst positions 	Search number 110 of 240
# The search took 2.4291861057281494 seconds.
#
# Searching Somerville, NJ for data scientist positions 	Search number 111 of 240
# The search took 2.804182529449463 seconds.
#
# Searching Somerville, NJ for financial analyst positions 	Search number 112 of 240
# The search took 2.237757921218872 seconds.
#
# Searching Summit, NJ for entry level data positions 	Search number 113 of 240
# The search took 2.8097238540649414 seconds.
#
# Searching Summit, NJ for entry level data analyst positions 	Search number 114 of 240
# The search took 3.9670662879943848 seconds.
#
# Searching Summit, NJ for entry level data scientist positions 	Search number 115 of 240
# The search took 4.2346601486206055 seconds.
#
# Searching Summit, NJ for entry level financial analyst positions 	Search number 116 of 240
# The search took 3.210437059402466 seconds.
#
# Searching Summit, NJ for junior data positions 	Search number 117 of 240
# The search took 3.0665054321289062 seconds.
#
# Searching Summit, NJ for junior data analyst positions 	Search number 118 of 240
# The search took 3.2681829929351807 seconds.
#
# Searching Summit, NJ for junior data scientist positions 	Search number 119 of 240
# The search took 2.7697207927703857 seconds.
#
# Searching Summit, NJ for junior financial analyst positions 	Search number 120 of 240
# The search took 2.341094732284546 seconds.
#
# Searching Summit, NJ for associate data positions 	Search number 121 of 240
# The search took 2.3995282649993896 seconds.
#
# Searching Summit, NJ for associate data analyst positions 	Search number 122 of 240
# The search took 2.3762567043304443 seconds.
#
# Searching Summit, NJ for associate data scientist positions 	Search number 123 of 240
# The search took 2.3693017959594727 seconds.
#
# Searching Summit, NJ for associate financial analyst positions 	Search number 124 of 240
# The search took 2.811509132385254 seconds.
#
# Searching Summit, NJ for data positions 	Search number 125 of 240
# The search took 3.451023817062378 seconds.
#
# Searching Summit, NJ for data analyst positions 	Search number 126 of 240
# The search took 5.001437664031982 seconds.
#
# Searching Summit, NJ for data scientist positions 	Search number 127 of 240
# The search took 3.960602283477783 seconds.
#
# Searching Summit, NJ for financial analyst positions 	Search number 128 of 240
# The search took 4.87314248085022 seconds.
#
# Searching Morristown, NJ for entry level data positions 	Search number 129 of 240
# The search took 3.5981929302215576 seconds.
#
# Searching Morristown, NJ for entry level data analyst positions 	Search number 130 of 240
# The search took 4.878819227218628 seconds.
#
# Searching Morristown, NJ for entry level data scientist positions 	Search number 131 of 240
# The search took 4.176565408706665 seconds.
#
# Searching Morristown, NJ for entry level financial analyst positions 	Search number 132 of 240
# The search took 3.4975054264068604 seconds.
#
# Searching Morristown, NJ for junior data positions 	Search number 133 of 240
# The search took 3.2430384159088135 seconds.
#
# Searching Morristown, NJ for junior data analyst positions 	Search number 134 of 240
# The search took 2.87287974357605 seconds.
#
# Searching Morristown, NJ for junior data scientist positions 	Search number 135 of 240
# The search took 3.0448496341705322 seconds.
#
# Searching Morristown, NJ for junior financial analyst positions 	Search number 136 of 240
# The search took 3.468259572982788 seconds.
#
# Searching Morristown, NJ for associate data positions 	Search number 137 of 240
# The search took 2.98803973197937 seconds.
#
# Searching Morristown, NJ for associate data analyst positions 	Search number 138 of 240
# The search took 3.0857033729553223 seconds.
#
# Searching Morristown, NJ for associate data scientist positions 	Search number 139 of 240
# The search took 3.4163830280303955 seconds.
#
# Searching Morristown, NJ for associate financial analyst positions 	Search number 140 of 240
# The search took 4.571077823638916 seconds.
#
# Searching Morristown, NJ for data positions 	Search number 141 of 240
# The search took 3.955427408218384 seconds.
#
# Searching Morristown, NJ for data analyst positions 	Search number 142 of 240
# The search took 3.647264003753662 seconds.
#
# Searching Morristown, NJ for data scientist positions 	Search number 143 of 240
# The search took 3.479818820953369 seconds.
#
# Searching Morristown, NJ for financial analyst positions 	Search number 144 of 240
# The search took 2.8664371967315674 seconds.
#
# Searching Edison, NJ for entry level data positions 	Search number 145 of 240
# The search took 3.1458866596221924 seconds.
#
# Searching Edison, NJ for entry level data analyst positions 	Search number 146 of 240
# The search took 3.4094550609588623 seconds.
#
# Searching Edison, NJ for entry level data scientist positions 	Search number 147 of 240
# The search took 3.5086989402770996 seconds.
#
# Searching Edison, NJ for entry level financial analyst positions 	Search number 148 of 240
# The search took 2.983158826828003 seconds.
#
# Searching Edison, NJ for junior data positions 	Search number 149 of 240
# The search took 2.707122802734375 seconds.
#
# Searching Edison, NJ for junior data analyst positions 	Search number 150 of 240
# The search took 3.1098856925964355 seconds.
#
# Searching Edison, NJ for junior data scientist positions 	Search number 151 of 240
# The search took 3.157762050628662 seconds.
#
# Searching Edison, NJ for junior financial analyst positions 	Search number 152 of 240
# The search took 2.7525393962860107 seconds.
#
# Searching Edison, NJ for associate data positions 	Search number 153 of 240
# The search took 2.46047043800354 seconds.
#
# Searching Edison, NJ for associate data analyst positions 	Search number 154 of 240
# The search took 2.540527820587158 seconds.
#
# Searching Edison, NJ for associate data scientist positions 	Search number 155 of 240
# The search took 3.2592413425445557 seconds.
#
# Searching Edison, NJ for associate financial analyst positions 	Search number 156 of 240
# The search took 3.170708656311035 seconds.
#
# Searching Edison, NJ for data positions 	Search number 157 of 240
# The search took 3.0999410152435303 seconds.
#
# Searching Edison, NJ for data analyst positions 	Search number 158 of 240
# The search took 2.9961607456207275 seconds.
#
# Searching Edison, NJ for data scientist positions 	Search number 159 of 240
# The search took 3.0602548122406006 seconds.
#
# Searching Edison, NJ for financial analyst positions 	Search number 160 of 240
# The search took 3.017040491104126 seconds.
#
# Searching Metuchen, NJ for entry level data positions 	Search number 161 of 240
# The search took 3.187344789505005 seconds.
#
# Searching Metuchen, NJ for entry level data analyst positions 	Search number 162 of 240
# The search took 3.0819509029388428 seconds.
#
# Searching Metuchen, NJ for entry level data scientist positions 	Search number 163 of 240
# The search took 3.1499204635620117 seconds.
#
# Searching Metuchen, NJ for entry level financial analyst positions 	Search number 164 of 240
# The search took 2.991762399673462 seconds.
#
# Searching Metuchen, NJ for junior data positions 	Search number 165 of 240
# The search took 3.020378589630127 seconds.
#
# Searching Metuchen, NJ for junior data analyst positions 	Search number 166 of 240
# The search took 3.1825592517852783 seconds.
#
# Searching Metuchen, NJ for junior data scientist positions 	Search number 167 of 240
# The search took 3.218258857727051 seconds.
#
# Searching Metuchen, NJ for junior financial analyst positions 	Search number 168 of 240
# The search took 3.150554656982422 seconds.
#
# Searching Metuchen, NJ for associate data positions 	Search number 169 of 240
# The search took 3.374598503112793 seconds.
#
# Searching Metuchen, NJ for associate data analyst positions 	Search number 170 of 240
# The search took 3.551270008087158 seconds.
#
# Searching Metuchen, NJ for associate data scientist positions 	Search number 171 of 240
# The search took 3.800337553024292 seconds.
#
# Searching Metuchen, NJ for associate financial analyst positions 	Search number 172 of 240
# The search took 3.5092058181762695 seconds.
#
# Searching Metuchen, NJ for data positions 	Search number 173 of 240
# The search took 3.457444190979004 seconds.
#
# Searching Metuchen, NJ for data analyst positions 	Search number 174 of 240
# The search took 2.9605345726013184 seconds.
#
# Searching Metuchen, NJ for data scientist positions 	Search number 175 of 240
# The search took 3.3166139125823975 seconds.
#
# Searching Metuchen, NJ for financial analyst positions 	Search number 176 of 240
# The search took 2.690333366394043 seconds.
#
# Searching Hackensack, NJ for entry level data positions 	Search number 177 of 240
# The search took 2.404360771179199 seconds.
#
# Searching Hackensack, NJ for entry level data analyst positions 	Search number 178 of 240
# The search took 2.70375919342041 seconds.
#
# Searching Hackensack, NJ for entry level data scientist positions 	Search number 179 of 240
# The search took 2.6371777057647705 seconds.
#
# Searching Hackensack, NJ for entry level financial analyst positions 	Search number 180 of 240
# The search took 3.1754748821258545 seconds.
#
# Searching Hackensack, NJ for junior data positions 	Search number 181 of 240
# The search took 2.781564235687256 seconds.
#
# Searching Hackensack, NJ for junior data analyst positions 	Search number 182 of 240
# The search took 2.4872682094573975 seconds.
#
# Searching Hackensack, NJ for junior data scientist positions 	Search number 183 of 240
# The search took 2.7419869899749756 seconds.
#
# Searching Hackensack, NJ for junior financial analyst positions 	Search number 184 of 240
# The search took 2.849231719970703 seconds.
#
# Searching Hackensack, NJ for associate data positions 	Search number 185 of 240
# The search took 2.9979541301727295 seconds.
#
# Searching Hackensack, NJ for associate data analyst positions 	Search number 186 of 240
# The search took 3.104218006134033 seconds.
#
# Searching Hackensack, NJ for associate data scientist positions 	Search number 187 of 240
# The search took 2.8330132961273193 seconds.
#
# Searching Hackensack, NJ for associate financial analyst positions 	Search number 188 of 240
# The search took 2.9267570972442627 seconds.
#
# Searching Hackensack, NJ for data positions 	Search number 189 of 240
# The search took 2.867485761642456 seconds.
#
# Searching Hackensack, NJ for data analyst positions 	Search number 190 of 240
# The search took 2.553161382675171 seconds.
#
# Searching Hackensack, NJ for data scientist positions 	Search number 191 of 240
# The search took 3.4023420810699463 seconds.
#
# Searching Hackensack, NJ for financial analyst positions 	Search number 192 of 240
# The search took 2.3185226917266846 seconds.
#
# Searching Stamford, CT for entry level data positions 	Search number 193 of 240
# The search took 2.684311628341675 seconds.
#
# Searching Stamford, CT for entry level data analyst positions 	Search number 194 of 240
# The search took 2.3771347999572754 seconds.
#
# Searching Stamford, CT for entry level data scientist positions 	Search number 195 of 240
# The search took 2.7125070095062256 seconds.
#
# Searching Stamford, CT for entry level financial analyst positions 	Search number 196 of 240
# The search took 3.730677366256714 seconds.
#
# Searching Stamford, CT for junior data positions 	Search number 197 of 240
# The search took 2.9831666946411133 seconds.
#
# Searching Stamford, CT for junior data analyst positions 	Search number 198 of 240
# The search took 2.2908706665039062 seconds.
#
# Searching Stamford, CT for junior data scientist positions 	Search number 199 of 240
# The search took 2.292451858520508 seconds.
#
# Searching Stamford, CT for junior financial analyst positions 	Search number 200 of 240
# The search took 2.2568063735961914 seconds.
#
# Searching Stamford, CT for associate data positions 	Search number 201 of 240
# The search took 10.465900659561157 seconds.
#
# Searching Stamford, CT for associate data analyst positions 	Search number 202 of 240
# The search took 2.4131877422332764 seconds.
#
# Searching Stamford, CT for associate data scientist positions 	Search number 203 of 240
# The search took 2.5967793464660645 seconds.
#
# Searching Stamford, CT for associate financial analyst positions 	Search number 204 of 240
# The search took 2.9199981689453125 seconds.
#
# Searching Stamford, CT for data positions 	Search number 205 of 240
# The search took 2.3137378692626953 seconds.
#
# Searching Stamford, CT for data analyst positions 	Search number 206 of 240
# The search took 2.348618984222412 seconds.
#
# Searching Stamford, CT for data scientist positions 	Search number 207 of 240
# The search took 2.1114988327026367 seconds.
#
# Searching Stamford, CT for financial analyst positions 	Search number 208 of 240
# The search took 2.457974672317505 seconds.
#
# Searching Greenwich, CT for entry level data positions 	Search number 209 of 240
# The search took 2.2909929752349854 seconds.
#
# Searching Greenwich, CT for entry level data analyst positions 	Search number 210 of 240
# The search took 2.251189708709717 seconds.
#
# Searching Greenwich, CT for entry level data scientist positions 	Search number 211 of 240
# The search took 2.6226112842559814 seconds.
#
# Searching Greenwich, CT for entry level financial analyst positions 	Search number 212 of 240
# The search took 2.4754061698913574 seconds.
#
# Searching Greenwich, CT for junior data positions 	Search number 213 of 240
# The search took 2.3939969539642334 seconds.
#
# Searching Greenwich, CT for junior data analyst positions 	Search number 214 of 240
# The search took 2.783508062362671 seconds.
#
# Searching Greenwich, CT for junior data scientist positions 	Search number 215 of 240
# The search took 2.219775915145874 seconds.
#
# Searching Greenwich, CT for junior financial analyst positions 	Search number 216 of 240
# The search took 2.8542871475219727 seconds.
#
# Searching Greenwich, CT for associate data positions 	Search number 217 of 240
# The search took 2.9250662326812744 seconds.
#
# Searching Greenwich, CT for associate data analyst positions 	Search number 218 of 240
# The search took 3.0698037147521973 seconds.
#
# Searching Greenwich, CT for associate data scientist positions 	Search number 219 of 240
# The search took 3.358116626739502 seconds.
#
# Searching Greenwich, CT for associate financial analyst positions 	Search number 220 of 240
# The search took 2.836066722869873 seconds.
#
# Searching Greenwich, CT for data positions 	Search number 221 of 240
# The search took 3.5231447219848633 seconds.
#
# Searching Greenwich, CT for data analyst positions 	Search number 222 of 240
# The search took 5.293894052505493 seconds.
#
# Searching Greenwich, CT for data scientist positions 	Search number 223 of 240
# The search took 3.0293498039245605 seconds.
#
# Searching Greenwich, CT for financial analyst positions 	Search number 224 of 240
# The search took 3.6713457107543945 seconds.
#
# Searching remote for entry level data positions 	Search number 225 of 240
# The search took 2.863171100616455 seconds.
#
# Searching remote for entry level data analyst positions 	Search number 226 of 240
# The search took 2.755338191986084 seconds.
#
# Searching remote for entry level data scientist positions 	Search number 227 of 240
# The search took 2.531521797180176 seconds.
#
# Searching remote for entry level financial analyst positions 	Search number 228 of 240
# The search took 2.1500821113586426 seconds.
#
# Searching remote for junior data positions 	Search number 229 of 240
# The search took 2.7572665214538574 seconds.
#
# Searching remote for junior data analyst positions 	Search number 230 of 240
# The search took 2.499925374984741 seconds.
#
# Searching remote for junior data scientist positions 	Search number 231 of 240
# The search took 2.107846975326538 seconds.
#
# Searching remote for junior financial analyst positions 	Search number 232 of 240
# The search took 2.414283514022827 seconds.
#
# Searching remote for associate data positions 	Search number 233 of 240
# The search took 2.2425389289855957 seconds.
#
# Searching remote for associate data analyst positions 	Search number 234 of 240
# The search took 2.3189284801483154 seconds.
#
# Searching remote for associate data scientist positions 	Search number 235 of 240
# The search took 2.455630302429199 seconds.
#
# Searching remote for associate financial analyst positions 	Search number 236 of 240
# The search took 2.8631675243377686 seconds.
#
# Searching remote for data positions 	Search number 237 of 240
# The search took 2.549696683883667 seconds.
#
# Searching remote for data analyst positions 	Search number 238 of 240
# The search took 3.3742594718933105 seconds.
#
# Searching remote for data scientist positions 	Search number 239 of 240
# The search took 2.8709030151367188 seconds.
#
# Searching remote for financial analyst positions 	Search number 240 of 240
# Indeed search completed in 4252.209062099457 seconds. 1303 results found (including duplicates).
# Returned 646 unique entries from Indeed.

# %% [markdown]
# # Monster

# %%
jobs_monster = []

########################
# Performance Monitors #
########################
search_times_monster = []
individual_searches = []

# Initialize these for performance monitoring
ttm = True
start_time = time.time()
counter = 1

for search_location in search_locations:
    for search_title in [(s + t) for s in prefixes for t in titles]:

        ####################################
        # Monitoring Chunk
        individual_searches.append([search_location, search_title])
        if counter > 1: 
            search_time = time.time() - search_start
            search_times_monster.append(search_time)
            if ttm:
                print(f'The search took {search_time} seconds.\n')
        if ttm:
            print(f'Searching {search_location} for {search_title} positions \tSearch number {counter} of {n_searches}') 
        counter += 1
        search_start = time.time()
        #####################################

        sl = search_location.replace(' ', '-').replace(',', '__2C')
        st = search_title.replace(' ', '-')
        URL = f'https://www.monster.com/jobs/search/?q={st}&where={sl}&stpage=1&page=10'
        try:
            results = get_job_results(URL, 'ResultsContainer')
        except:
            continue
        job_elems = results.find_all('section', class_='card-content')
        if results is None:
            continue

        for job in job_elems:
            # If the title or company isn't present, continue to the next one
            title_elem = job.find('h2', class_='title')
            if title_elem is None:
                continue
            else:
                title = title_elem.text.strip()
            
            # If it was posted over our limit we don't want it
                when_elem = job.find('time').text.strip()
                if (when_elem[0] == "P") | (when_elem[0] == "J"):
                    when_elem = 0
                elif when_elem[0] == "+":
                    continue
                elif pd.to_numeric(when_elem[:2]) > posted_date_cutoff:
                    continue
                else:
                    when_elem = pd.to_numeric(when_elem[:2])

           
            # If the company element isn't present continue to the next
            company_elem = job.find('div', class_='company')
            if company_elem is not None:
                company = company_elem.text.strip()
            
            # If there isn't a job location provided, indicate that
            location_elem = job.find('div', class_='location')
            if location_elem is not None:
                location = location_elem.text.strip()
            #####################
            # Get the link for the page with the full job description
            link = job.find('a')['href']

            description_results = get_job_results(link, 'main-content')
            details_elem = description_results.findAll('div', class_='detail-row')
            salary = None
            job_type = None
            for detail in details_elem:
                dt = detail.text.strip()
                if 'Salary' in dt:
                    salary = dt
                if 'Job Type' in dt:
                    job_type = dt                    
                # if when_elem is None and 'Posted' in dt:
                    # posted = dt

        
            

            description_elem = description_results.find('div', class_='job-description')
            if description_elem is not None:
                description = description_elem.text.strip()
            
            item = [
                search_title,
                search_location,
                location,
                title,
                company,
                when_elem,
                salary,
                job_type,
                link,
                description
            ]
            jobs_monster.append(item)

# This adds the time for the final search.
search_time = time.time() - search_start
search_times_monster.append(search_time)

total_search_time_monster = time.time() - start_time

if ttm:
     print(f'Monster search took {total_search_time_monster} seconds to retreive {len(jobs_monster)} total results (including some duplicates).')

# Convert array of arrays into data frame
monster_0 = pd.DataFrame(jobs_monster, columns=columns)
# Save raw data just in case
monster_0.to_csv('data/0rawdata/' + datetime.today().strftime("%Y-%m-%d") + '_monster.csv', index=False)
# filter and modify df going forward
monster_1 = preprocess_jobs_recent(monster_0)
monster_1.to_csv('data/' + datetime.today().strftime("%Y-%m-%d") + '_monster.csv', index=False)
# Save the monitoring data into their respective csv's for later analysis.
# collect_individual_search_info saves into a new csv which monitors performance of each individual search
# collect_individual_search_info('Monster', individual_searches, monster_0, monster_1, search_times_monster, total_search_time, 'Recent Jobs Only')
# save_search_stats('Monster', len(monster_0), len(monster_1), total_search_time_monster, n_searches, 'Recent Jobs Only')

print(f'Returned {len(monster_1)} unique entries from Monster.com')
# Out:
# took 0.9744727611541748 seconds.
#
# Searching Bridgewater, NJ for junior data positions 	Search number 85 of 240
# The search took 1.3325724601745605 seconds.
#
# Searching Bridgewater, NJ for junior data analyst positions 	Search number 86 of 240
# The search took 0.7694847583770752 seconds.
#
# Searching Bridgewater, NJ for junior data scientist positions 	Search number 87 of 240
# The search took 0.648444652557373 seconds.
#
# Searching Bridgewater, NJ for junior financial analyst positions 	Search number 88 of 240
# The search took 0.9148774147033691 seconds.
#
# Searching Bridgewater, NJ for associate data positions 	Search number 89 of 240
# The search took 2.9696292877197266 seconds.
#
# Searching Bridgewater, NJ for associate data analyst positions 	Search number 90 of 240
# The search took 1.4847412109375 seconds.
#
# Searching Bridgewater, NJ for associate data scientist positions 	Search number 91 of 240
# The search took 1.625230312347412 seconds.
#
# Searching Bridgewater, NJ for associate financial analyst positions 	Search number 92 of 240
# The search took 2.1682369709014893 seconds.
#
# Searching Bridgewater, NJ for data positions 	Search number 93 of 240
# The search took 42.09378528594971 seconds.
#
# Searching Bridgewater, NJ for data analyst positions 	Search number 94 of 240
# The search took 18.60987877845764 seconds.
#
# Searching Bridgewater, NJ for data scientist positions 	Search number 95 of 240
# The search took 12.705321788787842 seconds.
#
# Searching Bridgewater, NJ for financial analyst positions 	Search number 96 of 240
# The search took 6.860544919967651 seconds.
#
# Searching Somerville, NJ for entry level data positions 	Search number 97 of 240
# The search took 1.056072473526001 seconds.
#
# Searching Somerville, NJ for entry level data analyst positions 	Search number 98 of 240
# The search took 0.7845137119293213 seconds.
#
# Searching Somerville, NJ for entry level data scientist positions 	Search number 99 of 240
# The search took 0.7370467185974121 seconds.
#
# Searching Somerville, NJ for entry level financial analyst positions 	Search number 100 of 240
# The search took 0.7676787376403809 seconds.
#
# Searching Somerville, NJ for junior data positions 	Search number 101 of 240
# The search took 1.057748556137085 seconds.
#
# Searching Somerville, NJ for junior data analyst positions 	Search number 102 of 240
# The search took 0.8114819526672363 seconds.
#
# Searching Somerville, NJ for junior data scientist positions 	Search number 103 of 240
# The search took 0.8726084232330322 seconds.
#
# Searching Somerville, NJ for junior financial analyst positions 	Search number 104 of 240
# The search took 0.7248764038085938 seconds.
#
# Searching Somerville, NJ for associate data positions 	Search number 105 of 240
# The search took 2.6997475624084473 seconds.
#
# Searching Somerville, NJ for associate data analyst positions 	Search number 106 of 240
# The search took 1.3760340213775635 seconds.
#
# Searching Somerville, NJ for associate data scientist positions 	Search number 107 of 240
# The search took 1.279749870300293 seconds.
#
# Searching Somerville, NJ for associate financial analyst positions 	Search number 108 of 240
# The search took 1.456834316253662 seconds.
#
# Searching Somerville, NJ for data positions 	Search number 109 of 240
# The search took 38.90435171127319 seconds.
#
# Searching Somerville, NJ for data analyst positions 	Search number 110 of 240
# The search took 10.795314073562622 seconds.
#
# Searching Somerville, NJ for data scientist positions 	Search number 111 of 240
# The search took 12.868069648742676 seconds.
#
# Searching Somerville, NJ for financial analyst positions 	Search number 112 of 240
# The search took 6.824876546859741 seconds.
#
# Searching Summit, NJ for entry level data positions 	Search number 113 of 240
# The search took 1.9052767753601074 seconds.
#
# Searching Summit, NJ for entry level data analyst positions 	Search number 114 of 240
# The search took 1.030979871749878 seconds.
#
# Searching Summit, NJ for entry level data scientist positions 	Search number 115 of 240
# The search took 0.8220152854919434 seconds.
#
# Searching Summit, NJ for entry level financial analyst positions 	Search number 116 of 240
# The search took 0.8098559379577637 seconds.
#
# Searching Summit, NJ for junior data positions 	Search number 117 of 240
# The search took 1.5130014419555664 seconds.
#
# Searching Summit, NJ for junior data analyst positions 	Search number 118 of 240
# The search took 1.4453637599945068 seconds.
#
# Searching Summit, NJ for junior data scientist positions 	Search number 119 of 240
# The search took 0.758634090423584 seconds.
#
# Searching Summit, NJ for junior financial analyst positions 	Search number 120 of 240
# The search took 1.296750783920288 seconds.
#
# Searching Summit, NJ for associate data positions 	Search number 121 of 240
# The search took 7.013423204421997 seconds.
#
# Searching Summit, NJ for associate data analyst positions 	Search number 122 of 240
# The search took 3.4858174324035645 seconds.
#
# Searching Summit, NJ for associate data scientist positions 	Search number 123 of 240
# The search took 8.6103994846344 seconds.
#
# Searching Summit, NJ for associate financial analyst positions 	Search number 124 of 240
# The search took 4.647017002105713 seconds.
#
# Searching Summit, NJ for data positions 	Search number 125 of 240
# The search took 38.174742698669434 seconds.
#
# Searching Summit, NJ for data analyst positions 	Search number 126 of 240
# The search took 22.69054079055786 seconds.
#
# Searching Summit, NJ for data scientist positions 	Search number 127 of 240
# The search took 31.25683879852295 seconds.
#
# Searching Summit, NJ for financial analyst positions 	Search number 128 of 240
# The search took 18.92072892189026 seconds.
#
# Searching Morristown, NJ for entry level data positions 	Search number 129 of 240
# The search took 1.4405837059020996 seconds.
#
# Searching Morristown, NJ for entry level data analyst positions 	Search number 130 of 240
# The search took 0.7543416023254395 seconds.
#
# Searching Morristown, NJ for entry level data scientist positions 	Search number 131 of 240
# The search took 0.8051936626434326 seconds.
#
# Searching Morristown, NJ for entry level financial analyst positions 	Search number 132 of 240
# The search took 0.6559464931488037 seconds.
#
# Searching Morristown, NJ for junior data positions 	Search number 133 of 240
# The search took 1.2226929664611816 seconds.
#
# Searching Morristown, NJ for junior data analyst positions 	Search number 134 of 240
# The search took 0.7452895641326904 seconds.
#
# Searching Morristown, NJ for junior data scientist positions 	Search number 135 of 240
# The search took 0.9197442531585693 seconds.
#
# Searching Morristown, NJ for junior financial analyst positions 	Search number 136 of 240
# The search took 1.2597682476043701 seconds.
#
# Searching Morristown, NJ for associate data positions 	Search number 137 of 240
# The search took 1.6934819221496582 seconds.
#
# Searching Morristown, NJ for associate data analyst positions 	Search number 138 of 240
# The search took 1.4344141483306885 seconds.
#
# Searching Morristown, NJ for associate data scientist positions 	Search number 139 of 240
# The search took 1.0790317058563232 seconds.
#
# Searching Morristown, NJ for associate financial analyst positions 	Search number 140 of 240
# The search took 1.6183876991271973 seconds.
#
# Searching Morristown, NJ for data positions 	Search number 141 of 240
# The search took 38.477341651916504 seconds.
#
# Searching Morristown, NJ for data analyst positions 	Search number 142 of 240
# The search took 15.929317474365234 seconds.
#
# Searching Morristown, NJ for data scientist positions 	Search number 143 of 240
# The search took 14.442806243896484 seconds.
#
# Searching Morristown, NJ for financial analyst positions 	Search number 144 of 240
# The search took 10.19952392578125 seconds.
#
# Searching Edison, NJ for entry level data positions 	Search number 145 of 240
# The search took 1.2409355640411377 seconds.
#
# Searching Edison, NJ for entry level data analyst positions 	Search number 146 of 240
# The search took 0.7228477001190186 seconds.
#
# Searching Edison, NJ for entry level data scientist positions 	Search number 147 of 240
# The search took 0.9619319438934326 seconds.
#
# Searching Edison, NJ for entry level financial analyst positions 	Search number 148 of 240
# The search took 0.7910459041595459 seconds.
#
# Searching Edison, NJ for junior data positions 	Search number 149 of 240
# The search took 1.265946626663208 seconds.
#
# Searching Edison, NJ for junior data analyst positions 	Search number 150 of 240
# The search took 1.534367322921753 seconds.
#
# Searching Edison, NJ for junior data scientist positions 	Search number 151 of 240
# The search took 0.8037292957305908 seconds.
#
# Searching Edison, NJ for junior financial analyst positions 	Search number 152 of 240
# The search took 0.9067919254302979 seconds.
#
# Searching Edison, NJ for associate data positions 	Search number 153 of 240
# The search took 7.100261688232422 seconds.
#
# Searching Edison, NJ for associate data analyst positions 	Search number 154 of 240
# The search took 3.415977954864502 seconds.
#
# Searching Edison, NJ for associate data scientist positions 	Search number 155 of 240
# The search took 8.617522716522217 seconds.
#
# Searching Edison, NJ for associate financial analyst positions 	Search number 156 of 240
# The search took 4.46866774559021 seconds.
#
# Searching Edison, NJ for data positions 	Search number 157 of 240
# The search took 34.84802174568176 seconds.
#
# Searching Edison, NJ for data analyst positions 	Search number 158 of 240
# The search took 22.690779447555542 seconds.
#
# Searching Edison, NJ for data scientist positions 	Search number 159 of 240
# The search took 26.184947967529297 seconds.
#
# Searching Edison, NJ for financial analyst positions 	Search number 160 of 240
# The search took 19.900172233581543 seconds.
#
# Searching Metuchen, NJ for entry level data positions 	Search number 161 of 240
# The search took 1.3503310680389404 seconds.
#
# Searching Metuchen, NJ for entry level data analyst positions 	Search number 162 of 240
# The search took 0.8880383968353271 seconds.
#
# Searching Metuchen, NJ for entry level data scientist positions 	Search number 163 of 240
# The search took 0.6682243347167969 seconds.
#
# Searching Metuchen, NJ for entry level financial analyst positions 	Search number 164 of 240
# The search took 0.7621452808380127 seconds.
#
# Searching Metuchen, NJ for junior data positions 	Search number 165 of 240
# The search took 1.1676576137542725 seconds.
#
# Searching Metuchen, NJ for junior data analyst positions 	Search number 166 of 240
# The search took 1.5507748126983643 seconds.
#
# Searching Metuchen, NJ for junior data scientist positions 	Search number 167 of 240
# The search took 0.809638500213623 seconds.
#
# Searching Metuchen, NJ for junior financial analyst positions 	Search number 168 of 240
# The search took 0.8286857604980469 seconds.
#
# Searching Metuchen, NJ for associate data positions 	Search number 169 of 240
# The search took 8.467247724533081 seconds.
#
# Searching Metuchen, NJ for associate data analyst positions 	Search number 170 of 240
# The search took 4.057254076004028 seconds.
#
# Searching Metuchen, NJ for associate data scientist positions 	Search number 171 of 240
# The search took 9.234318494796753 seconds.
#
# Searching Metuchen, NJ for associate financial analyst positions 	Search number 172 of 240
# The search took 5.022032022476196 seconds.
#
# Searching Metuchen, NJ for data positions 	Search number 173 of 240
# The search took 33.541181325912476 seconds.
#
# Searching Metuchen, NJ for data analyst positions 	Search number 174 of 240
# The search took 24.63558340072632 seconds.
#
# Searching Metuchen, NJ for data scientist positions 	Search number 175 of 240
# The search took 25.234520435333252 seconds.
#
# Searching Metuchen, NJ for financial analyst positions 	Search number 176 of 240
# The search took 18.79799509048462 seconds.
#
# Searching Hackensack, NJ for entry level data positions 	Search number 177 of 240
# The search took 1.7845003604888916 seconds.
#
# Searching Hackensack, NJ for entry level data analyst positions 	Search number 178 of 240
# The search took 1.1618385314941406 seconds.
#
# Searching Hackensack, NJ for entry level data scientist positions 	Search number 179 of 240
# The search took 0.7387151718139648 seconds.
#
# Searching Hackensack, NJ for entry level financial analyst positions 	Search number 180 of 240
# The search took 0.825157642364502 seconds.
#
# Searching Hackensack, NJ for junior data positions 	Search number 181 of 240
# The search took 1.6058902740478516 seconds.
#
# Searching Hackensack, NJ for junior data analyst positions 	Search number 182 of 240
# The search took 1.659480333328247 seconds.
#
# Searching Hackensack, NJ for junior data scientist positions 	Search number 183 of 240
# The search took 0.7964043617248535 seconds.
#
# Searching Hackensack, NJ for junior financial analyst positions 	Search number 184 of 240
# The search took 0.7705717086791992 seconds.
#
# Searching Hackensack, NJ for associate data positions 	Search number 185 of 240
# The search took 6.888788223266602 seconds.
#
# Searching Hackensack, NJ for associate data analyst positions 	Search number 186 of 240
# The search took 2.9695703983306885 seconds.
#
# Searching Hackensack, NJ for associate data scientist positions 	Search number 187 of 240
# The search took 7.979079008102417 seconds.
#
# Searching Hackensack, NJ for associate financial analyst positions 	Search number 188 of 240
# The search took 4.802062749862671 seconds.
#
# Searching Hackensack, NJ for data positions 	Search number 189 of 240
# The search took 34.64650225639343 seconds.
#
# Searching Hackensack, NJ for data analyst positions 	Search number 190 of 240
# The search took 21.810492277145386 seconds.
#
# Searching Hackensack, NJ for data scientist positions 	Search number 191 of 240
# The search took 33.00518250465393 seconds.
#
# Searching Hackensack, NJ for financial analyst positions 	Search number 192 of 240
# The search took 22.210176706314087 seconds.
#
# Searching Stamford, CT for entry level data positions 	Search number 193 of 240
# The search took 1.6267929077148438 seconds.
#
# Searching Stamford, CT for entry level data analyst positions 	Search number 194 of 240
# The search took 1.1059327125549316 seconds.
#
# Searching Stamford, CT for entry level data scientist positions 	Search number 195 of 240
# The search took 0.7436785697937012 seconds.
#
# Searching Stamford, CT for entry level financial analyst positions 	Search number 196 of 240
# The search took 1.0982677936553955 seconds.
#
# Searching Stamford, CT for junior data positions 	Search number 197 of 240
# The search took 0.8757364749908447 seconds.
#
# Searching Stamford, CT for junior data analyst positions 	Search number 198 of 240
# The search took 0.9736595153808594 seconds.
#
# Searching Stamford, CT for junior data scientist positions 	Search number 199 of 240
# The search took 0.6492156982421875 seconds.
#
# Searching Stamford, CT for junior financial analyst positions 	Search number 200 of 240
# The search took 1.1859142780303955 seconds.
#
# Searching Stamford, CT for associate data positions 	Search number 201 of 240
# The search took 0.8359589576721191 seconds.
#
# Searching Stamford, CT for associate data analyst positions 	Search number 202 of 240
# The search took 0.9358060359954834 seconds.
#
# Searching Stamford, CT for associate data scientist positions 	Search number 203 of 240
# The search took 2.111687421798706 seconds.
#
# Searching Stamford, CT for associate financial analyst positions 	Search number 204 of 240
# The search took 1.416062355041504 seconds.
#
# Searching Stamford, CT for data positions 	Search number 205 of 240
# The search took 38.77476501464844 seconds.
#
# Searching Stamford, CT for data analyst positions 	Search number 206 of 240
# The search took 12.243589878082275 seconds.
#
# Searching Stamford, CT for data scientist positions 	Search number 207 of 240
# The search took 9.425668954849243 seconds.
#
# Searching Stamford, CT for financial analyst positions 	Search number 208 of 240
# The search took 7.9325854778289795 seconds.
#
# Searching Greenwich, CT for entry level data positions 	Search number 209 of 240
# The search took 1.1635761260986328 seconds.
#
# Searching Greenwich, CT for entry level data analyst positions 	Search number 210 of 240
# The search took 1.0101757049560547 seconds.
#
# Searching Greenwich, CT for entry level data scientist positions 	Search number 211 of 240
# The search took 0.6708142757415771 seconds.
#
# Searching Greenwich, CT for entry level financial analyst positions 	Search number 212 of 240
# The search took 0.947335958480835 seconds.
#
# Searching Greenwich, CT for junior data positions 	Search number 213 of 240
# The search took 0.8421497344970703 seconds.
#
# Searching Greenwich, CT for junior data analyst positions 	Search number 214 of 240
# The search took 0.9076414108276367 seconds.
#
# Searching Greenwich, CT for junior data scientist positions 	Search number 215 of 240
# The search took 0.8959946632385254 seconds.
#
# Searching Greenwich, CT for junior financial analyst positions 	Search number 216 of 240
# The search took 1.1482982635498047 seconds.
#
# Searching Greenwich, CT for associate data positions 	Search number 217 of 240
# The search took 4.301674842834473 seconds.
#
# Searching Greenwich, CT for associate data analyst positions 	Search number 218 of 240
# The search took 1.462383508682251 seconds.
#
# Searching Greenwich, CT for associate data scientist positions 	Search number 219 of 240
# The search took 4.57185697555542 seconds.
#
# Searching Greenwich, CT for associate financial analyst positions 	Search number 220 of 240
# The search took 2.4450674057006836 seconds.
#
# Searching Greenwich, CT for data positions 	Search number 221 of 240
# The search took 35.102935791015625 seconds.
#
# Searching Greenwich, CT for data analyst positions 	Search number 222 of 240
# The search took 22.650245428085327 seconds.
#
# Searching Greenwich, CT for data scientist positions 	Search number 223 of 240
# The search took 27.943957328796387 seconds.
#
# Searching Greenwich, CT for financial analyst positions 	Search number 224 of 240
# The search took 18.27552080154419 seconds.
#
# Searching remote for entry level data positions 	Search number 225 of 240
# The search took 0.9904215335845947 seconds.
#
# Searching remote for entry level data analyst positions 	Search number 226 of 240
# The search took 1.4332804679870605 seconds.
#
# Searching remote for entry level data scientist positions 	Search number 227 of 240
# The search took 9.796345233917236 seconds.
#
# Searching remote for entry level financial analyst positions 	Search number 228 of 240
# The search took 10.260658740997314 seconds.
#
# Searching remote for junior data positions 	Search number 229 of 240
# The search took 0.9694681167602539 seconds.
#
# Searching remote for junior data analyst positions 	Search number 230 of 240
# The search took 0.8983373641967773 seconds.
#
# Searching remote for junior data scientist positions 	Search number 231 of 240
# The search took 0.9736955165863037 seconds.
#
# Searching remote for junior financial analyst positions 	Search number 232 of 240
# The search took 10.83841848373413 seconds.
#
# Searching remote for associate data positions 	Search number 233 of 240
# The search took 1.2519850730895996 seconds.
#
# Searching remote for associate data analyst positions 	Search number 234 of 240
# The search took 1.6891016960144043 seconds.
#
# Searching remote for associate data scientist positions 	Search number 235 of 240
# The search took 1.407607078552246 seconds.
#
# Searching remote for associate financial analyst positions 	Search number 236 of 240
# The search took 0.9700438976287842 seconds.
#
# Searching remote for data positions 	Search number 237 of 240
# The search took 41.47669267654419 seconds.
#
# Searching remote for data analyst positions 	Search number 238 of 240
# The search took 13.439654111862183 seconds.
#
# Searching remote for data scientist positions 	Search number 239 of 240
# The search took 17.11463499069214 seconds.
#
# Searching remote for financial analyst positions 	Search number 240 of 240
# Monster search took 1830.128429889679 seconds to retreive 5257 total results (including some duplicates).
# Returned 1421 unique entries from Monster.com

# %%
df_0 = pd.concat([indeed_1, monster_1], ignore_index=True)
df_1 = df_0.drop_duplicates(subset=['description'])
# df = PreprocessJobs(df)
print('Both pre duplicate removal:', len(df_0), '\n', 'Post duplicate removal:', len(df_1))

df = df_1
# Out:
# Both pre duplicate removal: 204
#  Post duplicate removal: 177

# %%
df['description'] = df['description'].str.replace(',', ' ')

# %%
df.to_csv('data/' + datetime.today().strftime("%Y-%m-%d") + '_recentjobs.tsv', sep='\t', index=False)
