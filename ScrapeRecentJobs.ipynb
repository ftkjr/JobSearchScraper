# %%
# Import Packages 
import csv
from datetime import *
import numpy
import math
import requests
from bs4 import BeautifulSoup
import pandas as pd
import time
import re

# %%
def get_job_results(url: str, info_id: str) -> list:
    """"Return page results from job site"""
    page = requests.get(url)
    soup = BeautifulSoup(page.content, 'html.parser')
    results = soup.find(id=info_id) 
    return results

def collect_individual_search_info(site: str, individual_searches: list, total_results_frame, unique_results_frame, search_times: list, total_search_time: float, notes:str = None):
    """Return individual search info as one DataFrame"""
    # Create framework for the individual search data. 
    individual_searches_frame = pd.DataFrame(individual_searches, columns=['search_location', 'search_title'])
    individual_searches_frame['SearchTimes'] = search_times
    individual_searches_frame['Site'] = site
    individual_searches_frame['Date'] = datetime.now().strftime("%Y-%m-%d %H:%M:%S")

    # Collect the counts for the results before removing duplicates.
    total_results = total_results_frame[['search_title', 'search_location', 'description']].groupby(['search_title', 'search_location'], as_index=False).count()

    # Collect the counts for the results after removing duplicates.
    unique_results = unique_results_frame[['search_title', 'search_location', 'description']].groupby(['search_title', 'search_location'], as_index=False).count()

    # Add the Total Results count to the individual searches frame.
    individual_searches_frame = pd.merge(
        individual_searches_frame, 
        pd.DataFrame({
            'search_title': total_results['search_title'], 
            'search_location': total_results['search_location'], 
            'TotalResults': total_results['description']
            }),
        on=['search_title', 'search_location'], 
        how='left'
        )

    # Add the Unique Results count to the individual searches frame.
    individual_searches_frame = pd.merge(
        individual_searches_frame, 
        pd.DataFrame({
            'search_title': unique_results['search_title'], 
            'search_location': unique_results['search_location'], 
            'UniqueResults': unique_results['description']
            }),
            on=['search_title', 'search_location'], 
            how='left'
            )
    
    # Where we didn't have a results count we must not have found anything, so replace the NaN with a 0.
    for col in ['TotalResults', 'UniqueResults']:
        individual_searches_frame[col][individual_searches_frame[col].isnull()] = 0

    # Add the total search time to the data frame.
    individual_searches_frame['TotalSearchTime'] = total_search_time
    # Add any notes we have to the frame.
    individual_searches_frame['Notes'] = notes
    individual_searches_frame.to_csv('Diagnostics/ScraperPerformancebySearch.csv', mode='a', header=False)
  

def preprocess_jobs_recent(initial_data):
    """Clean up the jobs frame"""
    for col in [col for col in indeed_0.columns if col is not 'posted']:
        initial_data[col] = initial_data[col].str.replace('\n', ' ')
    processed_data = initial_data.drop_duplicates(subset=['link'], keep='first')
    processed_data['description'] = processed_data['description'].str.replace(r"([a-z])([A-Z])", r"\1 \.\2")
    processed_data['description'] = processed_data['description'].str.replace(r' \\.', '')
    return processed_data


    
def save_search_stats(site: str, total_returned_jobs: int, unique_jobs: int, search_time: float, total_searches: int, notes: str):
    """Write search statistics as new row in ScraperPerformance.csv"""
    with open('Diagnostics/ScraperPerformance.csv', 'a+', newline='') as file:
        write = csv.writer(file, delimiter=',')
        notes = notes.replace(',', ';')
        write.writerow([site, total_returned_jobs, unique_jobs, search_time, total_searches, date.today(), notes])

# %%
####################
# Data Frame Columns
columns = [
    'search_title', 'search_location', 'location', 'title', 'company', 'posted', 'salary', 'summary', 'link', 'description'
    ]

###############
# Job titles
prefixes = [
    'entry level ', 
    'junior ', 
    'associate ', 
    ''
    ]
titles = [
    'data', 
    'data analyst', 
    'data scientist',
    # 'data engineer',
    'business analyst', 
    'financial analyst', 
    # 'macro analyst'
    ]

################
# Job Locations
search_locations = [
    'New York, NY',
    'Newark, NJ', 
    'Princeton, NJ', 'Jersey City, NJ', 'Trenton, NJ', 
    'Bridgewater, NJ', 'Somerville, NJ', 'Summit, NJ', 
    'Morristown, NJ', 'Edison, NJ', 'Metuchen, NJ', 
    'Hackensack, NJ',
    # 'Philadelphia, PA', 
    'Stamford, CT', 'Greenwich, CT',
    # 'New York', 'New Jersey', 'New Hampshire', 'Pennsylvania', 'Connecticut',
    # 'NY', 'NJ', 'NH', 'PA', 'CT',
    'remote'
    ]


n_searches = (len(titles) * len(prefixes)) * len(search_locations)

# %%
posted_date_cutoff = 5
# posted_date_cutoff = input('What is our date cutoff for finding jobs? ')

# %% [markdown]
# # Indeed

# %%
################################
################################
#### Scrape Indeed for Jobs ####
################# ###############
################################

# Four Fors: Because who needs a head hunter anyways?
# 1. Search each location
#   2. Search each job title
#       3. Search each page of results 
#           4. Get each job's description
# nlocations * ntitles * npages * njobdescriptions = niterations
# 
# NOTE We sleep before hitting the page because if we over do it they won't give us the data
# 

#######################
# Change these fields #
#######################

#######################
# URL Fields
# How many pages per locale
location_results = 100
# How far out should we look?
radius = 50



########################
# Performance Monitors #
########################
search_times_indeed = []
individual_searches = []

# Initialize these for performance monitoring
ttm = True
start_time = time.time()
counter = 1

# Array of jobs
jobs_indeed = []
visited_links = set()

# Main two iterators for the search, 
for search_location in search_locations: 
    for search_title in [(s + t) for s in prefixes for t in titles]:

       ####################################
        # Monitoring Chunk
        individual_searches.append([search_location, search_title])
        if counter > 1: 
            search_time = time.time() - search_start
            search_times_indeed.append(search_time)
            if ttm:
                print(f'The search took {search_time} seconds.\n')
        if ttm:
            print(f'Searching {search_location} for {search_title} positions \tSearch number {counter} of {n_searches}') 
        counter += 1
        search_start = time.time()
        #####################################

        for nresults in range(0, location_results, 10):            
            # Go to the url below and get the results from each page
            s = search_location.replace(' ', '%20').replace(',', '%2C')
            st = search_title.replace(' ', '%20')
            url = f'https://www.indeed.com/jobs?q={st}+%2420%2C000&l={s}+&radius={radius}&start={str(nresults)}'
            try:
                results = get_job_results(url, 'resultsCol')
            except:
                continue
            # If we have run out of postings move on
            if results is None:
                continue
            job_elems = results.find_all('div', class_='jobsearch-SerpJobCard')
            
            ##############################
            # FIND THE MOST RECENT JOB POSTS!!! 
            for job in job_elems:
                # Make sure it's a valid post
                title_elem = job.find('h2', class_='title')
                if title_elem is None:  
                    continue
                else:
                    title = title_elem.text.strip()

                # Use the link to the job description to determine if it's
                # a job post that we have already scraped during this run.
                # If it is a job we've seen, continue on to the next one.
                link = job.find('a')['href']
                description_url = f'https://www.indeed.com{link}'
                if description_url in visited_links:
                    continue
                else:
                    visited_links.add(description_url)
                
                # If it was posted over our limit we don't want it
                when_elem = job.find('span', class_='date').text.strip()
                if (when_elem[0] == "T") | (when_elem[0] == "J"):
                    when_elem = 0
                elif when_elem[0] == "+":
                    continue
                elif pd.to_numeric(when_elem[:2]) > posted_date_cutoff:
                    continue
                else:
                    when_elem = pd.to_numeric(when_elem[:2])

                # Company:
                company_elem = job.find('span', class_='company')
                if company_elem is None:
                    continue
                else:
                    company_elem = company_elem.text.strip()


                #########################
                #   Location: Where is the job
                #   Salary: How much are they paying
                #   Summary: What's the provided job summary
                location_elem = job.find('span', class_='location')
                salary_elem = job.find('span', class_='salary')
                summary_elem = job.find('div', class_='summary')
                 
                
                # If there isn't a location provided, denote that
                if location_elem is not None:
                    location_elem = location_elem.text.strip()

                # If there isn't a salary provided, denote that
                if salary_elem is not None:
                    salary_elem = salary_elem.text.strip()
                
                 # If there isn't a job summary provided, denote that
                if summary_elem is not None:
                    summary_elem = summary_elem.text.strip()


                ##################################
                # Go to the Job Description Page #
                ##################################
                # Wait {sleep_time} seconds before hitting the page so they don't kick us out
                # 
                time.sleep(2)
                try:
                    description_results = get_job_results(description_url, 'jobDescriptionText')
                except:
                    continue
                # If we screwed up locating the description, denote that
                if description_results is not None:
                    description_text = description_results.text.strip()

                # Create an array of info for this job posting
                info = [
                    search_title,
                    search_location,
                    location_elem, 
                    title,
                    company_elem,
                    when_elem,
                    salary_elem,
                    summary_elem,
                    description_url,
                    description_text
                ]

                # Append the job info array to the array of job posting arrays
                jobs_indeed.append(info)

# This adds the time for the final search.
search_time = time.time() - search_start
search_times_indeed.append(search_time)

# Calculate the total search time.
total_search_time = time.time() - start_time

if ttm:
     print(f'Indeed search completed in {total_search_time} seconds. {len(jobs_indeed)} results found (including duplicates).') 

# Convert the array of job arrays into a data frame.
indeed_0 = pd.DataFrame(jobs_indeed, columns=columns)

# Save raw data just in case
indeed_0.to_csv('data/0rawdata/' + datetime.today().strftime("%Y-%m-%d") + '_indeed.csv', index=False)
indeed_0.to_csv('Z:/data/0rawdata/' + datetime.today().strftime("%Y-%m-%d") + '_indeed.csv', index=False)

# Filter and modify the original and put it in a new variable.
indeed_1 = preprocess_jobs_recent(indeed_0)
indeed_1.to_csv('data/' + datetime.today().strftime("%Y-%m-%d") + '_indeed.csv', index=False)
indeed_1.to_csv('Z:/data/' + datetime.today().strftime("%Y-%m-%d") + '_indeed.csv', index=False)


# Save the monitoring data into their respective csv's for later analysis.
# collect_individual_search_info saves into a new csv which monitors performance of each individual search
# collect_individual_search_info('Indeed', individual_searches, indeed_0, indeed_1, search_times_indeed, total_search_time, 'Recent Jobs Only')
# save_search_stats('Indeed', len(jobs_indeed), len(indeed_1), total_search_time, n_searches, 'Recent Jobs Only')

# Tell us when we're done!
print(f'Returned {len(indeed_1)} unique entries from Indeed.')
# Out:
# level financial analyst positions 	Search number 145 of 300
# The search took 10.901263236999512 seconds.
#
# Searching Summit, NJ for junior data positions 	Search number 146 of 300
# The search took 42.42372417449951 seconds.
#
# Searching Summit, NJ for junior data analyst positions 	Search number 147 of 300
# The search took 16.082374095916748 seconds.
#
# Searching Summit, NJ for junior data scientist positions 	Search number 148 of 300
# The search took 4.859485864639282 seconds.
#
# Searching Summit, NJ for junior business analyst positions 	Search number 149 of 300
# The search took 15.784451007843018 seconds.
#
# Searching Summit, NJ for junior financial analyst positions 	Search number 150 of 300
# The search took 5.808434009552002 seconds.
#
# Searching Summit, NJ for associate data positions 	Search number 151 of 300
# The search took 12.59956693649292 seconds.
#
# Searching Summit, NJ for associate data analyst positions 	Search number 152 of 300
# The search took 2.0330207347869873 seconds.
#
# Searching Summit, NJ for associate data scientist positions 	Search number 153 of 300
# The search took 1.8731663227081299 seconds.
#
# Searching Summit, NJ for associate business analyst positions 	Search number 154 of 300
# The search took 2.03432297706604 seconds.
#
# Searching Summit, NJ for associate financial analyst positions 	Search number 155 of 300
# The search took 2.0586628913879395 seconds.
#
# Searching Summit, NJ for data positions 	Search number 156 of 300
# The search took 2.0247130393981934 seconds.
#
# Searching Summit, NJ for data analyst positions 	Search number 157 of 300
# The search took 2.047762632369995 seconds.
#
# Searching Summit, NJ for data scientist positions 	Search number 158 of 300
# The search took 1.9801113605499268 seconds.
#
# Searching Summit, NJ for business analyst positions 	Search number 159 of 300
# The search took 1.9828691482543945 seconds.
#
# Searching Summit, NJ for financial analyst positions 	Search number 160 of 300
# The search took 1.9417164325714111 seconds.
#
# Searching Morristown, NJ for entry level data positions 	Search number 161 of 300
# The search took 2.3032267093658447 seconds.
#
# Searching Morristown, NJ for entry level data analyst positions 	Search number 162 of 300
# The search took 2.0878915786743164 seconds.
#
# Searching Morristown, NJ for entry level data scientist positions 	Search number 163 of 300
# The search took 2.4530866146087646 seconds.
#
# Searching Morristown, NJ for entry level business analyst positions 	Search number 164 of 300
# The search took 2.5384409427642822 seconds.
#
# Searching Morristown, NJ for entry level financial analyst positions 	Search number 165 of 300
# The search took 2.43009614944458 seconds.
#
# Searching Morristown, NJ for junior data positions 	Search number 166 of 300
# The search took 2.5882441997528076 seconds.
#
# Searching Morristown, NJ for junior data analyst positions 	Search number 167 of 300
# The search took 2.5162453651428223 seconds.
#
# Searching Morristown, NJ for junior data scientist positions 	Search number 168 of 300
# The search took 2.4981753826141357 seconds.
#
# Searching Morristown, NJ for junior business analyst positions 	Search number 169 of 300
# The search took 2.4590020179748535 seconds.
#
# Searching Morristown, NJ for junior financial analyst positions 	Search number 170 of 300
# The search took 2.7529947757720947 seconds.
#
# Searching Morristown, NJ for associate data positions 	Search number 171 of 300
# The search took 2.5779454708099365 seconds.
#
# Searching Morristown, NJ for associate data analyst positions 	Search number 172 of 300
# The search took 2.462580919265747 seconds.
#
# Searching Morristown, NJ for associate data scientist positions 	Search number 173 of 300
# The search took 2.4510512351989746 seconds.
#
# Searching Morristown, NJ for associate business analyst positions 	Search number 174 of 300
# The search took 2.5144190788269043 seconds.
#
# Searching Morristown, NJ for associate financial analyst positions 	Search number 175 of 300
# The search took 2.576202630996704 seconds.
#
# Searching Morristown, NJ for data positions 	Search number 176 of 300
# The search took 2.468614339828491 seconds.
#
# Searching Morristown, NJ for data analyst positions 	Search number 177 of 300
# The search took 2.515286922454834 seconds.
#
# Searching Morristown, NJ for data scientist positions 	Search number 178 of 300
# The search took 2.4928150177001953 seconds.
#
# Searching Morristown, NJ for business analyst positions 	Search number 179 of 300
# The search took 2.5087385177612305 seconds.
#
# Searching Morristown, NJ for financial analyst positions 	Search number 180 of 300
# The search took 2.5032858848571777 seconds.
#
# Searching Edison, NJ for entry level data positions 	Search number 181 of 300
# The search took 2.539553165435791 seconds.
#
# Searching Edison, NJ for entry level data analyst positions 	Search number 182 of 300
# The search took 2.418353796005249 seconds.
#
# Searching Edison, NJ for entry level data scientist positions 	Search number 183 of 300
# The search took 2.422607898712158 seconds.
#
# Searching Edison, NJ for entry level business analyst positions 	Search number 184 of 300
# The search took 2.066861391067505 seconds.
#
# Searching Edison, NJ for entry level financial analyst positions 	Search number 185 of 300
# The search took 1.842461109161377 seconds.
#
# Searching Edison, NJ for junior data positions 	Search number 186 of 300
# The search took 1.8896677494049072 seconds.
#
# Searching Edison, NJ for junior data analyst positions 	Search number 187 of 300
# The search took 1.9502074718475342 seconds.
#
# Searching Edison, NJ for junior data scientist positions 	Search number 188 of 300
# The search took 1.963101863861084 seconds.
#
# Searching Edison, NJ for junior business analyst positions 	Search number 189 of 300
# The search took 1.860203504562378 seconds.
#
# Searching Edison, NJ for junior financial analyst positions 	Search number 190 of 300
# The search took 1.8325119018554688 seconds.
#
# Searching Edison, NJ for associate data positions 	Search number 191 of 300
# The search took 2.042440176010132 seconds.
#
# Searching Edison, NJ for associate data analyst positions 	Search number 192 of 300
# The search took 1.8575167655944824 seconds.
#
# Searching Edison, NJ for associate data scientist positions 	Search number 193 of 300
# The search took 2.6605641841888428 seconds.
#
# Searching Edison, NJ for associate business analyst positions 	Search number 194 of 300
# The search took 1.8546948432922363 seconds.
#
# Searching Edison, NJ for associate financial analyst positions 	Search number 195 of 300
# The search took 1.956383466720581 seconds.
#
# Searching Edison, NJ for data positions 	Search number 196 of 300
# The search took 2.2444727420806885 seconds.
#
# Searching Edison, NJ for data analyst positions 	Search number 197 of 300
# The search took 1.9328877925872803 seconds.
#
# Searching Edison, NJ for data scientist positions 	Search number 198 of 300
# The search took 1.9326281547546387 seconds.
#
# Searching Edison, NJ for business analyst positions 	Search number 199 of 300
# The search took 1.9155235290527344 seconds.
#
# Searching Edison, NJ for financial analyst positions 	Search number 200 of 300
# The search took 1.7377443313598633 seconds.
#
# Searching Metuchen, NJ for entry level data positions 	Search number 201 of 300
# The search took 2.0739009380340576 seconds.
#
# Searching Metuchen, NJ for entry level data analyst positions 	Search number 202 of 300
# The search took 1.8649787902832031 seconds.
#
# Searching Metuchen, NJ for entry level data scientist positions 	Search number 203 of 300
# The search took 1.8428986072540283 seconds.
#
# Searching Metuchen, NJ for entry level business analyst positions 	Search number 204 of 300
# The search took 1.8502140045166016 seconds.
#
# Searching Metuchen, NJ for entry level financial analyst positions 	Search number 205 of 300
# The search took 1.8704769611358643 seconds.
#
# Searching Metuchen, NJ for junior data positions 	Search number 206 of 300
# The search took 1.8421480655670166 seconds.
#
# Searching Metuchen, NJ for junior data analyst positions 	Search number 207 of 300
# The search took 1.9234416484832764 seconds.
#
# Searching Metuchen, NJ for junior data scientist positions 	Search number 208 of 300
# The search took 2.491436243057251 seconds.
#
# Searching Metuchen, NJ for junior business analyst positions 	Search number 209 of 300
# The search took 2.002208709716797 seconds.
#
# Searching Metuchen, NJ for junior financial analyst positions 	Search number 210 of 300
# The search took 1.9534194469451904 seconds.
#
# Searching Metuchen, NJ for associate data positions 	Search number 211 of 300
# The search took 1.983478307723999 seconds.
#
# Searching Metuchen, NJ for associate data analyst positions 	Search number 212 of 300
# The search took 1.9878885746002197 seconds.
#
# Searching Metuchen, NJ for associate data scientist positions 	Search number 213 of 300
# The search took 1.9752392768859863 seconds.
#
# Searching Metuchen, NJ for associate business analyst positions 	Search number 214 of 300
# The search took 1.9250247478485107 seconds.
#
# Searching Metuchen, NJ for associate financial analyst positions 	Search number 215 of 300
# The search took 1.961775302886963 seconds.
#
# Searching Metuchen, NJ for data positions 	Search number 216 of 300
# The search took 2.042628049850464 seconds.
#
# Searching Metuchen, NJ for data analyst positions 	Search number 217 of 300
# The search took 1.9557218551635742 seconds.
#
# Searching Metuchen, NJ for data scientist positions 	Search number 218 of 300
# The search took 1.9152932167053223 seconds.
#
# Searching Metuchen, NJ for business analyst positions 	Search number 219 of 300
# The search took 1.983091115951538 seconds.
#
# Searching Metuchen, NJ for financial analyst positions 	Search number 220 of 300
# The search took 2.280937910079956 seconds.
#
# Searching Hackensack, NJ for entry level data positions 	Search number 221 of 300
# The search took 1.950777292251587 seconds.
#
# Searching Hackensack, NJ for entry level data analyst positions 	Search number 222 of 300
# The search took 2.0811779499053955 seconds.
#
# Searching Hackensack, NJ for entry level data scientist positions 	Search number 223 of 300
# The search took 1.914360523223877 seconds.
#
# Searching Hackensack, NJ for entry level business analyst positions 	Search number 224 of 300
# The search took 1.925687551498413 seconds.
#
# Searching Hackensack, NJ for entry level financial analyst positions 	Search number 225 of 300
# The search took 2.7155184745788574 seconds.
#
# Searching Hackensack, NJ for junior data positions 	Search number 226 of 300
# The search took 1.9929378032684326 seconds.
#
# Searching Hackensack, NJ for junior data analyst positions 	Search number 227 of 300
# The search took 1.8907263278961182 seconds.
#
# Searching Hackensack, NJ for junior data scientist positions 	Search number 228 of 300
# The search took 2.0060746669769287 seconds.
#
# Searching Hackensack, NJ for junior business analyst positions 	Search number 229 of 300
# The search took 1.9853358268737793 seconds.
#
# Searching Hackensack, NJ for junior financial analyst positions 	Search number 230 of 300
# The search took 2.0587921142578125 seconds.
#
# Searching Hackensack, NJ for associate data positions 	Search number 231 of 300
# The search took 2.1351163387298584 seconds.
#
# Searching Hackensack, NJ for associate data analyst positions 	Search number 232 of 300
# The search took 2.031820297241211 seconds.
#
# Searching Hackensack, NJ for associate data scientist positions 	Search number 233 of 300
# The search took 1.831833839416504 seconds.
#
# Searching Hackensack, NJ for associate business analyst positions 	Search number 234 of 300
# The search took 2.0521109104156494 seconds.
#
# Searching Hackensack, NJ for associate financial analyst positions 	Search number 235 of 300
# The search took 2.0306520462036133 seconds.
#
# Searching Hackensack, NJ for data positions 	Search number 236 of 300
# The search took 1.9106800556182861 seconds.
#
# Searching Hackensack, NJ for data analyst positions 	Search number 237 of 300
# The search took 1.977257490158081 seconds.
#
# Searching Hackensack, NJ for data scientist positions 	Search number 238 of 300
# The search took 2.0040204524993896 seconds.
#
# Searching Hackensack, NJ for business analyst positions 	Search number 239 of 300
# The search took 1.9903008937835693 seconds.
#
# Searching Hackensack, NJ for financial analyst positions 	Search number 240 of 300
# The search took 2.1365177631378174 seconds.
#
# Searching Stamford, CT for entry level data positions 	Search number 241 of 300
# The search took 1.9608960151672363 seconds.
#
# Searching Stamford, CT for entry level data analyst positions 	Search number 242 of 300
# The search took 2.229727268218994 seconds.
#
# Searching Stamford, CT for entry level data scientist positions 	Search number 243 of 300
# The search took 2.0326719284057617 seconds.
#
# Searching Stamford, CT for entry level business analyst positions 	Search number 244 of 300
# The search took 2.5482351779937744 seconds.
#
# Searching Stamford, CT for entry level financial analyst positions 	Search number 245 of 300
# The search took 2.541660785675049 seconds.
#
# Searching Stamford, CT for junior data positions 	Search number 246 of 300
# The search took 2.4247517585754395 seconds.
#
# Searching Stamford, CT for junior data analyst positions 	Search number 247 of 300
# The search took 2.86320161819458 seconds.
#
# Searching Stamford, CT for junior data scientist positions 	Search number 248 of 300
# The search took 2.490269184112549 seconds.
#
# Searching Stamford, CT for junior business analyst positions 	Search number 249 of 300
# The search took 2.796072244644165 seconds.
#
# Searching Stamford, CT for junior financial analyst positions 	Search number 250 of 300
# The search took 2.7124135494232178 seconds.
#
# Searching Stamford, CT for associate data positions 	Search number 251 of 300
# The search took 2.9588253498077393 seconds.
#
# Searching Stamford, CT for associate data analyst positions 	Search number 252 of 300
# The search took 2.4974114894866943 seconds.
#
# Searching Stamford, CT for associate data scientist positions 	Search number 253 of 300
# The search took 2.467301845550537 seconds.
#
# Searching Stamford, CT for associate business analyst positions 	Search number 254 of 300
# The search took 2.1200194358825684 seconds.
#
# Searching Stamford, CT for associate financial analyst positions 	Search number 255 of 300
# The search took 1.8354229927062988 seconds.
#
# Searching Stamford, CT for data positions 	Search number 256 of 300
# The search took 1.9164893627166748 seconds.
#
# Searching Stamford, CT for data analyst positions 	Search number 257 of 300
# The search took 1.79886794090271 seconds.
#
# Searching Stamford, CT for data scientist positions 	Search number 258 of 300
# The search took 1.8612523078918457 seconds.
#
# Searching Stamford, CT for business analyst positions 	Search number 259 of 300
# The search took 1.944873332977295 seconds.
#
# Searching Stamford, CT for financial analyst positions 	Search number 260 of 300
# The search took 1.970937967300415 seconds.
#
# Searching Greenwich, CT for entry level data positions 	Search number 261 of 300
# The search took 1.8949143886566162 seconds.
#
# Searching Greenwich, CT for entry level data analyst positions 	Search number 262 of 300
# The search took 1.9635796546936035 seconds.
#
# Searching Greenwich, CT for entry level data scientist positions 	Search number 263 of 300
# The search took 2.1873083114624023 seconds.
#
# Searching Greenwich, CT for entry level business analyst positions 	Search number 264 of 300
# The search took 1.8682050704956055 seconds.
#
# Searching Greenwich, CT for entry level financial analyst positions 	Search number 265 of 300
# The search took 1.9451680183410645 seconds.
#
# Searching Greenwich, CT for junior data positions 	Search number 266 of 300
# The search took 1.9820358753204346 seconds.
#
# Searching Greenwich, CT for junior data analyst positions 	Search number 267 of 300
# The search took 2.0581517219543457 seconds.
#
# Searching Greenwich, CT for junior data scientist positions 	Search number 268 of 300
# The search took 2.0042970180511475 seconds.
#
# Searching Greenwich, CT for junior business analyst positions 	Search number 269 of 300
# The search took 1.8390817642211914 seconds.
#
# Searching Greenwich, CT for junior financial analyst positions 	Search number 270 of 300
# The search took 1.928912878036499 seconds.
#
# Searching Greenwich, CT for associate data positions 	Search number 271 of 300
# The search took 2.046264886856079 seconds.
#
# Searching Greenwich, CT for associate data analyst positions 	Search number 272 of 300
# The search took 1.9049584865570068 seconds.
#
# Searching Greenwich, CT for associate data scientist positions 	Search number 273 of 300
# The search took 1.907210350036621 seconds.
#
# Searching Greenwich, CT for associate business analyst positions 	Search number 274 of 300
# The search took 2.1976728439331055 seconds.
#
# Searching Greenwich, CT for associate financial analyst positions 	Search number 275 of 300
# The search took 2.157249689102173 seconds.
#
# Searching Greenwich, CT for data positions 	Search number 276 of 300
# The search took 1.9774415493011475 seconds.
#
# Searching Greenwich, CT for data analyst positions 	Search number 277 of 300
# The search took 1.9830322265625 seconds.
#
# Searching Greenwich, CT for data scientist positions 	Search number 278 of 300
# The search took 2.033146858215332 seconds.
#
# Searching Greenwich, CT for business analyst positions 	Search number 279 of 300
# The search took 2.1828110218048096 seconds.
#
# Searching Greenwich, CT for financial analyst positions 	Search number 280 of 300
# The search took 2.9273407459259033 seconds.
#
# Searching remote for entry level data positions 	Search number 281 of 300
# The search took 1.8735592365264893 seconds.
#
# Searching remote for entry level data analyst positions 	Search number 282 of 300
# The search took 2.0805342197418213 seconds.
#
# Searching remote for entry level data scientist positions 	Search number 283 of 300
# The search took 1.9201231002807617 seconds.
#
# Searching remote for entry level business analyst positions 	Search number 284 of 300
# The search took 2.0397775173187256 seconds.
#
# Searching remote for entry level financial analyst positions 	Search number 285 of 300
# The search took 1.8807921409606934 seconds.
#
# Searching remote for junior data positions 	Search number 286 of 300
# The search took 1.9656095504760742 seconds.
#
# Searching remote for junior data analyst positions 	Search number 287 of 300
# The search took 2.0297110080718994 seconds.
#
# Searching remote for junior data scientist positions 	Search number 288 of 300
# The search took 1.8845040798187256 seconds.
#
# Searching remote for junior business analyst positions 	Search number 289 of 300
# The search took 1.9113328456878662 seconds.
#
# Searching remote for junior financial analyst positions 	Search number 290 of 300
# The search took 1.8348233699798584 seconds.
#
# Searching remote for associate data positions 	Search number 291 of 300
# The search took 1.8787004947662354 seconds.
#
# Searching remote for associate data analyst positions 	Search number 292 of 300
# The search took 1.7981617450714111 seconds.
#
# Searching remote for associate data scientist positions 	Search number 293 of 300
# The search took 1.92331862449646 seconds.
#
# Searching remote for associate business analyst positions 	Search number 294 of 300
# The search took 1.9279372692108154 seconds.
#
# Searching remote for associate financial analyst positions 	Search number 295 of 300
# The search took 1.9871644973754883 seconds.
#
# Searching remote for data positions 	Search number 296 of 300
# The search took 1.9894323348999023 seconds.
#
# Searching remote for data analyst positions 	Search number 297 of 300
# The search took 1.9433770179748535 seconds.
#
# Searching remote for data scientist positions 	Search number 298 of 300
# The search took 2.0013720989227295 seconds.
#
# Searching remote for business analyst positions 	Search number 299 of 300
# The search took 2.2301464080810547 seconds.
#
# Searching remote for financial analyst positions 	Search number 300 of 300
# Indeed search completed in 1495.7417511940002 seconds. 261 results found (including duplicates).
# Returned 261 unique entries from Indeed.

# %% [markdown]
# # Monster

# %%
jobs_monster = []
visited_links = set()
########################
# Performance Monitors #
########################
search_times_monster = []
individual_searches = []

# Initialize these for performance monitoring
ttm = True
start_time = time.time()
counter = 1

for search_location in search_locations:
    for search_title in [(s + t) for s in prefixes for t in titles]:

        ####################################
        # Monitoring Chunk
        individual_searches.append([search_location, search_title])
        if counter > 1: 
            search_time = time.time() - search_start
            search_times_monster.append(search_time)
            if ttm:
                print(f'The search took {search_time} seconds.\n')
        if ttm:
            print(f'Searching {search_location} for {search_title} positions \tSearch number {counter} of {n_searches}') 
        counter += 1
        search_start = time.time()
        #####################################

        sl = search_location.replace(' ', '-').replace(',', '__2C')
        st = search_title.replace(' ', '-')
        URL = f'https://www.monster.com/jobs/search/?q={st}&where={sl}&stpage=1&page=10'
        try:
            results = get_job_results(URL, 'ResultsContainer')
        except:
            continue
        job_elems = results.find_all('section', class_='card-content')
        if results is None:
            continue

        for job in job_elems:
            # If the title or company isn't present, continue to the next one
            title_elem = job.find('h2', class_='title')
            if title_elem is None:
                continue
            else:
                title = title_elem.text.strip()
            
            # If it was posted over our limit we don't want it
                when_elem = job.find('time').text.strip()
                if (when_elem[0] == "P") | (when_elem[0] == "J"):
                    when_elem = 0
                elif when_elem[0] == "+":
                    continue
                elif pd.to_numeric(when_elem[:2]) > posted_date_cutoff:
                    continue
                else:
                    when_elem = pd.to_numeric(when_elem[:2])
            
            #####################
            # Get the link for the page with the full job description,
            # then check to see if we have already been to that page.
            # If it's a link to a page we've been to already, 
            # continue on and get the next one.
            link = job.find('a')['href']
            if link in visited_links:
                continue
            else:
                visited_links.add(link)

           
            # If the company element isn't present continue to the next
            company_elem = job.find('div', class_='company')
            if company_elem is not None:
                company = company_elem.text.strip()
            
            # If there isn't a job location provided, indicate that
            location_elem = job.find('div', class_='location')
            if location_elem is not None:
                location = location_elem.text.strip()
            
            # Wait some time, then go to the job description page and get the relevant info.
            time.sleep(2)
            description_results = get_job_results(link, 'main-content')
            
            # Get the job details (Salary, etc)
            details_elem = description_results.findAll('div', class_='detail-row')
            salary = None
            job_type = None
            for detail in details_elem:
                dt = detail.text.strip()
                if 'Salary' in dt:
                    salary = dt
                if 'Job Type' in dt:
                    job_type = dt                    
                # if when_elem is None and 'Posted' in dt:
                    # posted = dt

            # Get the job description.
            description_elem = description_results.find('div', class_='job-description')
            if description_elem is not None:
                description = description_elem.text.strip()
            
            # Bundle all the info
            item = [
                search_title,
                search_location,
                location,
                title,
                company,
                when_elem,
                salary,
                job_type,
                link,
                description
            ]
            jobs_monster.append(item)

# This adds the time for the final search.
search_time = time.time() - search_start
search_times_monster.append(search_time)

total_search_time_monster = time.time() - start_time

if ttm:
     print(f'Monster search took {total_search_time_monster} seconds to retreive {len(jobs_monster)} total results (including some duplicates).')

# Convert array of arrays into data frame
monster_0 = pd.DataFrame(jobs_monster, columns=columns)
# Save raw data just in case
monster_0.to_csv('data/0rawdata/' + datetime.today().strftime("%Y-%m-%d") + '_monster.csv', index=False)
monster_0.to_csv('Z:/data/0rawdata/' + datetime.today().strftime("%Y-%m-%d") + '_monster.csv', index=False)
# filter and modify df going forward
monster_1 = preprocess_jobs_recent(monster_0)
monster_1.to_csv('data/' + datetime.today().strftime("%Y-%m-%d") + '_monster.csv', index=False)
monster_1.to_csv('Z:/data/' + datetime.today().strftime("%Y-%m-%d") + '_monster.csv', index=False)
# Save the monitoring data into their respective csv's for later analysis.
# collect_individual_search_info saves into a new csv which monitors performance of each individual search
# collect_individual_search_info('Monster', individual_searches, monster_0, monster_1, search_times_monster, total_search_time, 'Recent Jobs Only')
# save_search_stats('Monster', len(monster_0), len(monster_1), total_search_time_monster, n_searches, 'Recent Jobs Only')

print(f'Returned {len(monster_1)} unique entries from Monster.com')
# Out:
# ntry level financial analyst positions 	Search number 145 of 300
# The search took 1.9856746196746826 seconds.
#
# Searching Summit, NJ for junior data positions 	Search number 146 of 300
# The search took 0.8888695240020752 seconds.
#
# Searching Summit, NJ for junior data analyst positions 	Search number 147 of 300
# The search took 0.945331335067749 seconds.
#
# Searching Summit, NJ for junior data scientist positions 	Search number 148 of 300
# The search took 0.8728022575378418 seconds.
#
# Searching Summit, NJ for junior business analyst positions 	Search number 149 of 300
# The search took 1.0083463191986084 seconds.
#
# Searching Summit, NJ for junior financial analyst positions 	Search number 150 of 300
# The search took 1.0573289394378662 seconds.
#
# Searching Summit, NJ for associate data positions 	Search number 151 of 300
# The search took 2.0314579010009766 seconds.
#
# Searching Summit, NJ for associate data analyst positions 	Search number 152 of 300
# The search took 1.0012218952178955 seconds.
#
# Searching Summit, NJ for associate data scientist positions 	Search number 153 of 300
# The search took 1.5230021476745605 seconds.
#
# Searching Summit, NJ for associate business analyst positions 	Search number 154 of 300
# The search took 0.8958239555358887 seconds.
#
# Searching Summit, NJ for associate financial analyst positions 	Search number 155 of 300
# The search took 1.220599889755249 seconds.
#
# Searching Summit, NJ for data positions 	Search number 156 of 300
# The search took 11.333984375 seconds.
#
# Searching Summit, NJ for data analyst positions 	Search number 157 of 300
# The search took 2.3636770248413086 seconds.
#
# Searching Summit, NJ for data scientist positions 	Search number 158 of 300
# The search took 2.33095383644104 seconds.
#
# Searching Summit, NJ for business analyst positions 	Search number 159 of 300
# The search took 2.246350049972534 seconds.
#
# Searching Summit, NJ for financial analyst positions 	Search number 160 of 300
# The search took 4.804844379425049 seconds.
#
# Searching Morristown, NJ for entry level data positions 	Search number 161 of 300
# The search took 0.6606123447418213 seconds.
#
# Searching Morristown, NJ for entry level data analyst positions 	Search number 162 of 300
# The search took 0.793593168258667 seconds.
#
# Searching Morristown, NJ for entry level data scientist positions 	Search number 163 of 300
# The search took 0.6961255073547363 seconds.
#
# Searching Morristown, NJ for entry level business analyst positions 	Search number 164 of 300
# The search took 0.8256783485412598 seconds.
#
# Searching Morristown, NJ for entry level financial analyst positions 	Search number 165 of 300
# The search took 0.6430888175964355 seconds.
#
# Searching Morristown, NJ for junior data positions 	Search number 166 of 300
# The search took 0.7611551284790039 seconds.
#
# Searching Morristown, NJ for junior data analyst positions 	Search number 167 of 300
# The search took 0.8228762149810791 seconds.
#
# Searching Morristown, NJ for junior data scientist positions 	Search number 168 of 300
# The search took 0.6640708446502686 seconds.
#
# Searching Morristown, NJ for junior business analyst positions 	Search number 169 of 300
# The search took 0.8644740581512451 seconds.
#
# Searching Morristown, NJ for junior financial analyst positions 	Search number 170 of 300
# The search took 1.3743751049041748 seconds.
#
# Searching Morristown, NJ for associate data positions 	Search number 171 of 300
# The search took 0.8927562236785889 seconds.
#
# Searching Morristown, NJ for associate data analyst positions 	Search number 172 of 300
# The search took 0.705547571182251 seconds.
#
# Searching Morristown, NJ for associate data scientist positions 	Search number 173 of 300
# The search took 0.8153610229492188 seconds.
#
# Searching Morristown, NJ for associate business analyst positions 	Search number 174 of 300
# The search took 0.9483797550201416 seconds.
#
# Searching Morristown, NJ for associate financial analyst positions 	Search number 175 of 300
# The search took 3.720489501953125 seconds.
#
# Searching Morristown, NJ for data positions 	Search number 176 of 300
# The search took 89.59825897216797 seconds.
#
# Searching Morristown, NJ for data analyst positions 	Search number 177 of 300
# The search took 22.44587993621826 seconds.
#
# Searching Morristown, NJ for data scientist positions 	Search number 178 of 300
# The search took 23.507452487945557 seconds.
#
# Searching Morristown, NJ for business analyst positions 	Search number 179 of 300
# The search took 11.9919114112854 seconds.
#
# Searching Morristown, NJ for financial analyst positions 	Search number 180 of 300
# The search took 8.861390352249146 seconds.
#
# Searching Edison, NJ for entry level data positions 	Search number 181 of 300
# The search took 1.0124831199645996 seconds.
#
# Searching Edison, NJ for entry level data analyst positions 	Search number 182 of 300
# The search took 0.9499917030334473 seconds.
#
# Searching Edison, NJ for entry level data scientist positions 	Search number 183 of 300
# The search took 0.7063412666320801 seconds.
#
# Searching Edison, NJ for entry level business analyst positions 	Search number 184 of 300
# The search took 0.9772367477416992 seconds.
#
# Searching Edison, NJ for entry level financial analyst positions 	Search number 185 of 300
# The search took 0.7461390495300293 seconds.
#
# Searching Edison, NJ for junior data positions 	Search number 186 of 300
# The search took 1.4704267978668213 seconds.
#
# Searching Edison, NJ for junior data analyst positions 	Search number 187 of 300
# The search took 0.9715945720672607 seconds.
#
# Searching Edison, NJ for junior data scientist positions 	Search number 188 of 300
# The search took 0.8653013706207275 seconds.
#
# Searching Edison, NJ for junior business analyst positions 	Search number 189 of 300
# The search took 0.8521938323974609 seconds.
#
# Searching Edison, NJ for junior financial analyst positions 	Search number 190 of 300
# The search took 0.9193406105041504 seconds.
#
# Searching Edison, NJ for associate data positions 	Search number 191 of 300
# The search took 1.61846923828125 seconds.
#
# Searching Edison, NJ for associate data analyst positions 	Search number 192 of 300
# The search took 1.0168168544769287 seconds.
#
# Searching Edison, NJ for associate data scientist positions 	Search number 193 of 300
# The search took 1.3680241107940674 seconds.
#
# Searching Edison, NJ for associate business analyst positions 	Search number 194 of 300
# The search took 0.9681961536407471 seconds.
#
# Searching Edison, NJ for associate financial analyst positions 	Search number 195 of 300
# The search took 1.6682429313659668 seconds.
#
# Searching Edison, NJ for data positions 	Search number 196 of 300
# The search took 8.156216144561768 seconds.
#
# Searching Edison, NJ for data analyst positions 	Search number 197 of 300
# The search took 2.5028910636901855 seconds.
#
# Searching Edison, NJ for data scientist positions 	Search number 198 of 300
# The search took 6.832616567611694 seconds.
#
# Searching Edison, NJ for business analyst positions 	Search number 199 of 300
# The search took 8.832708835601807 seconds.
#
# Searching Edison, NJ for financial analyst positions 	Search number 200 of 300
# The search took 2.102283477783203 seconds.
#
# Searching Metuchen, NJ for entry level data positions 	Search number 201 of 300
# The search took 1.0212478637695312 seconds.
#
# Searching Metuchen, NJ for entry level data analyst positions 	Search number 202 of 300
# The search took 0.8435122966766357 seconds.
#
# Searching Metuchen, NJ for entry level data scientist positions 	Search number 203 of 300
# The search took 0.78564453125 seconds.
#
# Searching Metuchen, NJ for entry level business analyst positions 	Search number 204 of 300
# The search took 0.9118216037750244 seconds.
#
# Searching Metuchen, NJ for entry level financial analyst positions 	Search number 205 of 300
# The search took 0.782128095626831 seconds.
#
# Searching Metuchen, NJ for junior data positions 	Search number 206 of 300
# The search took 0.7648813724517822 seconds.
#
# Searching Metuchen, NJ for junior data analyst positions 	Search number 207 of 300
# The search took 0.8852460384368896 seconds.
#
# Searching Metuchen, NJ for junior data scientist positions 	Search number 208 of 300
# The search took 0.8770341873168945 seconds.
#
# Searching Metuchen, NJ for junior business analyst positions 	Search number 209 of 300
# The search took 0.9575047492980957 seconds.
#
# Searching Metuchen, NJ for junior financial analyst positions 	Search number 210 of 300
# The search took 0.9589784145355225 seconds.
#
# Searching Metuchen, NJ for associate data positions 	Search number 211 of 300
# The search took 1.2604753971099854 seconds.
#
# Searching Metuchen, NJ for associate data analyst positions 	Search number 212 of 300
# The search took 1.1157903671264648 seconds.
#
# Searching Metuchen, NJ for associate data scientist positions 	Search number 213 of 300
# The search took 1.4656331539154053 seconds.
#
# Searching Metuchen, NJ for associate business analyst positions 	Search number 214 of 300
# The search took 0.9344010353088379 seconds.
#
# Searching Metuchen, NJ for associate financial analyst positions 	Search number 215 of 300
# The search took 1.3114962577819824 seconds.
#
# Searching Metuchen, NJ for data positions 	Search number 216 of 300
# The search took 5.114853620529175 seconds.
#
# Searching Metuchen, NJ for data analyst positions 	Search number 217 of 300
# The search took 2.4328219890594482 seconds.
#
# Searching Metuchen, NJ for data scientist positions 	Search number 218 of 300
# The search took 2.145277976989746 seconds.
#
# Searching Metuchen, NJ for business analyst positions 	Search number 219 of 300
# The search took 2.2901179790496826 seconds.
#
# Searching Metuchen, NJ for financial analyst positions 	Search number 220 of 300
# The search took 2.129429340362549 seconds.
#
# Searching Hackensack, NJ for entry level data positions 	Search number 221 of 300
# The search took 5.685357570648193 seconds.
#
# Searching Hackensack, NJ for entry level data analyst positions 	Search number 222 of 300
# The search took 0.8628592491149902 seconds.
#
# Searching Hackensack, NJ for entry level data scientist positions 	Search number 223 of 300
# The search took 0.8327655792236328 seconds.
#
# Searching Hackensack, NJ for entry level business analyst positions 	Search number 224 of 300
# The search took 1.1268310546875 seconds.
#
# Searching Hackensack, NJ for entry level financial analyst positions 	Search number 225 of 300
# The search took 0.6969850063323975 seconds.
#
# Searching Hackensack, NJ for junior data positions 	Search number 226 of 300
# The search took 0.8586044311523438 seconds.
#
# Searching Hackensack, NJ for junior data analyst positions 	Search number 227 of 300
# The search took 1.2574236392974854 seconds.
#
# Searching Hackensack, NJ for junior data scientist positions 	Search number 228 of 300
# The search took 0.8174045085906982 seconds.
#
# Searching Hackensack, NJ for junior business analyst positions 	Search number 229 of 300
# The search took 0.9598307609558105 seconds.
#
# Searching Hackensack, NJ for junior financial analyst positions 	Search number 230 of 300
# The search took 0.7833456993103027 seconds.
#
# Searching Hackensack, NJ for associate data positions 	Search number 231 of 300
# The search took 1.1249258518218994 seconds.
#
# Searching Hackensack, NJ for associate data analyst positions 	Search number 232 of 300
# The search took 3.382312536239624 seconds.
#
# Searching Hackensack, NJ for associate data scientist positions 	Search number 233 of 300
# The search took 1.3596413135528564 seconds.
#
# Searching Hackensack, NJ for associate business analyst positions 	Search number 234 of 300
# The search took 0.9242115020751953 seconds.
#
# Searching Hackensack, NJ for associate financial analyst positions 	Search number 235 of 300
# The search took 1.0468413829803467 seconds.
#
# Searching Hackensack, NJ for data positions 	Search number 236 of 300
# The search took 25.4526309967041 seconds.
#
# Searching Hackensack, NJ for data analyst positions 	Search number 237 of 300
# The search took 2.3453235626220703 seconds.
#
# Searching Hackensack, NJ for data scientist positions 	Search number 238 of 300
# The search took 6.615076303482056 seconds.
#
# Searching Hackensack, NJ for business analyst positions 	Search number 239 of 300
# The search took 7.057054281234741 seconds.
#
# Searching Hackensack, NJ for financial analyst positions 	Search number 240 of 300
# The search took 6.504386901855469 seconds.
#
# Searching Stamford, CT for entry level data positions 	Search number 241 of 300
# The search took 3.045168161392212 seconds.
#
# Searching Stamford, CT for entry level data analyst positions 	Search number 242 of 300
# The search took 3.1329424381256104 seconds.
#
# Searching Stamford, CT for entry level data scientist positions 	Search number 243 of 300
# The search took 0.7500920295715332 seconds.
#
# Searching Stamford, CT for entry level business analyst positions 	Search number 244 of 300
# The search took 0.9509782791137695 seconds.
#
# Searching Stamford, CT for entry level financial analyst positions 	Search number 245 of 300
# The search took 0.6342716217041016 seconds.
#
# Searching Stamford, CT for junior data positions 	Search number 246 of 300
# The search took 0.8763928413391113 seconds.
#
# Searching Stamford, CT for junior data analyst positions 	Search number 247 of 300
# The search took 0.7984209060668945 seconds.
#
# Searching Stamford, CT for junior data scientist positions 	Search number 248 of 300
# The search took 0.6807703971862793 seconds.
#
# Searching Stamford, CT for junior business analyst positions 	Search number 249 of 300
# The search took 1.063993215560913 seconds.
#
# Searching Stamford, CT for junior financial analyst positions 	Search number 250 of 300
# The search took 0.6794745922088623 seconds.
#
# Searching Stamford, CT for associate data positions 	Search number 251 of 300
# The search took 2.9162042140960693 seconds.
#
# Searching Stamford, CT for associate data analyst positions 	Search number 252 of 300
# The search took 5.5425896644592285 seconds.
#
# Searching Stamford, CT for associate data scientist positions 	Search number 253 of 300
# The search took 1.5617494583129883 seconds.
#
# Searching Stamford, CT for associate business analyst positions 	Search number 254 of 300
# The search took 0.7670979499816895 seconds.
#
# Searching Stamford, CT for associate financial analyst positions 	Search number 255 of 300
# The search took 5.274121284484863 seconds.
#
# Searching Stamford, CT for data positions 	Search number 256 of 300
# The search took 233.08297681808472 seconds.
#
# Searching Stamford, CT for data analyst positions 	Search number 257 of 300
# The search took 60.7913019657135 seconds.
#
# Searching Stamford, CT for data scientist positions 	Search number 258 of 300
# The search took 21.63180947303772 seconds.
#
# Searching Stamford, CT for business analyst positions 	Search number 259 of 300
# The search took 19.32399034500122 seconds.
#
# Searching Stamford, CT for financial analyst positions 	Search number 260 of 300
# The search took 6.116993188858032 seconds.
#
# Searching Greenwich, CT for entry level data positions 	Search number 261 of 300
# The search took 1.2533643245697021 seconds.
#
# Searching Greenwich, CT for entry level data analyst positions 	Search number 262 of 300
# The search took 1.3547747135162354 seconds.
#
# Searching Greenwich, CT for entry level data scientist positions 	Search number 263 of 300
# The search took 0.78271484375 seconds.
#
# Searching Greenwich, CT for entry level business analyst positions 	Search number 264 of 300
# The search took 0.7444825172424316 seconds.
#
# Searching Greenwich, CT for entry level financial analyst positions 	Search number 265 of 300
# The search took 0.7168927192687988 seconds.
#
# Searching Greenwich, CT for junior data positions 	Search number 266 of 300
# The search took 0.6970207691192627 seconds.
#
# Searching Greenwich, CT for junior data analyst positions 	Search number 267 of 300
# The search took 0.840919017791748 seconds.
#
# Searching Greenwich, CT for junior data scientist positions 	Search number 268 of 300
# The search took 0.6718940734863281 seconds.
#
# Searching Greenwich, CT for junior business analyst positions 	Search number 269 of 300
# The search took 0.8162455558776855 seconds.
#
# Searching Greenwich, CT for junior financial analyst positions 	Search number 270 of 300
# The search took 0.785954475402832 seconds.
#
# Searching Greenwich, CT for associate data positions 	Search number 271 of 300
# The search took 1.1239724159240723 seconds.
#
# Searching Greenwich, CT for associate data analyst positions 	Search number 272 of 300
# The search took 0.8213346004486084 seconds.
#
# Searching Greenwich, CT for associate data scientist positions 	Search number 273 of 300
# The search took 0.9804975986480713 seconds.
#
# Searching Greenwich, CT for associate business analyst positions 	Search number 274 of 300
# The search took 0.7379443645477295 seconds.
#
# Searching Greenwich, CT for associate financial analyst positions 	Search number 275 of 300
# The search took 0.8320682048797607 seconds.
#
# Searching Greenwich, CT for data positions 	Search number 276 of 300
# The search took 32.62143659591675 seconds.
#
# Searching Greenwich, CT for data analyst positions 	Search number 277 of 300
# The search took 34.67682504653931 seconds.
#
# Searching Greenwich, CT for data scientist positions 	Search number 278 of 300
# The search took 38.727749824523926 seconds.
#
# Searching Greenwich, CT for business analyst positions 	Search number 279 of 300
# The search took 27.048507928848267 seconds.
#
# Searching Greenwich, CT for financial analyst positions 	Search number 280 of 300
# The search took 27.85036039352417 seconds.
#
# Searching remote for entry level data positions 	Search number 281 of 300
# The search took 3.010439872741699 seconds.
#
# Searching remote for entry level data analyst positions 	Search number 282 of 300
# The search took 0.6866650581359863 seconds.
#
# Searching remote for entry level data scientist positions 	Search number 283 of 300
# The search took 30.50328826904297 seconds.
#
# Searching remote for entry level business analyst positions 	Search number 284 of 300
# The search took 3.0355706214904785 seconds.
#
# Searching remote for entry level financial analyst positions 	Search number 285 of 300
# The search took 16.985835075378418 seconds.
#
# Searching remote for junior data positions 	Search number 286 of 300
# The search took 1.3924736976623535 seconds.
#
# Searching remote for junior data analyst positions 	Search number 287 of 300
# The search took 0.6059255599975586 seconds.
#
# Searching remote for junior data scientist positions 	Search number 288 of 300
# The search took 0.6220333576202393 seconds.
#
# Searching remote for junior business analyst positions 	Search number 289 of 300
# The search took 0.676084041595459 seconds.
#
# Searching remote for junior financial analyst positions 	Search number 290 of 300
# The search took 0.805161714553833 seconds.
#
# Searching remote for associate data positions 	Search number 291 of 300
# The search took 5.001335620880127 seconds.
#
# Searching remote for associate data analyst positions 	Search number 292 of 300
# The search took 2.859663963317871 seconds.
#
# Searching remote for associate data scientist positions 	Search number 293 of 300
# The search took 1.3046324253082275 seconds.
#
# Searching remote for associate business analyst positions 	Search number 294 of 300
# The search took 3.3382914066314697 seconds.
#
# Searching remote for associate financial analyst positions 	Search number 295 of 300
# The search took 0.6138684749603271 seconds.
#
# Searching remote for data positions 	Search number 296 of 300
# The search took 236.01415467262268 seconds.
#
# Searching remote for data analyst positions 	Search number 297 of 300
# The search took 40.96826171875 seconds.
#
# Searching remote for data scientist positions 	Search number 298 of 300
# The search took 29.01782202720642 seconds.
#
# Searching remote for business analyst positions 	Search number 299 of 300
# The search took 58.16767454147339 seconds.
#
# Searching remote for financial analyst positions 	Search number 300 of 300
# Monster search took 3572.887889146805 seconds to retreive 1376 total results (including some duplicates).
# Returned 1376 unique entries from Monster.com

# %%
df_0 = pd.concat([indeed_1, monster_1], ignore_index=True)
df_1 = df_0.drop_duplicates(subset=['description'])
# df = PreprocessJobs(df)
print('Both pre duplicate removal:', len(df_0), '\n', 'Post duplicate removal:', len(df_1))

df = df_1

# %%
df['description'] = df['description'].str.replace(',', ' ')

# %%
df.to_csv('data/' + datetime.today().strftime("%Y-%m-%d") + '_recentjobs.tsv', sep='\t', index=False)
