# %%
from os import listdir, path
import pandas as pd
import time
import re
from nltk import *
from nltk.collocations import BigramCollocationFinder, TrigramCollocationFinder
from nltk.metrics import BigramAssocMeasures, TrigramAssocMeasures
from nltk.corpus import stopwords
from IPython.display import clear_output
import numpy
import matplotlib.pyplot as plt

# %%
try:
    df
except:
    df = pd.DataFrame(columns=['posting_id', 'search_title', 'search_location', 'location', 'title',
       'company', 'posted', 'salary', 'summary', 'link', 'description'])

def sort_jobs(df, posting_number):
    """Prompt user for response, use the response to place posting_number into an array"""
    job_status = input('Is this a job you would want to apply to? (y/n/u/o) \n(u is yes but underqualified, o is none of the above.)')
    if job_status.lower() in ['yes', 'yeah', 'y']:
        yes.append(posting_number)
        print(df.link[posting_number])
    elif job_status.lower() in ['no', 'nah', 'n']:
        no.append(posting_number)
    elif job_status.lower() in ['maybe', 'm', 'other', 'o']:
        other.append(posting_number)
    elif job_status.lower() in ['underqualified', 'u']:
        underqualified.append(posting_number)
    elif job_status.lower() == 'ty':
        yes_test.append(posting_number)
    elif job_status.lower() == 'tn':
        no_test.append(posting_number)

def job_post_info(posting_number: int, df = df, n_results_per: int = 10, sorting: bool = True):
    '''
        Print important bigrams and trigrams and the job description
        0. Assemble stopword set
        1. Tokenize Sentences
        2. Remove sentences with particular words 
        3. Tokenize words from remaining sentences
        4. Remove stopwords
        5. Print collection of important bigrams and trigrams from remaining words
        6. Print the entire job description
        7. If we are sorting:
            7a. Prompt user to determine whether it's a yes, a no, a job the user is 
                underqualified for, or other
            7b. Depending on user's response append post index to appropriate list
    ''' 
    # Stopwords
    stopset = set(stopwords.words('english') + word_tokenize(df.company[posting_number].lower()))

    # Tokenize and remove sentences
    sentences = sent_tokenize(df.description[posting_number])
    sentences = [sentence for sentence in sentences if not [p for p in ['equal opportunity', 'not discriminate', 'diversity', 'affirmative action', 'gender', 'eoe'] if p  in sentence.lower()]]

    # Tokenize words
    words = [word for words in sentences for word in word_tokenize(words.lower()) if word not in stopset]
    words = [word for word in words if (word.isalpha() or word.isnumeric()) and (len(word) < 2 or len(word) > 3)]

    # Bigrams and Trigrams
    bcf = BigramCollocationFinder.from_words(words)
    tcf = TrigramCollocationFinder.from_words(words)
    # Print company and job title
    print(df.company[posting_number])
    print(df.title[posting_number])
    print("Location:", df.location[posting_number], "\n")
    # print bigrams
    print('Bigrams')
    print(set(bcf.nbest(BigramAssocMeasures.likelihood_ratio, n_results_per) + bcf.nbest(BigramAssocMeasures.raw_freq, n_results_per) + bcf.nbest(BigramAssocMeasures.chi_sq, n_results_per)), "\n")
    # Print Trigrams
    print('Trigrams')
    print(set(tcf.nbest(TrigramAssocMeasures.likelihood_ratio, n_results_per) + tcf.nbest(TrigramAssocMeasures.raw_freq, n_results_per) + tcf.nbest(TrigramAssocMeasures.chi_sq, n_results_per)), "\n")
    # Print Description
    print(df.description[posting_number])
    # If we are sorting them to train an algo
    if sorting:
        # If we are sorting through them
        sort_jobs(df, posting_number)

# %% [markdown]
# ## Initialize empty job index containers.
# These take the index position of the jobs in the data frame. Later they are used to form yes, no, and undequalified labels to train an algorithm.

# %%
##################################################################
#                                                                #
# MAKE SURE PREVIOUS DATA HAS BEEN WRITTEN BEFORE CLEARING !!!!! #
#                                                                #
##################################################################
yes = []
no = []
underqualified = []
other = []

# %% [markdown]
# ## Import job post data frame

# %%
# List the files in the shared drive to see which ones we want to load
listdir('Z:/data/')
# Out:
# ['0rawdata',
#  '2020-11-11_recentjobs.tsv',
#  '2021-01-18_monster.csv',
#  '2021-01-25_monsterScraped.csv',
#  '2021-01-26_monsterScraped.csv',
#  '2021-01-27_monsterScraped.csv',
#  '2021-01-31_monsterScraped.csv',
#  '2021-02-04_monsterScraped.csv',
#  '2021-02-05_monsterScraped.csv',
#  '2021-02-09_monster.csv',
#  '2021-02-09_monsterScraped.csv',
#  '2021-02-10_indeed.csv',
#  '2021-02-11_indeed.csv',
#  '2021-02-11_monsterScraped.csv',
#  '2021-02-12_indeed.csv',
#  '2021-02-13_indeed.csv',
#  '2021-02-16_indeed.csv',
#  '2021-02-17_indeed.csv',
#  '2021-02-17_monsterScraped.csv',
#  '2021-02-18_monster.csv',
#  '2021-02-20_indeed.csv',
#  '2021-02-21_indeed.csv',
#  '2021-03-07_indeed.csv',
#  '2021-03-07_monster.csv']

# %%
#########################################################
##########################################################
############### THIS CELL IS FOR RAW DATA ONLY!!!! ###########
#####################################################
# Import raw files and clean them up

# Set how many of the most recent files to include
last_n_files = 2

# Get the files from the shared directory
shared_drive = 'Z:/data/0rawdata/'

shared_files = listdir(shared_drive)[-last_n_files:]
df_0 = pd.DataFrame()
for our_file in shared_files:
    print("Loading", our_file)
    df_0 = pd.concat([df_0, pd.read_csv(shared_drive + our_file)], ignore_index=True)

print("Data Loaded")
# Out:
# Loading 2021-03-07_indeed.csv
# Loading 2021-03-07_monster.csv
# Data Loaded

# %%
#######################################################################################################
# Import most recent scraped file from the shared drive then clean the data so we can look through it #
#######################################################################################################

# Set how many of the most recent files to include
last_n_files = 2

# Get the files from the shared directory
shared_drive = 'Z:/data/'
shared_files = listdir(shared_drive)[-last_n_files:]
df_0 = pd.DataFrame()
for our_file in shared_files:
    print("Loading", our_file)
    df_0 = pd.concat([df_0, pd.read_csv(shared_drive + our_file)], ignore_index=True)

print("Data Loaded")
# Out:
# Loading 2021-03-07_indeed.csv
# Loading 2021-03-07_monster.csv
# Data Loaded

# %%
if "unnamed: 0" in df_0.columns.str.lower():
    df1 = df_0.loc[:, df_0.columns != "unnamed: 0"]
else:
    df1 = df_0
df1.columns = df1.columns.str.lower()
df1 = df1.drop_duplicates(subset=['description'], keep = 'first')
df1.description = df1.description.str.replace('A/R', 'AR')
df1.posted = pd.to_numeric(df1.posted,'coerce')
if df1.shape[1] == 11:
    for col in df1.columns[list(range(5)) + [10]]:
        df1[col] = df1[col].str.replace('\n', ' ').str.replace('\r', ' ').str.replace('/', ' ').str.replace(',', ' ')
else:
    for col in df1.columns[list(range(5)) + [9]]:
        df1[col] = df1[col].str.replace('\n', ' ').str.replace('\r', ' ').str.replace('/', ' ').str.replace(',', ' ')


df1.description = df1.description.str.replace(r"([a-z])([A-Z])", r"\1 \.\2").str.replace(r' \\.', '')
df1.description = df1.description.str.replace('Description', '')
df1 = df1.dropna(subset=['description'])
df1.sort_values('posted')
# Out:
#           search_title search_location            location  \
# 456     data scientist    New York  NY        New York  NY
# 1154              data  Morristown  NJ          Rahway  NJ
# 1538              data          remote          Remote  TX
# 553   business analyst    New York  NY        New York  NY
# 1167      data analyst  Morristown  NJ  Franklin Lakes  NJ
# ...                ...             ...                 ...
# 521   business analyst    New York  NY        New York  NY
# 527   business analyst    New York  NY   New York City  NY
# 528   business analyst    New York  NY          Newark  NJ
# 487     data scientist    New York  NY          Newark  NJ
# 0     entry level data    New York  NY                 NaN
#
#                                                   title  \
# 456                                      VP Engineering
# 1154                      HR Business Partner - Biotech
# 1538                        VP Global Sales Engineering
# 553                         Financial Technical Analyst
# 1167                           Microstrategy Consultant
# ...                                                 ...
# 521                             Senior Business Analyst
# 527                                    Business Analyst
# 528                  Project - Business Systems Analyst
# 487   Business Support Specialist - Customer Operations
# 0                     Entry Level Financial Analyst new
#
#                               company  posted          salary  \
# 456                              Away       0             NaN
# 1154              Nesco Resource  LLC       0             NaN
# 1538                           Actian       0             NaN
# 553   Yoh  A Day & Zimmermann Company       0             NaN
# 1167                        Mindlance       0             NaN
# ...                               ...     ...             ...
# 521                    Eliassen Group       5             NaN
# 527                      Apex Systems       5             NaN
# 528                              PSEG       5             NaN
# 487                              PSEG       5             NaN
# 0                         Precise Int       5  $51,000 a year
#
#                                                 summary  \
# 456                                                 NaN
# 1154                         Job Typefulltime, contract
# 1538                                                NaN
# 553                                                 NaN
# 1167                                                NaN
# ...                                                 ...
# 521                          Job Typefulltime, employee
# 527                          Job Typefulltime, employee
# 528                          Job Typefulltime, employee
# 487                          Job Typefulltime, employee
# 0     Mapping and analyzing quantitative data. An in...
#
#                                                    link  \
# 456   https://job-openings.monster.com/vp-engineerin...
# 1154  https://job-openings.monster.com/hr-business-p...
# 1538  https://job-openings.monster.com/vp-global-sal...
# 553   https://job-openings.monster.com/financial-tec...
# 1167  https://job-openings.monster.com/microstrategy...
# ...                                                 ...
# 521   https://job-openings.monster.com/senior-busine...
# 527   https://job-openings.monster.com/business-anal...
# 528   https://job-openings.monster.com/project-busin...
# 487   https://job-openings.monster.com/business-supp...
# 0     https://www.indeed.com/pagead/clk?mo=r&ad=-6NY...
#
#                                             description
# 456   Company is seeking a forward-thinking VP of En...
# 1154  Education:  • Minimum of a Bachelor degree in ...
# 1538  Company is looking for a Vice President of Glo...
# 553   Right to Hire Location: NY  Boston  Houston  R...
# 1167  Position :Microstrategy ConsultantLocation : F...
# ...                                                 ...
# 521    Job Our industry-leading financial services c...
# 527   Apex Systems combines with parent company On A...
# 528   Requisition ID:  62441  Job Function Category:...
# 487   Requisition ID: 64377 Job Function Category: C...
# 0     Background Summary: An international Financial...
#
# [1460 rows x 10 columns]

# %%
# Using the cleaned data, drop what we have already sorted
# create the sorting list from the remaining posts 
# then display that at the bottom

df = df1.drop(yes)
df = df.drop(no)
df = df.drop(other)
df = df.drop(underqualified)

sl = df[
  # df.description.str.lower().str.contains('scrap')
    # ~df.salary.str.lower().str.contains('no')
    # df.description.str.lower().str.contains('math')
     (
        df.description.str.lower().str.contains('python') 
       | df.description.str.lower().str.contains(' r ')
     )
    #  df.description.str.lower().str.contains('sql')
    # & df.description.str.lower().str.contains('')
    & ~df.company.str.lower().str.contains('jpm', na=False)
    & (
        df.title.str.lower().str.contains('assoc') 
      | df.title.str.lower().str.contains('junior')
      | df.title.str.lower().str.contains('jr')
      | df.title.str.lower().str.contains('entry')
      # | df.title.str.lower().str.contains('intern')
      )
    & ~(
        df.title.str.lower().str.contains('lead')
      | df.title.str.lower().str.contains('manager')
      | df.title.str.lower().str.contains('vp')
      | df.title.str.lower().str.contains('vice')
      | df.title.str.lower().str.contains('senior')
      | df.title.str.lower().str.contains('sr')
      | df.title.str.lower().str.contains('principal')
      | df.title.str.lower().str.contains('director')
      )
      & ~df.company.str.lower().str.contains('cobble', na=False)
    # & ~(
    #   df.location.str.contains('DE')
    #   | df.location.str.contains('NH')
    #   | df.location.str.contains('PA')
    # )
    # & (df['posted'] < 31)
].sort_values('posted')
sl
# Out:
#                   search_title  search_location  \
# 20            entry level data     New York  NY
# 191           entry level data     New York  NY
# 1488          entry level data           remote
# 192           entry level data     New York  NY
# 205      junior data scientist     New York  NY
# 212             associate data     New York  NY
# 239   associate data scientist     New York  NY
# 242   associate data scientist     New York  NY
# 108                junior data     New York  NY
# 636      junior data scientist       Newark  NJ
# 1193                      data       Edison  NJ
# 97                 junior data     New York  NY
# 124        junior data analyst     New York  NY
# 234   associate data scientist     New York  NY
# 1036                      data  Bridgewater  NJ
# 1342                      data     Stamford  CT
#
#                                     location  \
# 20                              New York  NY
# 191                             New York  NY
# 1488             DC Remote Office (DC99)  DC
# 192                             New York  NY
# 205   New York City  New York  United States
# 212                             Brooklyn  NY
# 239                             New York  NY
# 242                             New York  NY
# 108                             New York  NY
# 636                        New Brunswick  NJ
# 1193                 Monmouth (Township)  IL
# 97         New York  NY 10018 (Clinton area)
# 124                                      NaN
# 234                             New York  NY
# 1036                            Somerset  NJ
# 1342                           Greenwich  CT
#
#                                                   title  \
# 20              Junior Data Analyst - Consumer Team new
# 191            Junior Data Scientist (New York  NY  US)
# 1488                     Junior Business   Data Analyst
# 192                 Junior Data Analyst - Consumer Team
# 205                           Junior Analytics Engineer
# 212                           Associate  Data Analytics
# 239   Adjunct Associate Faculty  Applied Analytics F...
# 242   Adjunct Associate Faculty  Anomaly Detection (...
# 108   Jr. Software Data Engineers (AWS Data Engineer...
# 636   Postdoctoral Quantitative Scientist - Junior P...
# 1193              Data Analyst (Entry)-Data Science-R&D
# 97                  Junior Computer Vision Engineer new
# 124                  Jr. Data Analyst (Python  SQL) new
# 234                                           Associate
# 1036   Project - Associate Technology Software Engineer
# 1342                               Junior C++ developer
#
#                                    company  posted                    salary  \
# 20                                Balyasny       2                       NaN
# 191                     Mars  Incorporated       2                       NaN
# 1488             102 ICF Incorporated  LLC       2                       NaN
# 192   Balyasny Asset Management L.P. (BAM)       3                       NaN
# 205                         Signify Health       3                       NaN
# 212                 StrongArm Technologies       3                       NaN
# 239                    Columbia University       3                       NaN
# 242                    Columbia University       3                       NaN
# 108                     Quintrix Solutions       4  $55,000 - $57,000 a year
# 636                 Alpha Consulting Corp.       4                       NaN
# 1193                       The Judge Group       4                       NaN
# 97                                   Caper       5                       NaN
# 124                     Eight Eleven Group       5         $24 - $25 an hour
# 234                Goldman Sachs & Co. LLC       5                       NaN
# 1036                                  PSEG       5                       NaN
# 1342               Interactive Brokers LLC       5                       NaN
#
#                                                 summary  \
# 20    Strong analytical and data processing skills (...
# 191                                                 NaN
# 1488                                                NaN
# 192                                                 NaN
# 205                                                 NaN
# 212                                                 NaN
# 239                                                 NaN
# 242                                                 NaN
# 108   /week) of pre- employment online training that...
# 636                          Job Typefulltime, contract
# 1193                         Job Typefulltime, contract
# 97    Strong knowledge of computer science fundament...
# 124   Work within Alteryx to extract, manipulate and...
# 234                          Job Typefulltime, employee
# 1036                         Job Typefulltime, employee
# 1342                                                NaN
#
#                                                    link  \
# 20    https://www.indeed.com/rc/clk?jk=d28e651b6effe...
# 191   https://job-openings.monster.com/junior-data-s...
# 1488  https://job-openings.monster.com/junior-busine...
# 192   https://job-openings.monster.com/junior-data-a...
# 205   https://job-openings.monster.com/junior-analyt...
# 212   https://job-openings.monster.com/associate-dat...
# 239   https://job-openings.monster.com/adjunct-assoc...
# 242   https://job-openings.monster.com/adjunct-assoc...
# 108   https://www.indeed.com/company/Quintrix-Soluti...
# 636   https://job-openings.monster.com/postdoctoral-...
# 1193  https://job-openings.monster.com/data-analyst-...
# 97    https://www.indeed.com/rc/clk?jk=8c0d953fc69e5...
# 124   https://www.indeed.com/pagead/clk?mo=r&ad=-6NY...
# 234   https://job-openings.monster.com/associate-new...
# 1036  https://job-openings.monster.com/project-assoc...
# 1342  https://job-openings.monster.com/junior-c-deve...
#
#                                             description
# 20    We are looking for an exceptional data analyst...
# 191   A mutually rewarding experience.Work. Realize ...
# 1488  ICF is looking for a Junior Business Analyst D...
# 192   The Job Details are as follows:OVERVIEWWe are ...
# 205   How will this role have an impact? The Analyti...
# 212   POSITION OVERVIEW:As a Data Analytics Associat...
# 239   Company Columbia University has been a leader ...
# 242   Company Columbia University has been a leader ...
# 108   Quintrix is on the lookout for software data e...
# 636   POSTDOCTORAL QUANTITATIVE SCIENTIST – JUNIOR P...
# 1193  Location:  Monmouth (Township)  IL:  Our clien...
# 97    About Us: Caper builds smart shopping carts po...
# 124   Junior Data AnalystParsippany  NJ areaLong-ter...
# 234   Associate with Goldman Sachs & Co. LLC in New ...
# 1036  Requisition ID:  55017  Job Function Category:...
# 1342  Join the INTERACTIVE BROKERS Team! Interactive...

# %%
"""
If we put together a list of posts to go through:
    1. Clear previous output
    2. Show the post info and sort the job
"""

for post in sl.index[:5]:
    clear_output()
    job_post_info(post, df=df)
    input()
# Out:
# Mars  Incorporated
# Junior Data Scientist (New York  NY  US)
# Location: New York  NY
#
# Bigrams
# {('ambitions', 'realize'), ('years', 'experience'), ('ambition', 'makes'), ('accommodation', 'application'), ('applicant', 'penalized'), ('application', 'process'), ('ability', 'work'), ('around', 'planet'), ('also', 'provides'), ('bachelor', 'degree'), ('always', 'incorporatedmars'), ('available', 'upon'), ('almost', 'billion'), ('analytics', 'data'), ('also', 'build'), ('basic', 'probability')}
#
# Trigrams
# {('always', 'incorporatedmars', 'business'), ('blue', 'headquartered', 'mclean'), ('applicant', 'penalized', 'result'), ('around', 'planet', 'challenging'), ('years', 'experience', 'understanding'), ('also', 'build', 'enlightened'), ('also', 'provides', 'veterinary'), ('brand', 'grab', 'everything'), ('ambitions', 'realize', 'business'), ('ability', 'work', 'large'), ('pandas', 'years', 'experience'), ('years', 'experience', 'python'), ('accommodation', 'application', 'process'), ('bachelor', 'degree', 'stem'), ('ambition', 'makes', 'special'), ('application', 'process', 'disability'), ('analytics', 'data', 'science'), ('brands', 'milky', 'royal'), ('almost', 'billion', 'sales')}
#
# A mutually rewarding experience.Work. Realize your ambitions. And realize there’s more to being in business than just making a profit. That’s the Mars philosophy. And the opportunity we offer every one of our Associates. An opportunity to take what you do and make it mean more for you  for those around you and for the planet. What you get here is challenging  interesting work. You get the tools you need to do a great job and you get to have the best possible people on your side to help you do it. And at the same time as getting to find ways to do business better today than we did it yesterday and driving a great career  you also get to build a more enlightened business and drive sustainability.Because it’s never just about a single person  a single project or a single brand. It’s about how you can grab everything that’s within your reach here and use it to pursue mutual  long-term gain. It’s about having ideas. And ideals. Being prepared to risk failure because the promise of success means we’ll all be a little better off. It’s that mix of integrity and ambition that makes Mars such a special place to work. And why working here is always about more than just a job.About Mars  IncorporatedMars is a family-owned business with more than a century of history making diverse products and offering services for people and the pets people love. With almost $35 billion in sales  the company is a global business that produces some of the world’s best-loved brands: M&M’s®  SNICKERS®  TWIX®  MILKY WAY®  DOVE®  PEDIGREE®  ROYAL CANIN®  WHISKAS®  EXTRA®  ORBIT®  5™  SKITTLES®  UNCLE BEN’S®  MARS DRINKS and COCOAVIA®. Mars also provides veterinary health services that include BANFIELD® Pet Hospitals  Blue Pearl®  VCA® and Pet Partners™. Headquartered in McLean  VA  Mars operates in more than 80 countries. The Mars Five Principles – Quality  Responsibility  Mutuality  Efficiency and Freedom – inspire its more than 100 000 Associates to create value for all its partners and deliver growth they are proud of every day.Junior Data ScientistNew York  New York  What we are looking for?• Bachelor’s degree in STEM  including mathematics  statistics  economics  engineering  marketing  computer science • Experience in working with data and delivering business-changing analytics  data science and or marketing personalization (consumer- centric data)• 3+ years experience with Python (incl. pandas)  1+ years’ experience with SQL• Understanding of basic Probability and Statistics (t-tests  AB-testing)  familiarity with regression  clustering  and hypothesis testing• Ability to work with large data sets from multiple sources incl. joining  aggregating  running descriptive statistics  What would be your key responsibilities?• Use various data sources within our ecosystem  from electronic medical records to accelerometer data  to understand pet and pet care behaviors• Describe  summarize  clean  implement exploratory data analysis to raw datasets• Display curiosity and ability to learn use cases for various data points within the wider pet care industry• Use data analysis and visualizations to gain insight into business problems using datasets  some readily available  and some you create and curate yourself• Collaborate with internal and external teams to ensure we focus on pet-centric product and service recommendations and value generation Prove   Disprove hypotheses using data• Prove   Disprove hypotheses using data   Mars is an equal opportunity employer and all qualified applicants will receive consideration for employment without regard to race  color  religion  sex  sexual orientation  gender identity  national origin  disability status  protected veteran status  or any other characteristic protected by law. If you need assistance or an accommodation during the application process because of a disability  it is available upon request. The company is pleased to provide such assistance  and no applicant will be penalized as a result of such a request.

# %%
links = df_0.link[yes + underqualified]
df_0[~df_0.link.isin(links)]
# Out:
#          search_title search_location  \
# 0    entry level data    New York, NY
# 1    entry level data    New York, NY
# 2    entry level data    New York, NY
# 3    entry level data    New York, NY
# 4    entry level data    New York, NY
# ..                ...             ...
# 641              data     Trenton, NJ
# 642              data     Trenton, NJ
# 643              data     Trenton, NJ
# 644              data     Trenton, NJ
# 645              data     Trenton, NJ
#
#                                     location  \
# 0                                        NaN
# 1                                        NaN
# 2                                        NaN
# 3                                        NaN
# 4                               New York, NY
# ..                                       ...
# 641    Trenton, NJ 08611 (Chambersburg area)
# 642                        Trenton, NJ 08690
# 643  Philadelphia, PA (University City area)
# 644                            Princeton, NJ
# 645                       Florence, NJ 08518
#
#                                                  title  \
# 0                   Data Entry Analyst (Part-Time) new
# 1                              Data Entry/ Routing new
# 2                        Data Entry Clerk / Typist new
# 3                                       Data Entry new
# 4         Jr Data Analyst – Internship/Entry Level new
# ..                                                 ...
# 641               Private Investigator - Part Time new
# 642                  Principal Secondary Education new
# 643                                      SECRETARY new
# 644  Intern, Worldwide Patient Safety, BCI Pharmaco...
# 645                         Accounts Payable Clerk new
#
#                                             company  posted  \
# 0                                   Memorandum Inc.       4
# 1                             Diamond Trading Group       5
# 2                                Counsel Press Inc.       3
# 3    Catholic League for Religious and Civil Rights       1
# 4                                   CCS Global Tech       5
# ..                                              ...     ...
# 641               Meridian Investigative Group, Inc       3
# 642         Mercer County Technical School District       4
# 643                    United States Postal Service       3
# 644                            Bristol Myers Squibb       0
# 645                                    Cream O Land       3
#
#                        salary  \
# 0           Up to $15 an hour
# 1    $30,000 - $50,000 a year
# 2                         NaN
# 3                         NaN
# 4    $65,000 - $75,000 a year
# ..                        ...
# 641                       NaN
# 642                       NaN
# 643  $46,682 - $62,679 a year
# 644                       NaN
# 645                       NaN
#
#                                                summary  \
# 0    Querying for data and loading it into client r...
# 1    Enter Orders, Send to Warehouse, Route Orders,...
# 2    \* Provide data entry and other support for ke...
# 3    Data entry and tracking of all donations. The ...
# 4    Provides plan with data, reporting and analyse...
# ..                                                 ...
# 641  Ability to gather data, compile information, a...
# 642  Supplies forms for pupil accounting data such ...
# 643  Accesses, retrieves and/or updates files and o...
# 644  Support Clinical data management activities. W...
# 645  We are seeking an entry level Accounts Payable...
#
#                                                   link  \
# 0    https://www.indeed.com/pagead/clk?mo=r&ad=-6NY...
# 1    https://www.indeed.com/pagead/clk?mo=r&ad=-6NY...
# 2    https://www.indeed.com/pagead/clk?mo=r&ad=-6NY...
# 3    https://www.indeed.com/pagead/clk?mo=r&ad=-6NY...
# 4    https://www.indeed.com/company/CCS-Global-Tech...
# ..                                                 ...
# 641  https://www.indeed.com/rc/clk?jk=b745a4337c053...
# 642  https://www.indeed.com/rc/clk?jk=af40f34e6c8b2...
# 643  https://www.indeed.com/rc/clk?jk=d065c63c966e1...
# 644  https://www.indeed.com/rc/clk?jk=25f58910896d4...
# 645  https://www.indeed.com/rc/clk?jk=7b5e1420fc442...
#
#                                            description
# 0    Data Entry Analyst (Part-Time)Memo, NYC_______...
# 1    Enter Orders, Send to Warehouse, Route Orders,...
# 2    Data Entry Clerk / TypistPlease note that any ...
# 3    Job Description  Summary of Position: The Cath...
# 4    Responsibilities: · Provides plan with data, r...
# ..                                                 ...
# 641  Description:  SUMMARY: Conduct various types o...
# 642  QUALIFICATIONS: Valid New Jersey Principal Cer...
# 643  United States Postal Service External Publicat...
# 644  At Bristol Myers Squibb, we are inspired by a ...
# 645  If you need assistance applying for this posit...
#
# [637 rows x 10 columns]

# %%
# How many do we have?
print("yes:", len(yes))
print("no:", len(no)) 
print("underqualified:", len(underqualified))
# Out:
# yes: 0
# no: 0
# underqualified: 0

# %%
# When finished sorting, uncomment the below and save the classified data
our_columns = [
       # 'posting_id', 
       'search_title', 'search_location', 'location', 'title',
       'company', 'salary', 'summary', 'link', 'description']
df_0.loc[yes, our_columns].to_csv('yes.csv', index=False, header=False, mode = 'a')
df_0.loc[no, our_columns].to_csv('no.csv', index=False, header=False, mode = 'a')
df_0.loc[underqualified, our_columns].to_csv('underqualified.csv', index=False, header=False, mode='a')
