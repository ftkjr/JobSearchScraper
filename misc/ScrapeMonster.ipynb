# %%
# Import Packages 
import csv
from datetime import *
import requests
from bs4 import BeautifulSoup
import pandas as pd
import time
import re

# %%
def get_job_results(url: str, info_id: str) -> list:
    """Return page results from job site"""
    page = requests.get(url)
    soup = BeautifulSoup(page.content, 'html.parser')
    results = soup.find(id=info_id) 
    return results

def collect_individual_search_info(site: str, individual_searches: list, total_results_frame, unique_results_frame, search_times: list, total_search_time: float, notes:str = None):
    """Return individual search info as one DataFrame"""
    # Create framework for the individual search data. 
    individual_searches_frame = pd.DataFrame(individual_searches, columns=['search_location', 'search_title'])
    individual_searches_frame['SearchTimes'] = search_times
    individual_searches_frame['Site'] = site
    individual_searches_frame['Date'] = datetime.now().strftime("%Y-%m-%d %H:%M:%S")

    # Collect the counts for the results before removing duplicates.
    total_results = total_results_frame[['search_title', 'search_location', 'description']].groupby(['search_title', 'search_location'], as_index=False).count()

    # Collect the counts for the results after removing duplicates.
    unique_results = unique_results_frame[['search_title', 'search_location', 'description']].groupby(['search_title', 'search_location'], as_index=False).count()

    # Add the Total Results count to the individual searches frame.
    individual_searches_frame = pd.merge(
        individual_searches_frame, 
        pd.DataFrame({
            'search_title': total_results['search_title'], 
            'search_location': total_results['search_location'], 
            'TotalResults': total_results['description']
            }),
        on=['search_title', 'search_location'], 
        how='left'
        )

    # Add the Unique Results count to the individual searches frame.
    individual_searches_frame = pd.merge(
        individual_searches_frame, 
        pd.DataFrame({
            'search_title': unique_results['search_title'], 
            'search_location': unique_results['search_location'], 
            'UniqueResults': unique_results['description']
            }),
            on=['search_title', 'search_location'], 
            how='left'
            )
    
    # Where we didn't have a results count we must not have found anything, so replace the NaN with a 0.
    for col in ['TotalResults', 'UniqueResults']:
        individual_searches_frame[col][individual_searches_frame[col].isnull()] = 0

    # Add the total search time to the data frame.
    individual_searches_frame['TotalSearchTime'] = total_search_time
    # Add any notes we have to the frame.
    individual_searches_frame['Notes'] = notes
    individual_searches_frame.to_csv('Diagnostics/ScraperPerformancebySearch.csv', mode='a+', header=False)
  

def preprocess_jobs(initial_data):
    """Clean up the jobs frame"""
    for col in initial_data.columns:
        initial_data[col] = initial_data[col].str.replace('\n', ' ')
    processed_data = initial_data.drop_duplicates(subset=['title', 'company', 'description'], keep='first')
    processed_data['description'] = processed_data['description'].str.replace(r"([a-z])([A-Z])", r"\1 \.\2")
    processed_data['description'] = processed_data['description'].str.replace(r' \\.', '')
    processed_data['posted'] = processed_data['posted'].str.replace('+', '')
    processed_data['posted'] = processed_data['posted'].str.replace(r' day[a-z ]*', '')
    processed_data['posted'][processed_data['posted'].str.lower().str.contains('today')] = '0'
    processed_data['posted'][processed_data['posted'].str.lower().str.contains('just')]= '0'
    processed_data['posted'] = pd.to_numeric(processed_data['posted'])
    return processed_data

        
def save_search_stats(site: str, total_returned_jobs: int, unique_jobs: int, search_time: float, total_searches: int, notes = None):
    """Write search statistics as new row in ScraperPerformance.csv"""
    with open('Diagnostics/ScraperPerformance.csv', 'a+', newline='') as file:
        write = csv.writer(file, delimiter=',')
        if notes is not None:
            notes = notes.replace(',', ';')
        write.writerow([site, total_returned_jobs, unique_jobs, search_time, total_searches, date.today(), notes])

# %%
####################
# Data Frame Columns
columns = ['search_title', 'search_location', 'location', 'title', 'company', 'posted', 'salary', 'summary', 'link', 'description']

###############
# Job titles
prefixes = ['entry level ', 'junior ', 'associate ', '']
titles = ['business analyst', 'data analyst', 'data engineer', 'data scientist', 'financial analyst', 'macro analyst']

################
# Job Locations
search_locations = [
    'New York, NY',
    'Newark, NJ', 'Princeton, NJ', 'Jersey City, NJ', 'Trenton, NJ', 'Bridgewater, NJ', 'Somerville, NJ', 'Summit, NJ', 'Morristown, NJ', 'Edison, NJ', 'Metuchen, NJ', 'Hackensack, NJ',
    'Philadelphia, PA', 
    'Stamford, CT', 'Greenwich, CT',
    'New York', 'New Jersey', 'New Hampshire', 'Pennsylvania', 'Connecticut',
    'NY', 'NJ', 'NH', 'PA', 'CT',
    'remote'
    ]

n_searches = (len(titles) * len(prefixes)) * len(search_locations)

# %%
#####################################################
# Scrape Monster.com
# Empty container for posting info
jobs_monster = []

search_times_monster = []
individual_searches = []

ttm = True
start_time = time.time()
counter = 1


for search_location in search_locations:
    for search_title in [(s + t) for s in prefixes for t in titles]:

    ####################################
        # Monitoring Chunk
        individual_searches.append([search_location, search_title])
        if counter > 1: 
            search_time = time.time() - search_start
            search_times_monster.append(search_time)
            if ttm:
                print(f'The search took {search_time} seconds.\n')
        if ttm:
            print(f'Searching {search_location} for {search_title} positions \tSearch number {counter} of {n_searches}') 
        counter += 1
        search_start = time.time()
    #####################################

        st = search_title.replace(' ', '-')
        sl = search_location.replace(' ', '-').replace(',', '__2C')
        URL = f'https://www.monster.com/jobs/search/?q={st}&where={sl}&stpage=1&page=8'
        try:
            results = get_job_results(URL, 'ResultsContainer')
        except:
            continue

        job_elems = results.find_all('section', class_='card-content')
        if results is None: continue

        for job in job_elems:
            # If the title or company isn't present, continue to the next one
            title_elem = job.find('h2', class_='title')
            if title_elem is None:
                continue
            else:
                title = title_elem.text.strip()

            # If the company element isn't present continue to the next
            company_elem = job.find('div', class_='company')
            if company_elem is None:
                continue
            else:
                company = company_elem.text.strip()
            
            # If there isn't a job location provided, indicate that
            location_elem = job.find('div', class_='location')
            if location_elem is None:
                location = 'No Location Found'
            else:
                location = location_elem.text.strip()

            # When was the job posted
            posted = job.find('time').text.strip()
            
            # Get the link for the page with the full job description
            link = job.find('a')['href']

            try:
                description_results = get_job_results(link, 'main-content')
            except:
                continue
            details_elem = description_results.findAll('div', class_='detail-row')


            salary = None
            job_type = None
            for detail in details_elem:
                dt = detail.text.strip()
                if 'Salary' in dt:
                    salary = dt
                if 'Job Type' in dt:
                    job_type = dt                    
                if posted is None and 'Posted' in dt:
                    posted = dt

            if salary is None:
                salary = 'No Salary Provided'
            if job_type is None:
                job_type = 'No Job Type Provided'
            

            description_elem = description_results.find('div', class_='job-description')
            if description_elem is None:
                description = 'No Description Found'
            else:
                description = description_elem.text.strip()
            
            item = [
                search_title,
                search_location,
                location,
                title,
                company,
                posted,
                salary,
                job_type,
                link,
                description
            ]
            jobs_monster.append(item)
    
# This adds the time for the final search.
search_time = time.time() - search_start
search_times_monster.append(search_time)

total_search_time_monster = time.time() - start_time

if ttm:
     print(f'Monster search took {total_search_time_monster} seconds to retreive {len(jobs_monster)} total results (including some duplicates).')

# Convert array of arrays into data frame
monster_0 = pd.DataFrame(jobs_monster, columns=columns)

# filter and modify df going forward
monster_1 = preprocess_jobs(monster_0)

# Save the monitoring data into their respective csv's for later analysis.
# collect_individual_search_info saves into a new csv which monitors performance of each individual search
collect_individual_search_info('Monster', individual_searches, monster_0, monster_1, search_times_monster, total_search_time_monster)
save_search_stats('Monster', len(monster_0), len(monster_1), total_search_time_monster, n_searches)

print(f'Returned {len(monster_1)} unique entries from Monster.com')
# Out:
# rching Connecticut for entry level financial analyst positions 	Search number 461 of 624
# The search took 0.7883467674255371 seconds.
#
# Searching Connecticut for entry level macro analyst positions 	Search number 462 of 624
# The search took 6.996696710586548 seconds.
#
# Searching Connecticut for junior business analyst positions 	Search number 463 of 624
# The search took 7.803658962249756 seconds.
#
# Searching Connecticut for junior data analyst positions 	Search number 464 of 624
# The search took 7.381904125213623 seconds.
#
# Searching Connecticut for junior data engineer positions 	Search number 465 of 624
# The search took 4.4888856410980225 seconds.
#
# Searching Connecticut for junior data scientist positions 	Search number 466 of 624
# The search took 0.868741512298584 seconds.
#
# Searching Connecticut for junior financial analyst positions 	Search number 467 of 624
# The search took 0.7266631126403809 seconds.
#
# Searching Connecticut for junior macro analyst positions 	Search number 468 of 624
# The search took 7.535098314285278 seconds.
#
# Searching Connecticut for associate business analyst positions 	Search number 469 of 624
# The search took 7.714471101760864 seconds.
#
# Searching Connecticut for associate data analyst positions 	Search number 470 of 624
# The search took 7.642630100250244 seconds.
#
# Searching Connecticut for associate data engineer positions 	Search number 471 of 624
# The search took 21.1307635307312 seconds.
#
# Searching Connecticut for associate data scientist positions 	Search number 472 of 624
# The search took 1.1139843463897705 seconds.
#
# Searching Connecticut for associate financial analyst positions 	Search number 473 of 624
# The search took 1.594956398010254 seconds.
#
# Searching Connecticut for associate macro analyst positions 	Search number 474 of 624
# The search took 0.8863496780395508 seconds.
#
# Searching Connecticut for business analyst positions 	Search number 475 of 624
# The search took 38.83513021469116 seconds.
#
# Searching Connecticut for data analyst positions 	Search number 476 of 624
# The search took 41.89208960533142 seconds.
#
# Searching Connecticut for data engineer positions 	Search number 477 of 624
# The search took 51.87778282165527 seconds.
#
# Searching Connecticut for data scientist positions 	Search number 478 of 624
# The search took 34.04419207572937 seconds.
#
# Searching Connecticut for financial analyst positions 	Search number 479 of 624
# The search took 37.26131272315979 seconds.
#
# Searching Connecticut for macro analyst positions 	Search number 480 of 624
# The search took 2.3518049716949463 seconds.
#
# Searching NY for entry level business analyst positions 	Search number 481 of 624
# The search took 3.061347246170044 seconds.
#
# Searching NY for entry level data analyst positions 	Search number 482 of 624
# The search took 5.678947687149048 seconds.
#
# Searching NY for entry level data engineer positions 	Search number 483 of 624
# The search took 1.2588121891021729 seconds.
#
# Searching NY for entry level data scientist positions 	Search number 484 of 624
# The search took 1.4702198505401611 seconds.
#
# Searching NY for entry level financial analyst positions 	Search number 485 of 624
# The search took 2.243486166000366 seconds.
#
# Searching NY for entry level macro analyst positions 	Search number 486 of 624
# The search took 7.075956106185913 seconds.
#
# Searching NY for junior business analyst positions 	Search number 487 of 624
# The search took 3.4847354888916016 seconds.
#
# Searching NY for junior data analyst positions 	Search number 488 of 624
# The search took 2.919722080230713 seconds.
#
# Searching NY for junior data engineer positions 	Search number 489 of 624
# The search took 15.748987197875977 seconds.
#
# Searching NY for junior data scientist positions 	Search number 490 of 624
# The search took 2.017784833908081 seconds.
#
# Searching NY for junior financial analyst positions 	Search number 491 of 624
# The search took 2.592750072479248 seconds.
#
# Searching NY for junior macro analyst positions 	Search number 492 of 624
# The search took 7.02798056602478 seconds.
#
# Searching NY for associate business analyst positions 	Search number 493 of 624
# The search took 3.1656124591827393 seconds.
#
# Searching NY for associate data analyst positions 	Search number 494 of 624
# The search took 8.241815090179443 seconds.
#
# Searching NY for associate data engineer positions 	Search number 495 of 624
# The search took 51.77482318878174 seconds.
#
# Searching NY for associate data scientist positions 	Search number 496 of 624
# The search took 17.00245690345764 seconds.
#
# Searching NY for associate financial analyst positions 	Search number 497 of 624
# The search took 6.876484632492065 seconds.
#
# Searching NY for associate macro analyst positions 	Search number 498 of 624
# The search took 0.9620790481567383 seconds.
#
# Searching NY for business analyst positions 	Search number 499 of 624
# The search took 53.06898832321167 seconds.
#
# Searching NY for data analyst positions 	Search number 500 of 624
# The search took 48.80908799171448 seconds.
#
# Searching NY for data engineer positions 	Search number 501 of 624
# The search took 52.26368188858032 seconds.
#
# Searching NY for data scientist positions 	Search number 502 of 624
# The search took 49.285404205322266 seconds.
#
# Searching NY for financial analyst positions 	Search number 503 of 624
# The search took 49.43335437774658 seconds.
#
# Searching NY for macro analyst positions 	Search number 504 of 624
# The search took 6.517625331878662 seconds.
#
# Searching NJ for entry level business analyst positions 	Search number 505 of 624
# The search took 2.162057876586914 seconds.
#
# Searching NJ for entry level data analyst positions 	Search number 506 of 624
# The search took 0.986649751663208 seconds.
#
# Searching NJ for entry level data engineer positions 	Search number 507 of 624
# The search took 2.113002061843872 seconds.
#
# Searching NJ for entry level data scientist positions 	Search number 508 of 624
# The search took 1.0345344543457031 seconds.
#
# Searching NJ for entry level financial analyst positions 	Search number 509 of 624
# The search took 7.222045421600342 seconds.
#
# Searching NJ for entry level macro analyst positions 	Search number 510 of 624
# The search took 6.948434114456177 seconds.
#
# Searching NJ for junior business analyst positions 	Search number 511 of 624
# The search took 2.4860434532165527 seconds.
#
# Searching NJ for junior data analyst positions 	Search number 512 of 624
# The search took 1.7764248847961426 seconds.
#
# Searching NJ for junior data engineer positions 	Search number 513 of 624
# The search took 12.660760641098022 seconds.
#
# Searching NJ for junior data scientist positions 	Search number 514 of 624
# The search took 1.3821074962615967 seconds.
#
# Searching NJ for junior financial analyst positions 	Search number 515 of 624
# The search took 0.7589857578277588 seconds.
#
# Searching NJ for junior macro analyst positions 	Search number 516 of 624
# The search took 6.700159311294556 seconds.
#
# Searching NJ for associate business analyst positions 	Search number 517 of 624
# The search took 2.4461045265197754 seconds.
#
# Searching NJ for associate data analyst positions 	Search number 518 of 624
# The search took 4.233999729156494 seconds.
#
# Searching NJ for associate data engineer positions 	Search number 519 of 624
# The search took 48.01628112792969 seconds.
#
# Searching NJ for associate data scientist positions 	Search number 520 of 624
# The search took 1.8833577632904053 seconds.
#
# Searching NJ for associate financial analyst positions 	Search number 521 of 624
# The search took 1.4484624862670898 seconds.
#
# Searching NJ for associate macro analyst positions 	Search number 522 of 624
# The search took 1.0677814483642578 seconds.
#
# Searching NJ for business analyst positions 	Search number 523 of 624
# The search took 51.27412700653076 seconds.
#
# Searching NJ for data analyst positions 	Search number 524 of 624
# The search took 52.55636167526245 seconds.
#
# Searching NJ for data engineer positions 	Search number 525 of 624
# The search took 49.83874845504761 seconds.
#
# Searching NJ for data scientist positions 	Search number 526 of 624
# The search took 48.02790331840515 seconds.
#
# Searching NJ for financial analyst positions 	Search number 527 of 624
# The search took 48.98601293563843 seconds.
#
# Searching NJ for macro analyst positions 	Search number 528 of 624
# The search took 2.5876893997192383 seconds.
#
# Searching NH for entry level business analyst positions 	Search number 529 of 624
# The search took 7.256994962692261 seconds.
#
# Searching NH for entry level data analyst positions 	Search number 530 of 624
# The search took 6.891521453857422 seconds.
#
# Searching NH for entry level data engineer positions 	Search number 531 of 624
# The search took 7.199791193008423 seconds.
#
# Searching NH for entry level data scientist positions 	Search number 532 of 624
# The search took 7.643462657928467 seconds.
#
# Searching NH for entry level financial analyst positions 	Search number 533 of 624
# The search took 8.25365400314331 seconds.
#
# Searching NH for entry level macro analyst positions 	Search number 534 of 624
# The search took 6.815268516540527 seconds.
#
# Searching NH for junior business analyst positions 	Search number 535 of 624
# The search took 6.980575084686279 seconds.
#
# Searching NH for junior data analyst positions 	Search number 536 of 624
# The search took 8.143041849136353 seconds.
#
# Searching NH for junior data engineer positions 	Search number 537 of 624
# The search took 2.6425881385803223 seconds.
#
# Searching NH for junior data scientist positions 	Search number 538 of 624
# The search took 7.014604806900024 seconds.
#
# Searching NH for junior financial analyst positions 	Search number 539 of 624
# The search took 2.1698827743530273 seconds.
#
# Searching NH for junior macro analyst positions 	Search number 540 of 624
# The search took 7.522812128067017 seconds.
#
# Searching NH for associate business analyst positions 	Search number 541 of 624
# The search took 0.8759362697601318 seconds.
#
# Searching NH for associate data analyst positions 	Search number 542 of 624
# The search took 0.7413434982299805 seconds.
#
# Searching NH for associate data engineer positions 	Search number 543 of 624
# The search took 6.321432113647461 seconds.
#
# Searching NH for associate data scientist positions 	Search number 544 of 624
# The search took 7.273834466934204 seconds.
#
# Searching NH for associate financial analyst positions 	Search number 545 of 624
# The search took 5.8824241161346436 seconds.
#
# Searching NH for associate macro analyst positions 	Search number 546 of 624
# The search took 7.710611343383789 seconds.
#
# Searching NH for business analyst positions 	Search number 547 of 624
# The search took 5.2635111808776855 seconds.
#
# Searching NH for data analyst positions 	Search number 548 of 624
# The search took 11.953936338424683 seconds.
#
# Searching NH for data engineer positions 	Search number 549 of 624
# The search took 51.20369029045105 seconds.
#
# Searching NH for data scientist positions 	Search number 550 of 624
# The search took 5.887006759643555 seconds.
#
# Searching NH for financial analyst positions 	Search number 551 of 624
# The search took 6.893341302871704 seconds.
#
# Searching NH for macro analyst positions 	Search number 552 of 624
# The search took 6.368265151977539 seconds.
#
# Searching PA for entry level business analyst positions 	Search number 553 of 624
# The search took 1.1858999729156494 seconds.
#
# Searching PA for entry level data analyst positions 	Search number 554 of 624
# The search took 1.9585449695587158 seconds.
#
# Searching PA for entry level data engineer positions 	Search number 555 of 624
# The search took 1.9395785331726074 seconds.
#
# Searching PA for entry level data scientist positions 	Search number 556 of 624
# The search took 7.764528274536133 seconds.
#
# Searching PA for entry level financial analyst positions 	Search number 557 of 624
# The search took 7.118683338165283 seconds.
#
# Searching PA for entry level macro analyst positions 	Search number 558 of 624
# The search took 7.285888671875 seconds.
#
# Searching PA for junior business analyst positions 	Search number 559 of 624
# The search took 1.0224449634552002 seconds.
#
# Searching PA for junior data analyst positions 	Search number 560 of 624
# The search took 2.0113625526428223 seconds.
#
# Searching PA for junior data engineer positions 	Search number 561 of 624
# The search took 15.558366060256958 seconds.
#
# Searching PA for junior data scientist positions 	Search number 562 of 624
# The search took 1.187309980392456 seconds.
#
# Searching PA for junior financial analyst positions 	Search number 563 of 624
# The search took 2.7076730728149414 seconds.
#
# Searching PA for junior macro analyst positions 	Search number 564 of 624
# The search took 7.180957794189453 seconds.
#
# Searching PA for associate business analyst positions 	Search number 565 of 624
# The search took 4.217456340789795 seconds.
#
# Searching PA for associate data analyst positions 	Search number 566 of 624
# The search took 2.541173219680786 seconds.
#
# Searching PA for associate data engineer positions 	Search number 567 of 624
# The search took 55.12742614746094 seconds.
#
# Searching PA for associate data scientist positions 	Search number 568 of 624
# The search took 3.1849703788757324 seconds.
#
# Searching PA for associate financial analyst positions 	Search number 569 of 624
# The search took 4.207245588302612 seconds.
#
# Searching PA for associate macro analyst positions 	Search number 570 of 624
# The search took 7.402409076690674 seconds.
#
# Searching PA for business analyst positions 	Search number 571 of 624
# The search took 54.73599028587341 seconds.
#
# Searching PA for data analyst positions 	Search number 572 of 624
# The search took 54.09499430656433 seconds.
#
# Searching PA for data engineer positions 	Search number 573 of 624
# The search took 51.640530586242676 seconds.
#
# Searching PA for data scientist positions 	Search number 574 of 624
# The search took 50.48653221130371 seconds.
#
# Searching PA for financial analyst positions 	Search number 575 of 624
# The search took 51.53703737258911 seconds.
#
# Searching PA for macro analyst positions 	Search number 576 of 624
# The search took 4.165415287017822 seconds.
#
# Searching CT for entry level business analyst positions 	Search number 577 of 624
# The search took 6.985243797302246 seconds.
#
# Searching CT for entry level data analyst positions 	Search number 578 of 624
# The search took 7.849377393722534 seconds.
#
# Searching CT for entry level data engineer positions 	Search number 579 of 624
# The search took 7.771516799926758 seconds.
#
# Searching CT for entry level data scientist positions 	Search number 580 of 624
# The search took 0.8577404022216797 seconds.
#
# Searching CT for entry level financial analyst positions 	Search number 581 of 624
# The search took 0.7509279251098633 seconds.
#
# Searching CT for entry level macro analyst positions 	Search number 582 of 624
# The search took 6.778184652328491 seconds.
#
# Searching CT for junior business analyst positions 	Search number 583 of 624
# The search took 7.418799638748169 seconds.
#
# Searching CT for junior data analyst positions 	Search number 584 of 624
# The search took 7.612511396408081 seconds.
#
# Searching CT for junior data engineer positions 	Search number 585 of 624
# The search took 3.8579068183898926 seconds.
#
# Searching CT for junior data scientist positions 	Search number 586 of 624
# The search took 0.7920739650726318 seconds.
#
# Searching CT for junior financial analyst positions 	Search number 587 of 624
# The search took 1.0060224533081055 seconds.
#
# Searching CT for junior macro analyst positions 	Search number 588 of 624
# The search took 7.101143836975098 seconds.
#
# Searching CT for associate business analyst positions 	Search number 589 of 624
# The search took 7.632007360458374 seconds.
#
# Searching CT for associate data analyst positions 	Search number 590 of 624
# The search took 8.253342390060425 seconds.
#
# Searching CT for associate data engineer positions 	Search number 591 of 624
# The search took 21.109885215759277 seconds.
#
# Searching CT for associate data scientist positions 	Search number 592 of 624
# The search took 1.1773183345794678 seconds.
#
# Searching CT for associate financial analyst positions 	Search number 593 of 624
# The search took 1.7101664543151855 seconds.
#
# Searching CT for associate macro analyst positions 	Search number 594 of 624
# The search took 0.7477774620056152 seconds.
#
# Searching CT for business analyst positions 	Search number 595 of 624
# The search took 35.56469964981079 seconds.
#
# Searching CT for data analyst positions 	Search number 596 of 624
# The search took 53.64696145057678 seconds.
#
# Searching CT for data engineer positions 	Search number 597 of 624
# The search took 59.47855043411255 seconds.
#
# Searching CT for data scientist positions 	Search number 598 of 624
# The search took 39.6285343170166 seconds.
#
# Searching CT for financial analyst positions 	Search number 599 of 624
# The search took 46.215951919555664 seconds.
#
# Searching CT for macro analyst positions 	Search number 600 of 624
# The search took 2.9263906478881836 seconds.
#
# Searching remote for entry level business analyst positions 	Search number 601 of 624
# The search took 0.8360521793365479 seconds.
#
# Searching remote for entry level data analyst positions 	Search number 602 of 624
# The search took 1.1137402057647705 seconds.
#
# Searching remote for entry level data engineer positions 	Search number 603 of 624
# The search took 0.8481323719024658 seconds.
#
# Searching remote for entry level data scientist positions 	Search number 604 of 624
# The search took 8.28030014038086 seconds.
#
# Searching remote for entry level financial analyst positions 	Search number 605 of 624
# The search took 0.8798027038574219 seconds.
#
# Searching remote for entry level macro analyst positions 	Search number 606 of 624
# The search took 7.5764851570129395 seconds.
#
# Searching remote for junior business analyst positions 	Search number 607 of 624
# The search took 0.751521110534668 seconds.
#
# Searching remote for junior data analyst positions 	Search number 608 of 624
# The search took 1.158778190612793 seconds.
#
# Searching remote for junior data engineer positions 	Search number 609 of 624
# The search took 2.767723321914673 seconds.
#
# Searching remote for junior data scientist positions 	Search number 610 of 624
# The search took 10.759325742721558 seconds.
#
# Searching remote for junior financial analyst positions 	Search number 611 of 624
# The search took 0.6823258399963379 seconds.
#
# Searching remote for junior macro analyst positions 	Search number 612 of 624
# The search took 7.541656732559204 seconds.
#
# Searching remote for associate business analyst positions 	Search number 613 of 624
# The search took 7.81315803527832 seconds.
#
# Searching remote for associate data analyst positions 	Search number 614 of 624
# The search took 9.537635564804077 seconds.
#
# Searching remote for associate data engineer positions 	Search number 615 of 624
# The search took 2.8942131996154785 seconds.
#
# Searching remote for associate data scientist positions 	Search number 616 of 624
# The search took 1.3443303108215332 seconds.
#
# Searching remote for associate financial analyst positions 	Search number 617 of 624
# The search took 5.960865020751953 seconds.
#
# Searching remote for associate macro analyst positions 	Search number 618 of 624
# The search took 8.126867294311523 seconds.
#
# Searching remote for business analyst positions 	Search number 619 of 624
# The search took 32.28633713722229 seconds.
#
# Searching remote for data analyst positions 	Search number 620 of 624
# The search took 25.35648250579834 seconds.
#
# Searching remote for data engineer positions 	Search number 621 of 624
# The search took 65.70044589042664 seconds.
#
# Searching remote for data scientist positions 	Search number 622 of 624
# The search took 19.78467035293579 seconds.
#
# Searching remote for financial analyst positions 	Search number 623 of 624
# The search took 9.613230228424072 seconds.
#
# Searching remote for macro analyst positions 	Search number 624 of 624
# Monster search took 8841.339590072632 seconds to retreive 33401 total results (including some duplicates).
# Returned 6911 unique entries from Monster.com

# %%
monster_1.to_csv('data/' + datetime.now().strftime("%Y-%m-%d") + '_jobsmonster.tsv', sep='\t', index=False)
